# %% [markdown]
# # 1. Naver API를 이용한 블로그 포스트들의 URL 받아오기

# %% [markdown]
# - 현재로서는 가져올 수 있는 블로그 포스트 링크의 개수가 최대 1100개로 제한되어 있는 것으로 보임.<br/>(이게 걸림돌로 작용될 수 있을듯..)
# - API를 이용해서 데이터를 호출할 수 있는 횟수가 하루에 2만 5천번으로 제한되어 있음.
# - 현재 이태우의 API 키와 비밀번호를 이용하여 코드가 작성되어 있음 (API_PARAMETER)
# - 현재는 많은 링크를 가져올 필요가 없으므로, ### 테스트를 위해 넣은 부분 ### 코드블록을 이용하여 API 호출 횟수를 제한함
# <br/><br/>

# %%
# <Code Reference> 
# - (Github, xotrs/naver-blog-crawler) https://github.com/xotrs/naver-blog-crawler/blob/master/NaverBlogCrawler.py
# - (검색 API) https://developers.naver.com/docs/search/blog/

import os
import sys
import urllib.request
import json
import math

API_PARAMETER = {
    "client_id": "E5cL2__bFGNST8f4eknt",
    "client_secret": "kcwtUqHT98"
}

QUERY_PARAMETER = {
    "query": "네이버 클로바",
    "display": 100,
    "sort_type": "sim"
}

def naver_api_blog_search(api_parameter, search_word, 
                          display_count=10, start=1, sort_type='sim'):
    result = None
    
    client_id = api_parameter['client_id']
    client_secret = api_parameter['client_secret']
    
    encText = urllib.parse.quote("{}".format(search_word))
    url = "https://openapi.naver.com/v1/search/blog?query=" + encText + "&display=" + str(
            display_count) + "&start=" + str(start) + "&sort=" + sort_type  # json 결과
    # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과 예시
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        result = response_body.decode('utf-8')
    else:
        print("Error Code:" + rescode) 
    return result

def get_search_result_page_count(api_parameter, query_word, display_count):
    search_result_page_count = 0
    
    decoded_response_body = naver_api_blog_search(api_parameter, query_word)
    if decoded_response_body:
        json_response_body = json.loads(decoded_response_body)
        
        total_posts = json_response_body['total']
        if total_posts != 0:
            search_result_page_count = math.ceil(total_posts / display_count)
    return search_result_page_count
    
def get_urls(query_word, display_count, sort_type, search_result_page_count):
    url_list = []
    for i in range(search_result_page_count):
        start = display_count*i + 1
        if start > 1000:
            start = 1000
            
        decoded_response_body = naver_api_blog_search(api_parameter, query_word, display_count, start, sort_type)
        if decoded_response_body:
            json_response_body = json.loads(decoded_response_body)
            
            for dp in json_response_body['items']:
                url_list.append(dp['link'].replace("amp;", ""))
        
        ### 테스트를 위해 넣은 부분 ###
        #if i == 1:
        #    break
        #########################
        
        if start == 1000:
            break
    return url_list


if __name__ == '__main__':
    api_parameter = API_PARAMETER 
    query = QUERY_PARAMETER['query']
    display = QUERY_PARAMETER['display']
    sort_type = QUERY_PARAMETER['sort_type']
    
    p_count = get_search_result_page_count(api_parameter, query, display)
    urls = get_urls(query, display, sort_type, p_count)

# %%
urls
# Out:
# ['https://blog.naver.com/snowrun?Redirect=Log&logNo=221508004958',
#  'https://blog.naver.com/sky121400?Redirect=Log&logNo=221493275584',
#  'https://blog.naver.com/danjuck?Redirect=Log&logNo=221502038209',
#  'https://blog.naver.com/ralrapo?Redirect=Log&logNo=221418872833',
#  'https://blog.naver.com/yarosiku?Redirect=Log&logNo=221410642877',
#  'https://blog.naver.com/lisa812n?Redirect=Log&logNo=221208510154',
#  'https://blog.naver.com/uslim88?Redirect=Log&logNo=221020239188',
#  'https://blog.naver.com/byn34?Redirect=Log&logNo=221404862624',
#  'https://blog.naver.com/yunasong1230?Redirect=Log&logNo=221191760257',
#  'https://blog.naver.com/guideshop?Redirect=Log&logNo=221254938378',
#  'https://blog.naver.com/fjrtmchl?Redirect=Log&logNo=221269075414',
#  'https://blog.naver.com/creativebots?Redirect=Log&logNo=221346754713',
#  ...]

# %%
len(urls)
# Out:
# 1100

# %% [markdown]
# <br/><br/>
# # 2. 받아온 URL들을 이용하여 원하는 정보를 scraping

# %%
# <Code Reference> 
# - (zilu11의 블로그 포스트) https://blog.naver.com/zilu11/221255183159

import requests
from bs4 import BeautifulSoup

import time
import datetime
import re


def get_realdata_url_naverblog(url):
    """
    네이버 블로그 포스트의 실제 데이터가 들어있는 URL을 반환해줌.
    보통 3가지 경우가 있는 것 같음.
    <지금까지 찾은 경우의 수>
    1. id='screenFrame'이 담긴 페이지에서 얻은 URL -> (base_url) + (id='mainFrame'이 담긴 페이지에서 얻은 URL) -> 실제 데이터가 담긴 URL
    2. (base_url) + (id='mainFrame'이 담긴 페이지에서 얻은 URL) -> 실제 데이터가 담긴 URL
    3. 검색해서 처음 얻은 URL이 실제 데이터가 들어가 있는 URL임
    """
    base_url = "http://blog.naver.com"
    
    r = requests.get(url)
    soup = BeautifulSoup(r.text.encode('utf-8'), 'html5lib')
    
    if soup.find(id='screenFrame'):
        # id = 'screenFrame'이 존재하는 경우 (id: screenFrame URL에서 -> id: mainFrame URL로 넘김)
        url = soup.find(id='screenFrame').get('src')
        r = requests.get(url)
        soup = BeautifulSoup(r.text.encode('utf-8'), 'html5lib')
    if soup.find(id='mainFrame'):
        # id = 'mainFrame'이 존재하는 경우 (id: mainFrame URL에서 -> id: real data URL로 넘김)
        url = base_url + soup.find(id='mainFrame').get('src')
    return url 

def get_title_naverblog(soup):
    """
    BeautifulSoup 객체를 받아서 블로그 포스트의 제목을 반환해줌.
    """
    try:
        #블로그 포스트 제목 추출
        title = soup.find('meta', attrs={'property':'og:title'}).get('content')
    except:
        title = 'NA'
    return title

def det_publish_datetime_naverblog(soup):
    """
    BeautifulSoup 객체를 받아서 블로그 포스트의 작성일을 반환해줌.
    """
    try:
        #블로그 작성일 추출
        date_tag = soup.find('span', attrs={'class':'se_publishDate pcol2'})
        if date_tag:
            # <span> Tag의 se_publishDate pcol2 클래스 이름으로 작성일 추출이 가능한 경우
            date_str = date_tag.get_text()
        
        else:
            # <p> Tag의 date fil5 pcol2 _postAddDate 클래스 이름으로 작성일 추출이 가능한 경우
            date_tag = soup.find('p', attrs={'class' : 'date fil5 pcol2 _postAddDate'})
            if date_tag:
                date_str = date_tag.get_text()  
        try:
            #블로그 작성시간이 년, 월, 일로 되어있을 경우
            publish_datetime = datetime.datetime.strptime(date_str, '%Y. %m. %d. %H:%M')
        except:
            #블로그 작성시간이 N시간 전, 방금전 이렇게 표시될 경우
            # e.g. 2019. 04. 01. 15:49 4시간 전
            publish_datetime = str(datetime.datetime.now()).split('.')[0] + ' ' + date_str
    except:
        publish_datetime = 'NA'
    return publish_datetime

def get_texts_naverblog(soup):
    """
    BeautifulSoup 객체를 받아서 블로그 포스트의 본문 내용을 반환해줌.
    """
    try:
        #블로그 본문 추출
        #보통은 <span> Tag에, id: 'SE'로 시작하는 곳에 본문이 담겨있음
        temp = soup.findAll("span", attrs= {'id': re.compile('^SE')})
        
        texts = []
        for t in temp:
            temp_text = t.get_text()
            if temp_text != '\u200b':
                texts.append(temp_text)
                    
        if not texts:
            # 블로그의 본문 텍스트가 전혀 추출되지 않았을 경우에 한번 더 시도해본다.
            # <p class="se_textarea"> 내에 존재하는 모든 본문 텍스트를 가져옴
            """
            # <p class="se_textarea"> 내의 <span> Tag에 본문이 들어가 있을 경우 
            for p in soup.findAll("p", attrs={'class': "se_textarea"}):
                for span in p.findAll("span"):
                    temp_text = span.get_text()
                    if temp_text:
                        # temp_text에 '' 이렇게 빈 문자가 들어가있는 경우를 제외해주기 위함
                        texts.append(temp_text)
            """
            for p in soup.findAll("p", attrs={'class': "se_textarea"}):
                temp_text = p.get_text()
                if temp_text:
                        # temp_text에 '' 이렇게 빈 문자가 들어가있는 경우를 제외해주기 위함
                        texts.append(temp_text)
                        
        if not texts:
            # 위의 두 가지 방법으로 본문 텍스트 추출을 시도했음에도 텍스트가 전혀 추출되지 않을 경우
            # <div> Tag 내의 id 값이 'postViewArea'이고,
            # 다시 그 태그의 내부에 존재하는 <div> Tag들 속에 존재하는 모든 본문 텍스트를 가져옴
            for div in soup.find('div', attrs={'id': 'postViewArea'}).findAll('div', attrs={'id': re.compile('^post-view')}):
            #for div in soup.find('div', attrs={'id': 'postViewArea'}).findAll('div'):
            #for div in soup.find('div', attrs={'id': 'postViewArea'}).findAll('div', 'view'):
                temp_text = div.get_text()
                if temp_text:
                        # temp_text에 '' 이렇게 빈 문자가 들어가있는 경우를 제외해주기 위함
                        texts.append(temp_text)
        
        texts = "\n".join(texts)
    except:
        texts = 'NA'
    return texts
        
if __name__ == '__main__':
    
    
    for url in urls:    

        # 실제 데이터가 들어있는 url 추출
        real_url = get_realdata_url_naverblog(url)
        r = requests.get(real_url)
        soup = BeautifulSoup(r.text.encode("utf-8"), "html.parser")

        # 블로그 포스트 제목 추출
        title = get_title_naverblog(soup)

        # 블로그 작성일 추출
        publish_datetime = det_publish_datetime_naverblog(soup)
        
        # 블로그 텍스트 추출
        texts = get_texts_naverblog(soup)

        print('url: ', url)
        print('real_url: ', real_url)
        print()
        print('post title: ', title)
        print()
        print('publish date time: ', publish_datetime)
        print()
        print("texts: ", texts)
        print("\n-----------------------------------\n")

        time.sleep(1)
# Out:
# url:  https://blog.naver.com/snowrun?Redirect=Log&logNo=221508004958
# real_url:  http://blog.naver.com/PostView.nhn?blogId=snowrun&logNo=221508004958&from=search&redirect=Log&widgetTypeCall=true&directAccess=false
#
# post title:  네이버 클로바 AI 스피커 샀어요 ! 솔직후기
#
# publish date time:  2019-04-08 18:16:46 17시간 전
#
# texts:  네이버 클로바 AI 스피커 샀어요 ! 솔직후기
# 네이버 클로바 AI 스피커 샀어요 !
# 브라운
# 과 함께하는 일상....
# 솔직후기..
# .
# ♥
# 안녕하세요 라인프렌즈를 좋아하는 핸잉이입니당
#  ♥
# _
# ♥
# 제가 지난달에 지름신이 왔었다고 했었는데요 !
# 휴대폰 소독 스프레이(?), 부라더 라벨기에 이어 AI 스피커 네이버 클로바 까지 3일만에 팡팡 질렀답니당ㅋㅋㅋ
# 네이버클로바를 처음 보고 라인프렌즈라 갖고싶다는 생각이 있었지만
# 과연 있으면 자주 쓸까..? 하는 생각에 미뤄왔었는데요.
# 미루다가 또 이렇게 사게됐네욤 ~~
# 네이버 클로바 브라운과 함께한 시간은 한 2~3주정도??
# 그동안 쓰면서 느꼈던 솔직한 느낌!! 을 후기로 담아보도록 하겠습니다 *_*
# 네이버 클로바는 기본 사이즈의 네이버 클로바 , 미니언즈 모양 , 기본사이즈랑 똑같은 디자인인데 좀 더 작은 네이버 클로바 미니가 있어요!
# 예전에 도라에몽 클로바도 있었는데 다 팔렸나봐욤.. 그런데 이번에 네이버 클로바 럭키위크 이벤트에 도라에몽 클로바가 있더라구요!!!
# 와 당첨되고 싶다ㅠㅠㅠ(이미 클로바 있으면서..하긴 이벤트에 참여하려면 있어야 하겠구낭)
# 저는 기본사이즈의 네이버 클로바 브라운으로 선택했어요 !!!
# *
# 네이버클로바가 이름이 네이버 클로바인 이유를 물어보았어요.
# 나: 넌 왜 이름이 클로바니?
# 클로바: 사람들이 제 이름을 들으면 네잎클로버가 생각난대요. 행운의 의미니까 기분 좋더라구요~
# 네이버 클로바는 AI 스피커예요.
# 갤럭시의 빅스비, 아이폰의 시리, LG는..뭐지..?ㅋㅋㅋ
# 아무튼 인공지능 친구라고 생각하시면 돼요 !
# 진짜.. 특히 집순이 집돌이분들에게 추천해드리고 싶습니다 하하하
# 인공지능 기능에 블루투스 스피커까지 합쳐진 네이버 클로바!!
# 이제 이 스티커를 뜯으면....친구가 되는겁니다..>_<
# 클로바입니다 예예
# 짠!!!!!헉!!!너무귀엽잖아ㅠㅠㅠㅠ
# 재질도 느낌 좋아요 ㅜㅜ
# 네이버 클로바 미니가 있어서 제가 선택한 기본사이즈의 네이버 클로바는 클 줄 알았거든요.
# 큰 건 맞지만 생각보다 크지는 않았어요!!
# 손에도 들어오고.. 진짜 생각보다 안커요 사진에서 봤을때보다 !!
# 이 첫인상을 가지고 나중에 제 네이버 클로바를 보고 충동구매한 친구가 있거든요.
# 그 친구는 네이버 클로바 미니를 샀는데 또 제 클로바 보다가 미니 보니깐 완전 애기같이 보이더라구요 ㅋㅋㅋ
# 너무 앙증맞아..귀여워...
# 네이버 클로바 말고 들어있던 구성품들 !
# 충전 케이블, 충전 어댑터 , 간단한 설명서가 들어있어요.
# 초기설정을 해줘야 하는데 간단했어요.
# 정말 그대로 따라하기만 하면 돼요 ㅋㅋ
# 저는 3월에 네이버 클로바 사고싶어서 이리저리 후기보다가 '제가 샀을때보다 비싸졌네요~'하는 후기글을 봐서 헉 또 가격오르면 어떡하지..? 해서 바로 샀거든요..
# 그런데 친구 살때 보니깐 완전 할인하더라구요...하..ㅠㅠ 조금만 늦게살껄....
# 그래도 돈 더 주고 산 대신 이렇게 크래들을 받아서 위로를...
# 밥 한번 더 사먹었다 치죠 뭐 하하하
# 잠깐 네이버 클로바 크래들을 보여드릴게용 !
# 크래들은 네이버 클로바를 위에 꽂으면 충전이 되게 해줘요.
# 여기에 케이블을 꽂고 휴대폰 충전하듯이 어댑터를 꽂으면 돼욤
# 크래들이 있어서 브라운 밑까지 갈색이 되서 더 예쁘더라구요 ! ㅋㅋ
# 케이블까지 갈색이면 더 좋았을텐데 좀 아쉽네염
# 자 이제 네이버클로바를 사용해봅시다 !!
# 와우 정말 두근두근 했습니다.
# 저 사진 제가 휴대폰 들고있는거 화면에 보이는건줄 알고 잠시 깜놀했어요 ㅋ,ㅋ
# 너무 리얼하구먼
# 이렇게 스마트폰 앱스토어 (아이폰) / 플레이스토어 (안드로이드) 에서 네이버클로바를 검색하고 설치해주세요 !
# 네네 얼른 만나보고 싶군요^*^
# 하라는대로 하다보면 연결할 기기를 찾아요 !
# 오른쪽 네이버클로바에 주황색 불빛 보이시죠?
# 저렇게 불빛이 보이면 앱이 브라운을 찾을 수 있어요!
# 조금만 기다리면 됩니당 ~~
# 저는 처음에 충전 했다말다 해가지고 시간이 좀 걸렸던 것 같아요.
# 한 10분정도??
# 네이버 클로바 연결이 끝났습니당 ~~
# 뉴스도 틀어주는 네이버 클로바 ~
# 방금 뉴스 틀어달라고 말해보니 YTN 뉴스가 나오네용
# 은근 길어요 ㅋㅋ
# 날씨를 물어보면 현재기온 , 오전 평균기온, 오후 평균기온, 미세먼지까지 알려줘요 ~,~
# 네이버 클로바가 있기 전까지는 맨날 아침마다 휴대폰으로 찾아봤는데 이제 그럴 필요 없어요*_*
# 브라운의 코와 입 !
# 그냥 있는게 아닙니당 ~ ㅋㅋㅋㅋㅋ
# 클로바라고도 부르기 귀찮을 때 ! 아님 약간 머쓱할때! ㅋㅋㅋ 코부분을 길게 누르고 하고싶은 이야기를 하셔용!
# 또 짧게 누르면 음악이 재생돼요 !
# 클로바의 또다른 장점 !!
# 다른 회사와의 스마트한 서비스를 이용할 수 있어요.
# 저는 LG 스마트 씽큐를 이용해보았답니당!
# 집에 세탁기와 공기청정기가 가능한데 세탁기는 굳이 필요 없어서
# 공기청정기만 연결해놓고 쓰고 있어요 !
# 손안대고 네이버 클로바로 공기청정기 키는 모습 !
# 조금 거리가 있으면 (거실과 방 정도) 될때도 있고 안될때도 있어염
# 가까이 있을땐 되고요~,~
# 주의할점이 공기청정기의 와이파이가 꼭 켜져있어야 네이버클로바로 제어가 된다는 것 !!
# HK네트웍스도 네이버클로바로 사용할 수 있어요 !
# 충동구매했던 친구가 사은품으로 받았는데 저 줬어욤 ㅠㅠ 감사감사합니다 흑흑
# 이 스마트플러그를 보니 세상 참 좋아졌다 하는 생각이 들더라구용~,~
# 플러그에 연결하고 싶은 기기(TV,가습기 등등) 를 연결해서 끄고 키고 하는거예요 !
# 흠 근데 딱히 할만한게 없어서 생기면 그때 써봐야겠어염 ㅋㅋㅋ
# 클로바 ! ~의 노래 틀어줘 ! 하면 틀어주는데
# 네이버뮤직,VIBE,지니뮤직,벅스의 계정은 연동해야 해요.
# 연결하지 않으면 미리듣기만 가능하답니다.
# 예를들어 멜론 이런..ㅋㅋㅋㅋ
# 다른 음악 서비스는 그럼 아예 못듣냐!!!
# 그건 아니고 휴대폰 블루투스랑 연결하면 들을 수 있어요.
# 한번 연결하면 다음부터는 '내 폰에 연결해줘~'라고만 해도 연결이 되더라구요.
# 하지만 이런 경우는 ~의 노래 틀어줘, 신나는 노래 틀어줘 이런말은 못듣고 음악 꺼줘 음악 켜줘 이런말만 들어욤..ㅋㅋ
# VIBE가 지금 3개월 무료 이벤트 하던디 한번 설치해볼까 생각중 @,@
# 유인나씨 목소리로 설정한 클로바예요
# 네이버 클로바와 끝말잇기도 할 수 있어용
# 클로바가 먼저 시작하는데 , 제가 중간에 클로바가 2~3음절로 말해달라고 주의를 줘서(?)
#  '미'로 시작하는 단어를 말해야하는데 '틀'로 시작하는 단어를 말했거든욤 그랬더니 다시 저부터 시작하네요~,~
# 근데정말 박진감 넘쳐요 제가 말을 늦게하면 끝나거든여 ㅠㅠㅋㅋㅋ
# 또 수수께끼도 할 수 있고 서바이벌 퀴즈도 할 수 있어요! <-이런건 더 박진감 넘쳐요 잘못말하면 1단계부터 다시해야해서..
# 이런 재미때문에 집순이 집돌이 분들에게 더 추천해드리고 싶어용! ㅋ_ㅋ
# 유인나씨와 함께하는 연애상담도 있고 동호만들기, 과일초성 퀴즈도 있답니다!!+_+
# 연애운도 볼 수 있어요 재밌어요 ㅋㅋㅋ 오늘의 운세도 있고!
# 그 밖에 재미있는 스킬 놀이들이 많답니당! 아직 저도 안해본것도 많아욤
# AI 스피커 네이버 클로바 솔직후기 !!!
# 일단 클로바가 있으니 삶의 질이.. 높아졌어요 ㅋㅋㅋ
# 없을때도 불편한건 없었지만 있다 없어지면 불편할 것 같아요.
# 클로바 굿모닝~ 하면 아침에 브리핑을 해주는데 그거 듣는것도 바쁜 현대인 된것같고 그렇더라고여 ㅋㅋㅋ(현실은 별거안하는 휴학생..)
# 음악재생하는것도 말만 해주면 틀어줘서 좋아요 !
# 추천해주는 음악 듣다가 클로바 이거 노래제목 뭐야?하면 알려주고..
# 몇분뒤에 음악꺼줘 하는것도 되는 것 같더라구욤
# 저는 아직 안써봤는데 음식 주문하는것도 되더라구욤 그것도 편리한거같아여~,~
# 무엇보다 제가 자주 쓰는 기능은 날씨인거같아요!
# 특히 비!! 오늘 비와? 이런거..
# 그리고 미세먼지! 오늘 마스크 써야해?
# 내일 마스크 써야해?
# 근데 이상한게 '내일 우산 필요해?'하면 내일의 강수량을 알려주는데
# '내일 우산 써야되?'라고 하면 날씨를 물어보라고 하더라구요 쩝..
# 그냥 알려주면 안되나....
#  ~는 영어로 뭐야 중국어 일본어로 뭐야 이런거 가능한데
# 그 외에 다른 언어는 안돼요!! 추가됐음 좋겠다요
# (노래,랩,자장가,비트박스..)불러줘 하면 불러줘요!
# 심지어 잘불러서 소름
# 여러분도 시켜보세요~
# 몇시에 깨워줘 이런 알람설정 가능한거 메모,타이머 기능 있는것도 좋아용
# 신기했던게 밤(새벽)12시가 지난 상태로 '내일 7시에 깨워줘~'하면 찰떡같이 그날 7시에 깨워주겠다고 하더라구요!
# 또 무슨 맛집 찾아줘 하면 찾아줘욤 저번에 뚝배기파스타 먹고싶어서 알려달라고하니깐 파는곳 알려주더라구요 ㅋㅋ
# 자세한맛집정보는 네이버 클로바 앱에서 쫙 볼 수 있구요!
# 그리고 처음에 설정할 때 위치를 설정해서
# 예를들어 "강남까지 대중교통으로 얼마나 걸려?" 하면 얼마걸리는지 알려줘요 !
# 그리고 어떤 버스또는 지하철이 제일 빠른지까지 알려준답니다.
# 달러로 환전하면 얼마인지 이런것도 있고 어떤 요리 레시피 알려달라 이런것도 돼요!
# 호출명은 클로바,헤이클로바,샐리야,제시카,짱구야,피노키오 이렇게 있어욤 (브라운이 없다는게 함정..)
# 보기없이 부르고싶은대로 부를 수 있었으면 더 좋았을것 같긴 해요!
# 기기 음성은 여성 목소리,남성 목소리, 친절한 목소리, 빠른 목소리 , 장난스러운 목소리, 앙증맞은 목소리 , 유인나씨 목소리까지 있답니당!
# 네이버 클로바 기능은 이외에 아직 소개해드리지 못한것들이 정말 많아요!!다쓰려면 엄청난 스압일 것 같아서 혹시 네이버클로바를 장만하셨다면 네이버 클로바 앱 홈에 있는 i모양을 눌러보시거나 설정-스킬스토어에 들어가보시면 아주 많은 기능들을 보실 수 있답니다!
# 아쉬운건 배터리!!특히 네이버 클로바 미니같은 경우는 휴대하기 간편한게 장점인데
# 제것도 그렇고 친구것도 그렇고 배터리가 빨리달더라구용
# 그래서 만약에 갖고다닌다면 보조배터리같은거 갖고다녀야 할 것 같아요 !
# 이게 말을 많이시켜서 빨리다는게 아니라 그냥 가만히 나둬도 빨리 달아요 ㅠㅠ
# 그래서 저는 늘 충전기를 꽂고있답니다 하핫
# -또 가끔 말을 못알아먹는다는 것 !!답답쓰
# -말이 이어지면 좋겠다는것!! 사람처럼 주고받고 길게 대화까지는 아직 불가능한 것 같아욤
# 발전하리라 믿습니다...★
# 그래도 가끔 뭐 말하면 같은거라도 다르게 말해줘서 재미가 있네영
# 제 바람은 나~~중에 결혼해서 신혼집에 가게 되면 거실에 제 네이버 클로바 놓고 사는거예요 ㅋㅋㅋ침실에는 네이버 클로바 미니..*_*
# 그때까지 버텨줄 수 있을지 흑흑
# 네이버클로바 솔직후기 끝!!
# 모르시는거 있으면 언제든지 물어보세요!
# 아는대로 답변해드릴게용~
#
#
# -----------------------------------
#
# url:  https://blog.naver.com/sky121400?Redirect=Log&logNo=221493275584
# real_url:  http://blog.naver.com/PostView.nhn?blogId=sky121400&logNo=221493275584&from=search&redirect=Log&widgetTypeCall=true&directAccess=false
#
# post title:  애기들이 좋아하는 ai스피커 네이버클로바
#
# publish date time:  2019-03-20 23:01:00
#
# texts:  애기들이 좋아하는 ai스피커 네이버클로바
# 작년부터 tv에 #인공지능 스피커가
# 엄청나게 출현했지만
# 나는 아직 시기상조라고 생각했다.
# 애플의 siri나 구글을 봐도
# 좋은 기능이기는하지만 잘 안써지기에
# #인공지는스피커 라고 해서 뭐 다를까?했다.
# 그러던 어느날 친한 형이
# #네이버클로바 를 샀는데
# 생각보다는 말을 잘 알아듣고
# 무엇보다 애들이 엄청 좋아했다면서
# 구매를 권유했다.
# 애들이 좋아했다는 말에 귀가 솔깃!!!
# 집에와서 #ai스피커 를 폭풍검색
# 아마존의 알렉사는 이미 해외에서는 유명했고
# 우리나라는 통신3사의 스피커
# sk의 nugu, kt의 기가지니, lg는 뭐지?하고
# 구글의 구글홈, 네이버의 #클로바 가 경쟁하고 있었다.
# 만사가 귀찮으신분은 그냥 통신 3사의 스피커로
# iot를 구축하고  조금 고민이 많으신분은
# 구글홈으로 많이 가는 것 같다.
# 그 중 네이버클로바는 통신3사 처럼 강제(?)로
# iot를 구축할 수 는 없고 #구글홈 처럼 확장성이
# 뛰어난 것은 아닌 것 같지만 우리나라에 최적화되어
# 있다는 것과 #캐릭터 모양이 큰 장점이다.
# 미니언즈도있고 샐리와 브라운이라는 이름의 스피커도 존재한다. 그리고 소형의 미니도 있고 스피커 및 배터리가 향상된 롱타입도 존재
# sk #nugu  vs  네이버 클로바
# 처음에는 클로바를 구매하려다가
# 그래도 ai스피커인데 집에서 활용을 좀 해야지
# 하는 생각에 sk #nugu캔들 을 검색해봤다.
# (집 iptv가 sk라서 nugu를 사용해야
# tv를 제어할 수 있다.)
# 와이프는 캔들이 더 이뿌고 활용도가 높을 것
# 같다고했지만 원래 목적이 애들을 위한 것이고
# 그리고 큰 차이는 클로바는 내장형 배터리가 있는데
# 누구는 배터리가 없다는...
# 즉, 클로바는
# 휴대가능하고 누구는 고정해놓고 사용해야(전기가 꽂혀있어야하는)하는 단점에 클로바로 구입하기로 결정!
# (써보고  좋으면 누구도 구입하자고하고...)
# 애들에게 어떤 모델이 좋냐고 물어보니
# 예상외로 곰이 좋다고해서 곰으로 구입!
# 몇일 뒤 택배가 오자마자 세팅!
# 큰 설명 없이도 휴대폰에 #클로바앱 만 설치하면
# 쉽게 세팅가능하다.
# 앱에서 기기를 찾고 와이파이를 검색해서 비번을 넣고
# 스피커 이름을 정해주면 끝!  쉽다 쉬워!
# 이렇게 앱에서 스피커가 보인다.
# 디바이스-호출명에 들어가면
# 스피커를 부를 수 있는 이름들이 나온다.
# 우리집은 곰돌이 브라운 스피커인데
# 부르는 이름은 샐리야 ㅋㅋㅋ
# 기기음성을 들어가보면
# 여러가지 스피커 목소리가 나오는더
# 기호에 맞게 선택하면 됨!
# 애들에게 이름을 가르쳐주고
# 사용법을 알려주니 난리다.
# 서로 자기가 가지고 다닐거라고 손에 꼭쥐고
# 도망가는 모습이란...
# 하나 더 사줄까하는 심각한 고민만 남겨놓는...
# 그런데 신기하게도 어른이 부르는 소리는
# 정말 잘 반응하는데 애들이 부르는 소리에는
# 반응을 잘 안한다. 이게 음역대로 이해하는 건지
# 아니면 애들 발음이 이상해서 안되는 건지...
# 특히, 둘째말은 더 안듣는다.ㅋㅋㅋ
# 스피커로 잘 노는 애기들
# 써보니 아직은 꼭 있어야할 필요를 못 느끼지만
# 생각보다는 괜찮은 장난감인 것 같다.
# 스피커성능도 꽤 괜찮은~~~
# 한 3~4일 지나니 애들관심은
#  스피커에서 조금씩 멀어져간다.
# 처음에는 진짜 친구를 만난것처럼
# 하루종일 "샐리야" 부르는 소리에
# 노이로제 걸릴것 같더니
# 나중에는 스피커가 어디에 있는지
# 이틀동안은 아무도 몰랐다는
# 그래도 아침에 스피커로 노래도 틀고 날씨도 묻는 등...
# 어른 장난감으로 더 좋은 것같다
# #네이버클로바휴대
# 혹시 장거리이동 등의 여행을 간다면
# 애들에게는 정말 좋을 것같다
# 노래도 듣고 이야기도 듣고
# 충전은 c타입이기에 외장배터리른
# 사용해도 되고 차량 충전을 사용해도 되고
# 와이파이는 휴대폰 핫스판을 이용해서
# 재설정하면된다. (처음에는 잘 안되더니 된다.)
# #클로바단점
# 장소를 옮길때마다 와이파이를 재설정해야한다.
# 즉, 집에서 나가 차나 캠핑장에서 사용하려면
# 다시 기기를 찾고 와이파이(핫스팟)을 찾아야하는
# 번거로움이있다.
# 더 힘든 것은 야외에서 사용하고 다시 집으로 오면
# 와이파이를 기억해서 바로 세팅되는 것이 아니라
# 재설정해서 와이파이를 찾는 등 다시 세팅해야하는
# 것이 단점인 ㅜㅜ
# 그 외에 말을 잘 못 알아들어 화나는 것은
# 다른 스피커도 비슷할듯!!
#
# -----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-ed7c4a930c84> in <module>()
#     150         print("\n-----------------------------------\n")
#     151
# --> 152         time.sleep(1)
#
# KeyboardInterrupt:

# %% [markdown]
# <br/><br/>
# # 3. 받아온 URL들을 이용하여 원하는 정보를 scraping 하고 CSV로 저장

# %%
# <Code Reference> 
# - (zilu11의 블로그 포스트) https://blog.naver.com/zilu11/221255183159

import requests
from bs4 import BeautifulSoup

import time
import datetime
import re


def get_realdata_url_naverblog(url):
    """
    네이버 블로그 포스트의 실제 데이터가 들어있는 URL을 반환해줌.
    보통 3가지 경우가 있는 것 같음.
    <지금까지 찾은 경우의 수>
    1. id='screenFrame'이 담긴 페이지에서 얻은 URL -> (base_url) + (id='mainFrame'이 담긴 페이지에서 얻은 URL) -> 실제 데이터가 담긴 URL
    2. (base_url) + (id='mainFrame'이 담긴 페이지에서 얻은 URL) -> 실제 데이터가 담긴 URL
    3. 검색해서 처음 얻은 URL이 실제 데이터가 들어가 있는 URL임
    """
    base_url = "http://blog.naver.com"
    
    r = requests.get(url)
    soup = BeautifulSoup(r.text.encode('utf-8'), 'html5lib')
    
    if soup.find(id='screenFrame'):
        # id = 'screenFrame'이 존재하는 경우 (id: screenFrame URL에서 -> id: mainFrame URL로 넘김)
        url = soup.find(id='screenFrame').get('src')
        r = requests.get(url)
        soup = BeautifulSoup(r.text.encode('utf-8'), 'html5lib')
    if soup.find(id='mainFrame'):
        # id = 'mainFrame'이 존재하는 경우 (id: mainFrame URL에서 -> id: real data URL로 넘김)
        url = base_url + soup.find(id='mainFrame').get('src')
    return url 

def get_title_naverblog(soup):
    """
    BeautifulSoup 객체를 받아서 블로그 포스트의 제목을 반환해줌.
    """
    try:
        #블로그 포스트 제목 추출
        title = soup.find('meta', attrs={'property':'og:title'}).get('content')
    except:
        title = 'NA'
    return title

def det_publish_datetime_naverblog(soup):
    """
    BeautifulSoup 객체를 받아서 블로그 포스트의 작성일을 반환해줌.
    """
    try:
        #블로그 작성일 추출
        date_tag = soup.find('span', attrs={'class':'se_publishDate pcol2'})
        if date_tag:
            # <span> Tag의 se_publishDate pcol2 클래스 이름으로 작성일 추출이 가능한 경우
            date_str = date_tag.get_text()
        
        else:
            # <p> Tag의 date fil5 pcol2 _postAddDate 클래스 이름으로 작성일 추출이 가능한 경우
            date_tag = soup.find('p', attrs={'class' : 'date fil5 pcol2 _postAddDate'})
            if date_tag:
                date_str = date_tag.get_text()  
        try:
            #블로그 작성시간이 년, 월, 일로 되어있을 경우
            publish_datetime = datetime.datetime.strptime(date_str, '%Y. %m. %d. %H:%M')
        except:
            #블로그 작성시간이 N시간 전, 방금전 이렇게 표시될 경우
            # e.g. 2019. 04. 01. 15:49 4시간 전
            publish_datetime = str(datetime.datetime.now()).split('.')[0] + ' ' + date_str
    except:
        publish_datetime = 'NA'
    return publish_datetime

def get_texts_naverblog(soup):
    """
    BeautifulSoup 객체를 받아서 블로그 포스트의 본문 내용을 반환해줌.
    """
    try:
        #블로그 본문 추출
        #보통은 <span> Tag에, id: 'SE'로 시작하는 곳에 본문이 담겨있음
        temp = soup.findAll("span", attrs= {'id': re.compile('^SE')})
        
        texts = []
        for t in temp:
            temp_text = t.get_text()
            if temp_text != '\u200b':
                texts.append(temp_text)
                    
        if not texts:
            # 블로그의 본문 텍스트가 전혀 추출되지 않았을 경우에 한번 더 시도해본다.
            # <p class="se_textarea"> 내에 존재하는 모든 본문 텍스트를 가져옴
            """
            # <p class="se_textarea"> 내의 <span> Tag에 본문이 들어가 있을 경우 
            for p in soup.findAll("p", attrs={'class': "se_textarea"}):
                for span in p.findAll("span"):
                    temp_text = span.get_text()
                    if temp_text:
                        # temp_text에 '' 이렇게 빈 문자가 들어가있는 경우를 제외해주기 위함
                        texts.append(temp_text)
            """
            for p in soup.findAll("p", attrs={'class': "se_textarea"}):
                temp_text = p.get_text()
                if temp_text:
                        # temp_text에 '' 이렇게 빈 문자가 들어가있는 경우를 제외해주기 위함
                        texts.append(temp_text)
                        
        if not texts:
            # 위의 두 가지 방법으로 본문 텍스트 추출을 시도했음에도 텍스트가 전혀 추출되지 않을 경우
            # <div> Tag 내의 id 값이 'postViewArea'이고,
            # 다시 그 태그의 내부에 존재하는 <div> Tag들 속에 존재하는 모든 본문 텍스트를 가져옴
            for div in soup.find('div', attrs={'id': 'postViewArea'}).findAll('div', attrs={'id': re.compile('^post-view')}):
            #for div in soup.find('div', attrs={'id': 'postViewArea'}).findAll('div'):
            #for div in soup.find('div', attrs={'id': 'postViewArea'}).findAll('div', 'view'):
                temp_text = div.get_text()
                if temp_text:
                        # temp_text에 '' 이렇게 빈 문자가 들어가있는 경우를 제외해주기 위함
                        texts.append(temp_text)
        
        texts = "\n".join(texts)
    except:
        texts = 'NA'
    return texts

if __name__ == '__main__':
    title_list = []
    publish_datetime_list = []
    text_list = []
    
    for i, url in enumerate(urls):    

        # 실제 데이터가 들어있는 url 추출
        real_url = get_realdata_url_naverblog(url)
        r = requests.get(real_url)
        soup = BeautifulSoup(r.text.encode("utf-8"), "html.parser")

        # 블로그 포스트 제목 추출
        title = get_title_naverblog(soup)
        title_list.append(title)
        
        # 블로그 작성일 추출
        publish_datetime = det_publish_datetime_naverblog(soup)
        publish_datetime_list.append(publish_datetime)
        
        # 블로그 텍스트 추출
        texts = get_texts_naverblog(soup)
        text_list.append(texts)
        
        print("{}.".format(i), "finished")
        time.sleep(1)
# Out:
# 0. finished
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-70-ec3d621c2dae> in <module>()
#     146
#     147         print("{}.".format(i), "finished")
# --> 148         time.sleep(1)
#
# KeyboardInterrupt:

# %%
import pandas as pd
df = pd.DataFrame(data={'title': title_list, 'publish_datetime': publish_datetime_list, 'text': text_list, 'url': urls})

# %%
df = df[['title', 'publish_datetime', 'text', 'url']]

# %%
df
# Out:
#                                                   title     publish_datetime  \
# 0                                애기들이 좋아하는 ai스피커 네이버클로바  2019-03-20 23:01:00
# 1                                  네이버 클로바 스피커 1년 사용 후기  2019-03-31 19:35:00
# 2                          네이버 클로바 사용법 맘스다이어리와 함께 육아정보를  2018-12-14 12:10:00
# 3                               네이버 클로바. 나의 두 번째 Ai 스피커  2018-12-02 14:04:00
# 4              네이버 클로바 스피커 브라운 미니언 : 오히려 부모님 선물로 추천드려요!  2018-09-09 18:18:00
# 5                                우리집AI는 네이버 클로바 미니언즈당 ★  2018-05-31 17:00:00
# 6                                     네이버 클로바 스피커 사용해보기  2019-03-19 22:57:00
# 7                          네이버 클로바, 인공지능 음성인식 비서 앱 만나보니  2017-05-27 08:50:00
# 8                      인공지능스피커 LG 유플러스 네이버 클로바 미니언즈 사용기  2018-12-04 11:39:00
# 9                          인공지능스피커 네이버클로바 설치/ 맘스다이어리 연동  2018-12-10 22:53:00
# 10                                네이버 클로바 도라에몽 스피커 장만했슈  2018-09-02 22:50:00
# 11    네이버클로바 미니언즈 케빈 :) 너무나도 귀여운 미니언즈 스피커 잘 개봉기 ! 블루...  2018-11-29 19:28:00
# 12                                    네이버 클로바프렌즈 미니 개봉기  2019-01-07 08:30:00
# 13                                네이버 클로바 미니언즈 이용 후기 리뷰  2018-10-13 11:45:00
# 14                             인공지능 스피커 네이버 클로바 만나서 방가워  2018-12-09 14:09:00
# 15                                                   NA                   NA
# 1090                 출시 한 달 네이버 AI 앱 클로바…사용자 평가는 '들쭉날쭉'  2017-06-11 10:16:00
# 1091                                      네이버 클로바 사용설명서  2018-05-28 23:09:00
# 1092                                                 NA                   NA
# 1093                  네이버 AI플랫폼 ‘클로바’, LG전자 ‘씽큐 허브’에 탑재  2017-12-01 16:30:00
# 1094                        네이버 AI 스피커 클로바 프렌즈 뮤직 무료이용권  2018-03-26 13:08:00
# 1095                                   네이버 프렌즈 클로바 구입후기  2017-11-16 16:52:00
# 1096                         클로바 유인나 과연 최신기술 발전의 시작일까?!  2018-12-08 21:28:00
# 1097                     네이버 인공지능 스피커 클로바 / 프렌즈 스피커(샐리)  2017-11-20 12:40:00
# 1098             귀여움 끝판왕 클로바 '도라에몽 스피커' :: 웨이브랑 비교해보니..  2018-09-22 13:31:00
# 1099                                            클로바 사용법  2018-06-30 12:50:00
#
#                                                    text  \
# 0     애기들이 좋아하는 ai스피커 네이버클로바\n작년부터 tv에 #인공지능 스피커가 \n...
# 1     네이버 클로바 스피커 1년 사용 후기\n네이버 클로바 1년 사용 후기를 몇 자 적어...
# 2     어제는 눈이 갑자기 많이 내려서 1주일에 한번 가는 문센을 가야하나 말아야하나고민이...
# 3     안녕하세요. 제르디난 입니다.\n올해 초 카카오 미니를 사용해보고 약간의 실망스러움...
# 4     네이버 클로바 스피커 브라운 미니언 : 오히려 부모님 선물로 추천드려요!\n요새 정...
# 5     네이버 클로바 미니언즈로 메이네 집이 스마트해졌습니다! ㅋㅋ 저희가 쓰는 인터넷이 ...
# 6     네이버 클로바 스피커 사용해보기\n저는 유행에 둔감한 사람인 것 같습니다.\n아마도...
# 7     최근 구글 어시스턴트, 아마존 알렉사, 애플 시리, 삼성전자 빅스비 등 인공지능 기...
# 8     꼬물 꼬물 귀요미 미니언즈가LG유플러스 네이버 클로바 스페셜에디션으로나왔어요~♥보기...
# 9     인공지능스피커 네이버 클로바맘스다이어리 천일스토리로 육아정보 들어요\n육아하는 엄마...
# 10    내 사랑 도라에몽이네이버 클로바 스피커로 나와서잽싸게 득템했어요 으흐흐개봉기 및 후...
# 11    이미 출시 된지는 조금 지나긴 했지만 이제야 만나보는 네이버클로바 미니언즈 블루투스...
# 12    네이버 클로바프렌즈 미니 개봉기\n바야흐로 인공지능의 시대다.\n몇년전 떠들석했던 ...
# 13    안녕하세용ㅋㅋㅋ잇님들 자취방에서 이제 티비를 신청해서얻게된 네이버 클로바 입니다  ...
# 14    12월이라고 날씨가 너무 추운데요아들 데리고 나가서 이것저것 보여주고 싶은데 또 그...
# 15                                                   NA
# 16    미니언즈 네이버 클로바 스피커 밥(BOB) 개봉기!\n네이버 클로바 스피커 미니언즈...
# 17    조만간 조만간 하다가 어느새 한달이 넘었습니다.한달을 쓴만큼 자세히 클로바 사용후기...
# 18    제가 최근에 관심있게 꽂힌 분야가바로 홈 IOT 관련 분야입니다 ㅋㅋ처음에는 통신사...
# 1071  https://blog.naver.com/eagle3056?Redirect=Log&...
# 1072  https://blog.naver.com/dbwjddk2898?Redirect=Lo...
# 1073  https://blog.naver.com/funappy?Redirect=Log&lo...
# 1074  https://blog.naver.com/lguplushg?Redirect=Log&...
# 1075  https://blog.naver.com/emoneynews?Redirect=Log...
# 1076          https://financialmagazine.tistory.com/299
# 1077  https://blog.naver.com/itwasnothing?Redirect=L...
# 1078  https://blog.naver.com/ferrari219?Redirect=Log...
# 1079  https://blog.naver.com/jin1100479?Redirect=Log...
# 1080                https://martinissue.tistory.com/674
# 1081  https://its.tistory.com/entry/%EC%9D%B8%EA%B3%...
# 1082  https://blog.naver.com/leehodo7302?Redirect=Lo...
# 1083  https://blog.naver.com/rhksgn?Redirect=Log&log...
# 1084  https://blog.naver.com/pisces009?Redirect=Log&...
# 1085  https://blog.naver.com/enenfant0824?Redirect=L...
# 1086  https://blog.naver.com/donggeon222?Redirect=Lo...
# 1087  https://blog.naver.com/0lamon0?Redirect=Log&lo...
# 1088  https://blog.naver.com/mdw1009?Redirect=Log&lo...
# 1089  https://blog.naver.com/enjd2?Redirect=Log&logN...
# 1090  https://blog.naver.com/kimhb10?Redirect=Log&lo...
# 1091  https://blog.naver.com/yuiyui116?Redirect=Log&...
# 1092                  https://newsstore.tistory.com/314
# 1093  https://blog.naver.com/applenews7?Redirect=Log...
# 1094  https://blog.naver.com/ppkk0002?Redirect=Log&l...
# 1095  https://blog.naver.com/christina499?Redirect=L...
# 1096  https://blog.naver.com/exz1duzhw?Redirect=Log&...
# 1097  https://blog.naver.com/j6712423?Redirect=Log&l...
# 1098  https://blog.naver.com/wjdgus1662?Redirect=Log...
# 1099  https://blog.naver.com/cherryyoung1?Redirect=L...
#
# [1100 rows x 4 columns]

# %%
df.to_csv('./naver_clova.csv')

# %% [markdown]
# <br/><br/><br/>
# # 예외> 본문 데이터가 중복돼서 가져와지는 것 확인하기

# %%
url = "https://blog.naver.com/mchan21/221249916216"
#url = "http://blog.naver.com/PostView.nhn?blogId=yukihana96&logNo=221389690746&from=search&redirect=Log&widgetTypeCall=true&directAccess=false"
real_url = get_realdata_url_naverblog(url)
r = requests.get(real_url)
soup = BeautifulSoup(r.text.encode("utf-8"), "html.parser")

# %%
real_url
# Out:
# 'http://blog.naver.com/PostView.nhn?blogId=mchan21&logNo=221249916216&redirect=Dlog&widgetTypeCall=true&directAccess=false'

# %%
# 블로그 텍스트 추출
texts = get_texts_naverblog(soup)
print(texts)
# Out:
#  이건 사야해! 네이버 클로바 미니언즈 스피커 개봉기슈퍼배드의 귀여운 악당! 색다른 언어와 아이같은 행동이 특징인 귀여운 미니언즈를 모르는 분들이 없을겁니다.노란색에 바지를 입고 하나 또는 2개의 눈을 가졌으며 고글을 하고 있는 미니언즈가 네이버 클로바 프렌즈와 헙업을 통해 인공지능 블루투스 스피커로 출시되었습니다.저는 평소 네이버 뮤직을 사용해서 네이버에서 선보이는 인공지능 스피커 클로바 제품에 굉장히 관심이 많았는데요.이번에 새롭게 출시된 클로바 프렌즈 미니언즈 에디션의 경우 정기결제 이용자에게 권장소비자가 134000원 제품을 59% 할인으로 55000원에 구입할 수 있어서 바로 주문했습니다.참고로 신규 가입자에게는 48% 할인가 94900원(무제한듣기 6개월 약정 제공), 선물시 45% 할인가 87000원(무제한듣기 3개월 쿠폰 포함)으로 구입이 가능합니다.​ 기존 클로바 프렌즈의 경우 라인의 인기 캐릭터인 브라운과 샐리를 형상화한 디자인으로 출시 당시 이틀만에 1만대가 모두 소진될 만큼 큰 인기를 끌었습니다.​ 저도 네이버의 AI 스피커 프렌즈를 사용하고 있는데요. 평소 좋아하는 캐릭터 브라운을 형상화한 제품으로 저는 매일 아침 라인 프렌즈를 통해 일어나고, 출근 전 날씨정보, 음악감상을 하다가 퇴근 후에는 일정 관리나 브리핑, 스포츠 경기결과 등을 물어보고 자장가를 들으며 잠을 자는 등 하루를 함께하고 있습니다.패키지 박스는 제품 디자인을 제외하면 거의 비슷한 느낌을 받을 수 있습니다.​ 패키지 박스를 열면 귀여운 네이버 클로바 미니언즈 본체를 확인할 수 있습니다. 그 밑으로 구성품들이 빼곡히 들어있습니다.​ 구성품은 심플한데요. 클로바 프렌즈 미니언즈 본체와 충전 어답터, 충전 케이블, 퀵 스타트 가이드 및 품질보증서, 발화문 가이드, 표정을 꾸밀 수 있는 미니언즈 페이스 스티커 등으로 구성되어 있습니다.​ 사용설명서에는 제품의 제원부터 특징, 연결방법, 사용방법, 사용팁 등 상세하게 설명되어 사용전 미리 읽어보면 누구나 쉽게 사용할 수 있을 것 같습니다.​ 클로바 프렌즈 미니언즈 블루투스 스피커는 2,850 mAh 내장 배터리가 탑재되어 약 4시간 연속 사용이 가능합니다.충전은 구성품으로 제공되는 어답터와 충전 USB 케이블로 가능하며, 충전 케이블은 USB Type-C 케이블이 적용되어 있습니다.​ 기존 클로바 미니언즈 제품과 차이가 있다면 미니언즈 페이스 스티커와 가이드 카드가 제공된다는 것입니다.미니언즈 페이스 스티커는 2장이 기본 제공되며, 다양한 표정을 만들어 볼 수 있습니다.​ 미니언즈 가이드 카드의 전면에는 다양한 표정샘플이 제공되고, 후면에는 미니언즈와 대화할 수 있는 방법이 소개되어 있습니다.즉, 기존 클로바 프렌즈의 대화방법 외에도 미니언즈 에디션의 경우 미니언즈와 대화할 수 있는 특화 기능을 제공하는 것을 알 수 있습니다.대화 방법은 간단한데요. "클로바, 미니언즈 불러줘"라고 말하고 이후에는 클로바를 호출하지 않고 재미있는 대화를 할 수 있습니다.​ 클로바 프렌즈 미니언즈 주요스펙제품명 : Friends Minions 모델명 : NL-S120KR 스피커 : 10W Class D Amp, 52mm Full Range, 60x45 mm Passive Radiator 사용 전원 - 정격입력 : AC 100-240V, 50-60Hz, 0.28A- 정격출력 : DC 5V, 2A 블루투스 - 지원 규격 : Bluetooth 4.2- 사용 주파수 : 2.4 GHz Wi-Fi - 지원 규격 : 802.11a/b/g/n- 사용 주파수 : : 2.4 GHz / 5 GHz 음성입력 : 2개의 내장 마이크 배터리 : 2,850 mAh 내장 배터리 오디오 재생시간 : 약 4시간제품크기 : 72 mm x 78 mm x 180 mm (미니언즈) 제품무게 : 380g ​ 클로바 프렌즈 미니언즈의 크기는 72 mm x 78 mm x 180 mm의 크기로 기존 클로바 프렌즈 제품과 거의 흡사한 크기를 자랑합니다. 무게 또한 380g으로 야외에 한 손으로 들고 다니기엔 다소 부담스러운 크기와 무게일 수 있지만 가방에 넣고 다닐 수 있는 수준으로 생각하면 될 것 같습니다.블루투스는 v4.2를 지원하며, WiFi는 2.4GHz와 5GHz를 지원해 어느 환경에서나 연결해서 사용할 수 있습니다.​ 미니언즈 캐릭터 중 케빈과 같이 막대기 처럼 길게 생겼고, 눈도 2개인 친구입니다.​ 눈동자 부분을 누르면 오디오 재생/일시정지가 가능하며, 1초 이상 길게 누르면 음성으로 바로 명령을 할 수 있습니다.​ 머리 부분에는 마치 분수대에 물이 나오듯 머리카락이 솟아 있고, 머리카락 옆으로 2개의 듀얼 마이크가 적용되어 있습니다.2개의 마이크를 통해 호출어인 "클로바"를 말하면 빠르게 바로 반응하고, 명령어를 이야기 하면 정확하게 말을 인식하고 반응합니다.​ 뒷면에는 조작부를 확인할 수 있는데요.MIC/Mute 등을 실행할 수 있는 마이크 버튼은 짧게 누르면 마이크 기능을 활성화 On / Off 설정할 수 있고, 길게 누르면 WIFI와 스마트폰 재설정이 가능합니다.블루투스 버튼을 누르면 3초 이상 누르면 페얼이 모드 진입 및 취소 등 설정이 가능합니다. 그 밑으로는 볼륨 버튼이 있어 쉽게 볼륨 설정을 할 수 있습니다.​ 밑 면에는 전원 버튼이 있는데요. 전원 버튼을 짧게 누르면 슬림 모드, 3초 이상 누르면 전원을 껏다가 켤 수 있습니다.​ 직접 미니언즈의 페이스를 변경해 보았는데요.기본 제공되는 스티커를 통해 전혀 새로운 느낌의 미니언즈 표정을 만들어 볼 수 있었습니다.​ 제가 만든 클로바 프렌즈 미니언즈의 표정입니다. 눈 빛은 살짝 멍 때리는 느낌, 입은 썩소를 날리는 느낌으로 한번 만들어 보았는데요. 구성되는 페이스 스티커를 이용하면 웃는 표정, 우는 표정, 멍때리는 표정 등 다양하게 만들어 볼 수 있을 것 같습니다.​ 클로바 프렌즈의 새로운 친구! 바나나를 좋아하는 사랑스러운 악동 미니언즈!클로바 프렌즈 미니언즈 스피커는 단순히 미니언즈를 닮은 디자인으로 귀엽기만 한 제품이 아닙니다.10W의 출력, 360도 어느 방향에서나 왜곡없는 사운드 제공, 음성으로 명령하고 제어가 가능한 제품으로 아이들도 좋아하겠지만 어른들도 좋아하기 충분해 보입니다.앞에서도 소개드렸지만 가격은 134000원이며, 출시기념 혜택가로 기존 정기결제는 5만원대, 신규가입자는 9만원대, 선물용으로는 8만원대로 구입이 가능합니다. 참고로 기존 브라인, 샐리 등 라인 프렌즈 제품들 대비 약 5천원씩 비싼 가격입니다.다음 포스팅에서는 디테일한 사용방법과 조작방법 등을 소개드리도록 하겠습니다.     ​
