# %% [markdown]
# # TF-IDF 구하기
# - 벡터화하기 전에 데이터 전처리
#    - document별 형태소 분석
#    - 미등록단어 처리
#    - 명사만 추출
#    - 불용어(stopwords) 처리
# - document별 단어로 tokenize되어 있는 것을 다시 합쳐서 각각 하나의 document로 만들기
# - 벡터화(vectorize) 하기
# - tf-idf 값 구하기

# %%
import pandas as pd

# %%
# CSV 데이터 불러오기
clova_df = pd.read_csv("../../data/sentiment/sentiment_clova.csv", index_col=0)
kakao_df = pd.read_csv("../../data/sentiment/sentiment_mini.csv", index_col=0)
geni_df = pd.read_csv("../../data/sentiment/sentiment_gigagenie.csv", index_col=0)
nugu_df = pd.read_csv("../../data/sentiment/sentiment_nugu.csv", index_col=0)

# %%
# 데이터 합치기
# 긍정 document
pos_c_text = clova_df.positive_text[clova_df.positive_text.notnull()]
pos_k_text = kakao_df.positive_text[kakao_df.positive_text.notnull()]
pos_g_text = geni_df.positive_text[geni_df.positive_text.notnull()]
pos_n_text = nugu_df.positive_text[nugu_df.positive_text.notnull()]

positive_text = [pos_c_text, pos_k_text, pos_g_text, pos_n_text]

# %%
# 데이터 합치기
# 부정 document
neg_c_text = clova_df.negative_text[clova_df.negative_text.notnull()]
neg_k_text = kakao_df.negative_text[kakao_df.negative_text.notnull()]
neg_g_text = geni_df.negative_text[geni_df.negative_text.notnull()]
neg_n_text = nugu_df.negative_text[nugu_df.negative_text.notnull()]

negative_text = [neg_c_text, neg_k_text, neg_g_text, neg_n_text]

# %%
len(positive_text), len(negative_text)
# Out:
# (4, 4)

# %% [markdown]
# # <br>
# ## 긍정 document

# %% [markdown]
# <br/><br/>
# ### POS tagging하기

# %% [markdown]
# #### 1.  Komoran 사용

# %%
komoran.pos("네콘")
# Out:
# [('네코', 'NNP'), ('ㄴ', 'JX')]

# %%
komoran.pos("척수 장애인")
# Out:
# [('척수', 'NNP'), ('장애인', 'NNP')]

# %%
komoran.pos("가스잠그미")
# Out:
# [('가스', 'NNP'), ('잠', 'NNG'), ('그', 'MM'), ('미', 'NNP')]

# %%
komoran.pos("삼행시")
# Out:
# [('삼행', 'NNG'), ('시', 'XSN')]

# %%
komoran.pos("교동제비집")
# Out:
# [('교동', 'NNP'), ('제비집', 'NNG')]

# %%
komoran.pos("교동스튜디오")
# Out:
# [('교동', 'NNP'), ('스튜디오', 'NNP')]

# %%
komoran.pos("올레tv스카이라이프")
# Out:
# [('올레', 'NNP'), ('tv', 'SL'), ('스카이', 'NNP'), ('라이프', 'NNP')]

# %%
from konlpy.tag import Komoran

# %%
komoran = Komoran(userdic='./unregistered.txt')

# %%
import re

# 명사와 외래어만 뽑아내기위한 정규표현식
p = re.compile('NN.*|SL')

# %% [markdown]
# results = []
# for i, brand_text in enumerate(positive_text):
#     pos_tagging_list = list(map(komoran.pos, brand_text))
#     print("pos tagging -", i)
#
#     docs = []
#     for doc in pos_tagging_list:
#         want_words = []
#         for word, pos in doc:
#             if p.match(pos):
#                 want_words.append(word)
#         docs.append(want_words)
#     print("noun extract -", i)
#
#     results.append(sum(docs, []))
#     print("finish -", i)

# %%
results = []
for i, brand_text in enumerate(positive_text):
    pos_tagging_list = list(map(komoran.pos, brand_text))
    print("pos tagging -", i)

    docs = []
    for doc in pos_tagging_list:
        want_words = [word for word, pos in doc if p.match(pos)]         
        docs.append(want_words)
    print("noun extract -", i)
    
    results.append(sum(docs, []))
    print("finish -", i)

# %% [markdown]
# ### pickle로 일단 저장

# %%
import pickle
#pickle.dump(results, open('tfidf_pos_list.pickle', "wb"))

# %%
load_result = pickle.load(open('tfidf_pos_list.pickle', "rb"))
results = load_result

# %% [markdown]
# <br/><br/>
# ### stopword 제거

# %%
stopwords = [line.strip() for line in open('./stopwordsKor.txt', encoding='utf-8')]

# %% [markdown]
# final_docs = []
# for doc in results:
#     unique_NN_words = set(doc)
#     final_NN_words = doc
#
#     for word in unique_NN_words:
#         if word in stopwords:
#             while word in final_NN_words: final_NN_words.remove(word)
#     final_docs.append(final_NN_words)

# %% [markdown]
# from tqdm import tqdm_notebook
# stopword_dict = {}
# for s_word in stopwords:
#     stopword_dict[s_word] = 1
#
# final_docs = []
# for i, doc in enumerate(results):
#     unique_NN_words = set(doc)
#     final_NN_words = doc
#
#     for word in tqdm_notebook(unique_NN_words):
#         if stopword_dict.get(word):
#             while True:
#                 try:
#                     final_NN_words.remove(word)
#                 except ValueError:
#                     break
#     print("finish -", i)

# %%
from tqdm import tqdm_notebook
stopword_dict = {}
for s_word in stopwords:
    stopword_dict[s_word] = 1

final_docs = []
for i, doc in enumerate(results):
    unique_NN_words = set(doc)
    final_NN_words = doc
    
    for word in tqdm_notebook(unique_NN_words):
        if stopword_dict.get(word):
            final_NN_words = list(filter(lambda x: x!= word, final_NN_words))
    final_docs.append(final_NN_words)
    print("finish -", i)
# Out:
# Widget Javascript not detected.  It may not be installed or enabled properly.
# finish - 0
# Widget Javascript not detected.  It may not be installed or enabled properly.
# finish - 1
# Widget Javascript not detected.  It may not be installed or enabled properly.
# finish - 2
# Widget Javascript not detected.  It may not be installed or enabled properly.
# finish - 3

# %% [markdown]
# <br/><br/>
# ### document별 단어들을 각각의 document로 바꾸기

# %%
documents = []
for doc_words in final_docs:
    document = " ".join(doc_words)
    documents.append(document)

# %%
documents[0][:200]
# Out:
# '직장인 김 모 미국 출장 당시 인공지능 AI 스피커 구글 홈 사 아내 아들 영어 공부 부탁 김 영어 유치원 아들 구글 홈 대화 학부모 조언 스피커 정보 확인 검색 음악 알람 아이 흥미 영어 사용 대학 강모 네이버 스피커 웨이브 이벤트 선물 내년 교환 학생 계획 강 웨이브 영어 회화 기능 활용 거란 강 네이버 번역 파파 활용 기본 회화 습득 활용 웨이브 대화'

# %% [markdown]
# <br/><br/>
# ### 벡터화 하기

# %%
from sklearn.feature_extraction.text import CountVectorizer     # 벡터 수 카운트 할 때

# %%
cv=CountVectorizer(max_df=0.85, max_features=10000)     
# 문서 집합에서 단어 토큰을 생성하고 각 단어의 수를 세어 BOW(Bag Of Words) 인코딩한 벡터를 만든다.
# max_df=0.85란 말은 documents들에서 85%이상 나타나는 토큰(단어)를 무시하라는 것, 
# max_df=25란 말은 documents들에서 25번 이상 나타나는 토큰(단어)를 무시하라는 것,
# maximum 단어의 개수를 1만개로 정함 - 빈도수가 높은 단어 순으로 1만개를 자름(메모리 에러 안나려고)
# min_df=1, ngram_range=(1,1) 등은 default 값임  

word_count_vector=cv.fit_transform(documents)      # vectorize된 word_count_vector
feature_names=cv.get_feature_names()

# %%
len(cv.vocabulary_)      # 위에서 max_features를 10000으로 주었지만 단어 수가 그 이하였음
# Out:
# 10000

# %%
cv.

# %%
cv.vocabulary_
# Out:
# {'김진형': 3741,
#  'airi': 65,
#  '코리': 8843,
#  '하현': 9485,
#  '팬서': 9218,
#  '스트레인지': 6286,
#  'uiot': 2627,
#  '원혁': 7242,
#  'aiot': 61,
#  '수요처': 6165,
#  '사업단': 5641,
#  '최준': 8672,
#  'luxmen': 1524,
#  'personalizedtext': 1913,
#  '임미숙': 7725,
#  '숙달': 6198,
#  'ups': 2656,
#  'nlskrl': 1745,
#  '형석': 9767,
#  '투자비': 9088,
#  '패트릭': 9214,
#  '피력': 9401,
#  '십수': 6480,
#  '상층부': 5789,
#  '불평등': 5484,
#  '플리커': 9393,
#  'items': 1267,
#  '중략': 8299,
#  'inside': 1223,
#  '하버드': 9452,
#  '오즈': 7041,
#  '이한': 7613,
#  'mashine': 1558,
#  '뒷심': 4368,
#  'wake': 2763,
#  '명사': 4773,
#  '뇌리': 3976,
#  '간밤': 2984,
#  '박흥순': 5078,
#  '김경민': 3647,
#  '여세': 6859,
#  '국제가전박람회': 3465,
#  '문지현': 4912,
#  '김기진': 3654,
#  '동승': 4304,
#  '김승미': 3688,
#  '쉬리': 6228,
#  '선희': 5924,
#  'weconomy': 2781,
#  '마이크로소프트웨어': 4637,
#  '셰어': 6027,
#  '에디터톤': 6800,
#  'marathon': 1548,
#  '분장': 5459,
#  '태평로': 9012,
#  'makers': 1534,
#  '한정수': 9596,
#  '라지브': 4447,
#  '콤비네이션': 8873,
#  '특파원': 9130,
#  '신현규': 6434,
#  '희영': 9987,
#  '특전': 9126,
#  '홍익대': 9838,
#  'siemens': 2266,
#  '진원지': 8423,
#  '편재': 9259,
#  '함의': 9625,
#  '김수연': 3685,
#  '도요타자동차': 4242,
#  'ask': 150,
#  '이솝': 7526,
#  '우화': 7187,
#  '강정수': 3040,
#  '어린': 6759,
#  '실린더': 6443,
#  '오자': 7033,
#  '단답': 4052,
#  '송지호': 6109,
#  '남궁훈': 3836,
#  '난적': 3830,
#  '해나': 9641,
#  '면담': 4757,
#  '허심탄회': 9700,
#  '냉정': 3898,
#  '금지법': 3567,
#  '특정시': 9127,
#  '보더': 5305,
#  '모스트': 4809,
#  '생업': 5816,
#  '테크니컬': 9029,
#  '인도네시아어': 7641,
#  '편견': 9255,
#  '명암': 4776,
#  '도봉구': 4234,
#  '난제': 3831,
#  '소동': 6037,
#  '고민거리': 3229,
#  '창사': 8507,
#  'skcc': 2284,
#  '낭패': 3870,
#  '별일': 5288,
#  '강수량': 3030,
#  '사심': 5639,
#  'iu': 1272,
#  '이경은': 7456,
#  '몬테': 4838,
#  '불여일견': 5480,
#  'csmo': 552,
#  '최현정': 8676,
#  '응답하라': 7424,
#  '화구': 9851,
#  'he': 1088,
#  'she': 2253,
#  '화성시': 9864,
#  '아유미': 6554,
#  '이태원역': 7606,
#  '이병헌': 7494,
#  '개천절': 3068,
#  '맹하': 4713,
#  'fcfuture': 837,
#  'converged': 501,
#  '그르노블': 3524,
#  'gio': 992,
#  '마그나': 4593,
#  '동맹군': 4285,
#  '이경전': 7457,
#  '정의석': 8037,
#  '특허분쟁': 9131,
#  'cvpr': 565,
#  'builtin': 336,
#  '작업장': 7827,
#  '능지': 4008,
#  'deview': 620,
#  'extensions': 815,
#  'cic': 414,
#  '다카라토미': 4045,
#  '후반부': 9938,
#  '석상': 5888,
#  '비탈길': 5568,
#  '스케이트보드': 6271,
#  '감속': 3004,
#  '기울기': 3616,
#  '이지현': 7595,
#  'vinclu': 2712,
#  'whale': 2791,
#  '정상급': 8017,
#  '여가수': 6852,
#  '하정우': 9475,
#  '김찬': 3742,
#  '경호': 3181,
#  'clair': 427,
#  'feature': 841,
#  'matrix': 1565,
#  '가을밤': 2961,
#  '클레어': 8925,
#  'extraction': 818,
#  'emotion': 749,
#  '볼루': 5362,
#  '홈사': 9825,
#  '앰비언트': 6700,
#  '언어학': 6778,
#  '생활관': 5822,
#  '한화자산운용': 9611,
#  '맨해튼': 4707,
#  '김수미': 3684,
#  'sally': 2160,
#  '영동대로': 6930,
#  '협회장': 9765,
#  '협의체': 9762,
#  '진기': 8409,
#  '기진': 3620,
#  '전환율': 7983,
#  '분초': 5461,
#  '무더기': 4857,
#  'cpnd': 528,
#  '클립스': 8935,
#  '이규섭': 7462,
#  '박지성': 5069,
#  '맨체스터': 4705,
#  '앰버': 6699,
#  '어린이재단': 6760,
#  '와이디온라인': 7080,
#  '순서도': 6206,
#  '사육': 5650,
#  '아시안': 6545,
#  '이선': 7520,
#  '코렐': 8838,
#  '헤라': 9716,
#  '제너': 8077,
#  '넵튠': 3918,
#  '음양사': 7420,
#  '기묘한': 3593,
#  'sr': 2364,
#  '등불': 4388,
#  '던전': 4197,
#  '벡스코': 5252,
#  '알약': 6640,
#  'trojan': 2567,
#  'ransom': 2056,
#  '격전장': 3127,
#  '은혜': 7405,
#  '인내심': 7640,
#  '장래': 7857,
#  '체카': 8623,
#  '선양': 5916,
#  '해단식': 9642,
#  '박상진': 5045,
#  '환골탈태': 9885,
#  'aitems': 68,
#  '친분': 8752,
#  '뉴욕타임스': 4003,
#  'foodtech': 897,
#  '트러스트': 9101,
#  '격언': 3125,
#  '선봉장': 5907,
#  '직책': 8404,
#  'aiaas': 54,
#  '회동': 9915,
#  '시화': 6362,
#  '윤필': 7377,
#  '권도경': 3496,
#  '유일무이': 7325,
#  '김건우': 3644,
#  '혜진': 9775,
#  '라만': 4432,
#  '명문장': 4771,
#  '영미': 6932,
#  '어법': 6764,
#  '집구석': 8449,
#  '에픽하이': 6838,
#  '첫돌': 8585,
#  '신승훈': 6408,
#  '로버트': 4492,
#  '허구': 9696,
#  '차치': 8481,
#  '공공복지': 3270,
#  '융자': 7386,
#  'dnn': 655,
#  '연구원장': 6885,
#  '길재': 3642,
#  '익살': 7630,
#  '물통': 4932,
#  '박세정': 5051,
#  '리멤버': 4552,
#  '붉은빛': 5487,
#  'coral': 509,
#  '개인차': 3064,
#  '작은': 7828,
#  '직선거리': 8393,
#  '중음': 8323,
#  '눈동자': 3988,
#  '심경': 6462,
#  'frame': 918,
#  '백지영': 5194,
#  'citylife': 421,
#  '사장단': 5660,
#  '포수': 9290,
#  '사오정': 5644,
#  '체급': 8612,
#  '라이온': 4443,
#  '직육면체': 8400,
#  '강석호': 3028,
#  'ilc': 1192,
#  'espz': 781,
#  '최현': 8675,
#  '라쿠텐': 4449,
#  '유키': 7345,
#  '가창력': 2970,
#  '시치미': 6353,
#  '이재연': 7576,
#  '타나': 8948,
#  'plug': 1950,
#  '찹쌀떡': 8501,
#  '하마': 9449,
#  '블랙리스트': 5519,
#  'doc': 657,
#  '하도급': 9444,
#  '과징금': 3301,
#  '윤활유': 7381,
#  '태현': 9013,
#  'pool': 1963,
#  '김현철': 3768,
#  '일산화탄소': 7706,
#  '알코올': 6642,
#  '이영호': 7546,
#  '축사': 8695,
#  '김용수': 3703,
#  '사무총장': 5624,
#  '정태': 8060,
#  'living': 1484,
#  '김규식': 3652,
#  '동철': 4328,
#  '토다이': 9042,
#  '김창현': 3744,
#  '서진욱': 5870,
#  '이석영': 7517,
#  'programming': 1998,
#  'sjw': 2282,
#  '조깅': 8136,
#  'mars': 1556,
#  '태국어': 8991,
#  'buds': 334,
#  'dash': 579,
#  '김어준': 3693,
#  '출국장': 8699,
#  '이은정': 7564,
#  '별내역': 5282,
#  '아이파크': 6575,
#  '상규': 5755,
#  '문호': 4918,
#  '윤경': 7365,
#  '신동': 6388,
#  'lg상사': 1460,
#  '구본무': 3424,
#  '마곡사': 4591,
#  '기술원': 3602,
#  '크리스털': 8914,
#  '백상': 5183,
#  '혜성': 9773,
#  '진규': 8408,
#  '진서': 8413,
#  '전보': 7952,
#  '이승': 7533,
#  '김석기': 3676,
#  '김필': 3758,
#  '숙희': 6201,
#  '장영': 7880,
#  '김준': 3733,
#  '유석': 7310,
#  '박성': 5047,
#  'lg하우시스': 1461,
#  '민화': 4997,
#  '지투알': 8379,
#  '원준': 7238,
#  '소우': 6053,
#  '크로스오버': 8907,
#  '배타': 5171,
#  '합동': 9628,
#  '김인': 3709,
#  '희석': 9986,
#  '국무총리': 3456,
#  '강윤': 3036,
#  '임아영': 7730,
#  '시바': 6333,
#  '브라마': 5495,
#  '번들': 5214,
#  '이인희': 7569,
#  '나폴레옹': 3809,
#  '툴롱': 9089,
#  '포위전': 9298,
#  '코르시카': 8842,
#  '전향': 7980,
#  '관광업': 3307,
#  '자크': 7816,
#  '다비드': 4023,
#  '알프스': 6648,
#  '알렉산더': 6633,
#  '한니발': 9556,
#  '영웅들': 6941,
#  '전황': 7985,
#  '함대': 9620,
#  '왕당파': 7096,
#  '장교': 7845,
#  '수송': 6151,
#  '대포': 4156,
#  '세티': 6018,
#  '댓가': 4178,
#  '요충지': 7137,
#  '사형': 5676,
#  '중위': 8321,
#  '자장면': 7811,
#  '김영욱': 3698,
#  '단박': 4056,
#  '축약': 8697,
#  '대치동': 4153,
#  '데미안': 4205,
#  '접근법': 7996,
#  'dsf': 688,
#  '태아': 8999,
#  '원규': 7217,
#  '책무': 8536,
#  '역외': 6879,
#  '게로': 3110,
#  '건호': 3098,
#  '이합집산': 7614,
#  '분발': 5455,
#  '박재형': 5059,
#  'partnership': 1891,
#  'answering': 114,
#  'nsml': 1772,
#  '부등': 5393,
#  '스타터킷': 6278,
#  '크레인': 8901,
#  '김문성': 3663,
#  '박정수': 5063,
#  '탑승객': 8986,
#  '송인': 6105,
#  'jebo': 1288,
#  '김상조': 3674,
#  '제재': 8113,
#  '개선책': 3055,
#  '불똥': 5471,
#  '설선': 5929,
#  '행위자': 9687,
#  '히든카드': 9991,
#  '삼성벤처투자': 5722,
#  '전직': 7973,
#  '충당': 8709,
#  '전환사채': 7982,
#  '김정우': 3715,
#  'think': 2498,
#  '세상의': 5999,
#  '모든': 4796,
#  '한창희': 9602,
#  '희종': 9989,
#  '박성우': 5048,
#  '블루홀': 5529,
#  '장병규': 7867,
#  '일갈': 7688,
#  'feel': 845,
#  '영화배우': 6958,
#  '최재필': 8669,
#  '이정호': 7584,
#  '편제': 9260,
#  '제천': 8119,
#  'isms': 1262,
#  '조달청': 8137,
#  '한중': 9598,
#  'images': 1195,
#  '라데온': 4430,
#  '컴스코어': 8813,
#  '인호': 7685,
#  '블링크': 5531,
#  '초인종': 8641,
#  '이해관계자': 7616,
#  '라이스': 4442,
#  'fwa': 945,
#  'gpp': 1019,
#  'nugusk': 1793,
#  'geniekt': 973,
#  '한국공학한림원': 9507,
#  '김정희': 3719,
#  '지식in': 8364,
#  '한국공항공사': 9509,
#  '초대권': 8630,
#  '몸동작': 4844,
#  '하바': 9451,
#  '그랜드체이스': 3518,
#  '앙상블': 6668,
#  '해시': 9654,
#  '양립': 6725,
#  '수여식': 6159,
#  '휴게실': 9962,
#  '안식': 6619,
#  'entertain': 763,
#  '이석우': 7518,
#  '정령': 8007,
#  '페어리': 9240,
#  '아이린': 6560,
#  'npc': 1764,
#  '루돌프': 4526,
#  '머리띠': 4718,
#  '수필': 6187,
#  '현석': 9749,
#  '농촌': 3973,
#  '당선작': 4100,
#  '원더': 7220,
#  '케플러': 8826,
#  '트레이스': 9104,
#  '배지': 5169,
#  '계측': 3197,
#  '모네': 4794,
#  'newsai': 1725,
#  '밑바탕': 5006,
#  '조성진': 8152,
#  'sho': 2256,
#  '보직': 5329,
#  '사령탑': 5615,
#  'disco': 641,
#  '커머스': 8800,
#  '글쇠': 3547,
#  '맞춤법': 4685,
#  '음란': 7413,
#  'foldable': 889,
#  '하키': 9480,
#  '다이내믹스': 4035,
#  '아틀라스': 6593,
#  'atlas': 166,
#  '단잠': 4066,
#  '박나래': 5036,
#  '우르': 7161,
#  'kisti': 1361,
#  '이종민': 7587,
#  'yeslin': 2873,
#  '홍윤정': 9837,
#  '이경수': 7454,
#  '윤희': 7383,
#  '서영호': 5856,
#  '획정': 9923,
#  '철광석': 8573,
#  '구용': 3427,
#  '이창': 7598,
#  '혜원': 9774,
#  '주문자': 8246,
#  '개안': 3058,
#  'page': 1876,
#  '글꼴': 3540,
#  '외적': 7117,
#  'brich': 312,
#  '격변기': 3123,
#  '카리': 8765,
#  '펠리오': 9250,
#  '이동식': 7471,
#  '수지구': 6178,
#  '죽전동': 8271,
#  '해령': 9645,
#  '등식': 4390,
#  '등무': 4387,
#  '호서대': 9787,
#  'around': 146,
#  'aircart': 63,
#  '오동환': 6990,
#  '외래어': 7112,
#  'unmanned': 2648,
#  'automated': 178,
#  '취급고': 8716,
#  'commerce': 463,
#  '쇼핑카트': 6119,
#  '서빙': 5848,
#  '창립자': 8506,
#  '대담': 4117,
#  '하수': 9455,
#  '회귀': 9913,
#  '국제기구': 3466,
#  '부익부': 5417,
#  '송년': 6098,
#  '얼론': 6781,
#  '만달레이': 4656,
#  '허프': 9704,
#  '총책임자': 8650,
#  '상대편': 5760,
#  '이항': 7615,
#  'las': 1422,
#  'vegas': 2683,
#  '소방대원': 6042,
#  '라이카': 4444,
#  '브리프': 5514,
#  '안감': 6604,
#  '성용': 5964,
#  '이상우': 7511,
#  '차별화': 8475,
#  '강호': 3043,
#  '바통': 5034,
#  'artik': 148,
#  'wear': 2777,
#  '파고다교육그룹': 9153,
#  '김철': 3747,
#  '레미제라블': 4467,
#  '진척': 8434,
#  '사임': 5658,
#  '동아시아': 4307,
#  '실익': 6454,
#  '균열': 3512,
#  '하의': 9462,
#  'iocare': 1238,
#  '진혁': 8441,
#  'nxp': 1803,
#  '꼴찌': 3783,
#  '방송업': 5131,
#  'cj그룹': 423,
#  'mso': 1666,
#  '김기환': 3656,
#  '김용': 3700,
#  '김진욱': 3740,
#  'navi': 1700,
#  'iocareapmse': 1241,
#  'iocareapd': 1240,
#  '조문': 8141,
#  '중후반': 8333,
#  '오스트리아': 7027,
#  '디톡스': 4409,
#  '미나리': 4939,
#  '휴롬': 9964,
#  '원액': 7228,
#  '도라지': 4223,
#  '오미자': 7014,
#  '효능': 9929,
#  '아이클레보': 6571,
#  'bldc': 275,
#  'mapping': 1545,
#  '쇼트': 6117,
#  '석암': 5889,
#  'joonxnugu': 1310,
#  'tvx': 2593,
#  '엄정화': 6784,
#  '크로': 8903,
#  '애트모스': 6687,
#  '토털': 9055,
#  'btvnugu': 330,
#  'gu': 1048,
#  '퇴계로': 9076,
#  '실탄': 6458,
#  '최인혁': 8668,
#  'voddb': 2738,
#  '타임머신': 8957,
#  '김창훈': 3745,
#  '간극': 2982,
#  '고가도': 3199,
#  '실마리': 6444,
#  'cp': 526,
#  'yuni': 2888,
#  '보릿고개': 5311,
#  'kt스포츠': 1407,
#  'blaster': 273,
#  '차코': 8482,
#  'cgo': 391,
#  '미와': 4975,
#  '미도': 4944,
#  '강미': 3020,
#  '스쿠터': 6274,
#  '그린팩토리': 3526,
#  '쇼트트랙': 6118,
#  '이상화': 7514,
#  '선수촌': 5913,
#  '아이스하키': 6565,
#  'gai': 948,
#  '추진단': 8688,
#  '화씨': 9866,
#  '운동선수': 7190,
#  '스케이팅': 6272,
#  '포장마차': 9301,
#  '현지인': 9755,
#  '테라로사': 9027,
#  '한강로': 9497,
#  '언감생심': 6775,
#  '용산사': 7146,
#  '용품점': 7153,
#  '질문자': 8444,
#  '호화': 9808,
#  '해피빈': 9667,
#  '교생': 3381,
#  '박민수': 5041,
#  '콘티': 8865,
#  '추리': 8683,
#  '아마추어': 6534,
#  '화이트데이': 9871,
#  '발작': 5110,
#  '에오스': 6818,
#  '휘트니': 9958,
#  '에밀': 6806,
#  'gen': 969,
#  '미디어오늘': 4947,
#  '지구촌': 8346,
#  '주호': 8268,
#  '채도': 8522,
#  '극성': 3533,
#  '집진': 8453,
#  '마이크로미터': 4635,
#  '이산화질소': 7505,
#  '대섭': 4133,
#  '오염도': 7030,
#  '사친': 5671,
#  '강박': 3021,
#  '진면목': 8412,
#  '고마워요': 3226,
#  '롯데케미칼': 4521,
#  '액면': 6691,
#  '입국': 7748,
#  '송원산업': 6104,
#  '포스코강판': 9291,
#  '두산인프라코어': 4347,
#  '천주로': 8564,
#  '배급사': 5146,
#  '덕산': 4188,
#  'simpac': 2271,
#  '첼로': 8626,
#  'lighting': 1466,
#  'satellite': 2169,
#  'lm': 1489,
#  '루멘': 4527,
#  '적색': 7924,
#  '플로어': 9391,
#  '설리': 5926,
#  '집무실': 8450,
#  '벙어리': 5234,
#  '소회': 6070,
#  '한통': 9606,
#  'ugc': 2623,
#  '외환은행': 7121,
#  '문어체': 4903,
#  '김광현': 3651,
#  '당연시': 4102,
#  '하객': 9429,
#  '인큐베이터': 7672,
#  '인터콘티넨탈': 7677,
#  '테헤란로': 9032,
#  '인터컨티넨탈': 7676,
#  '일용': 7712,
#  '불식': 5478,
#  '봄나들이': 5368,
#  '경향하우징페어': 3179,
#  'kisdi': 1359,
#  '참관': 8494,
#  'kjy': 1364,
#  'coal': 448,
#  'care': 363,
#  '이해선': 7617,
#  '박소연': 5052,
#  '클로즈': 8927,
#  '반젤리스': 5097,
#  '부부장': 5398,
#  '답방': 4088,
#  '정상회담': 8020,
#  '후손': 9942,
#  '선언문': 5917,
#  '구속': 3426,
#  '단원': 4063,
#  '연극': 6886,
#  '성폭력': 5973,
#  '슈퍼카': 6246,
#  '조수용': 8155,
#  '예탁': 6983,
#  'gdr': 966,
#  '번역가': 5216,
#  '바벨': 5019,
#  '재채기': 7910,
#  '염기서열': 6922,
#  '말뭉치': 4671,
#  '빈축': 5583,
#  '법적': 5230,
#  '농구': 3957,
#  '자금력': 7770,
#  '사외이사': 5646,
#  '건영': 3095,
#  '강변북로': 3024,
#  '치기': 8731,
#  'cloi': 435,
#  'leader': 1437,
#  '현영': 9751,
#  '최정': 8670,
#  '조현영': 8182,
#  '일임': 7714,
#  '홀몸': 9821,
#  'csr': 553,
#  '열심': 6917,
#  '성종': 5970,
#  '결별': 3133,
#  '우투': 7184,
#  '측량': 8726,
#  '이동인': 7473,
#  '데브': 4207,
#  'dev': 615,
#  '첫눈': 8584,
#  '유니버스': 7293,
#  '락스': 4453,
#  '토익': 9053,
#  '명문대': 4770,
#  '개소식': 3056,
#  'qs': 2042,
#  '대위': 4139,
#  '김성훈': 3683,
#  '양철': 6745,
#  '대응책': 4141,
#  '노인과': 3937,
#  '김성': 3678,
#  '이경우': 7455,
#  '비전동': 5558,
#  '인턴십': 7678,
#  'recommendation': 2079,
#  'dialog': 627,
#  'mobility': 1621,
#  '해대': 9643,
#  'msc': 1664,
#  '조종사': 8174,
#  '악당': 6599,
#  '마크로': 4645,
#  '네이션': 3911,
#  '슈퍼배드': 6242,
#  '피부색': 9404,
#  '파이오니아': 9171,
#  'holobox': 1117,
#  '인원수': 7659,
#  '스루': 6253,
#  '김희': 3773,
#  '정희': 8069,
#  '척도': 8547,
#  '동태': 4332,
#  '연단': 6889,
#  '의료인': 7435,
#  'airspace': 66,
#  'present': 1984,
#  '채집': 8531,
#  '다이스': 4038,
#  '클립보드': 8934,
#  'award': 192,
#  '심미': 6467,
#  '스팅어': 6289,
#  'laser': 1423,
#  '최고상': 8653,
#  '본상': 5358,
#  '이정환': 7585,
#  '레드닷': 4464,
#  '어워드': 6767,
#  'winner': 2807,
#  '컬럼': 8811,
#  '병실': 5297,
#  '보훈': 5339,
#  '심리치료': 6466,
#  '병동': 5293,
#  '복약': 5345,
#  'occ': 1812,
#  '송가': 6096,
#  '박민영': 5042,
#  '수신인': 6154,
#  '구출': 3440,
#  'cirp': 418,
#  '권경원': 3494,
#  '양재천': 6738,
#  '찬우': 8489,
#  'lifestyle': 1465,
#  '포스트잇': 9296,
#  'npb': 1763,
#  'dau': 583,
#  '동작구': 4325,
#  '배달업': 5149,
#  '요도': 7123,
#  '난관': 3823,
#  '애비뉴': 6683,
#  '과학기술대학교': 3303,
#  'laboratory': 1414,
#  '환금': 9886,
#  '인피': 7681,
#  '레드카펫': 4465,
#  '위도': 7262,
#  'thek': 2492,
#  '링키지': 4585,
#  '수어': 6158,
#  '수화': 6195,
#  '길드': 3639,
#  '이종석': 7589,
#  '첫사랑': 8586,
#  '요식': 7129,
#  '슈퍼셀': 6244,
#  'stage': 2375,
#  '연세로': 6898,
#  '암초': 6657,
#  '미풍': 4981,
#  '일라이': 7696,
#  '샬롯': 5828,
#  '대화체': 4173,
#  '본궤도': 5353,
#  '유후': 7357,
#  '힘찬': 9999,
#  '자임': 7808,
#  '비콘': 5565,
#  '곤두': 3259,
#  '후광': 9937,
#  '거래선': 3078,
#  'gallery': 951,
#  'festival': 849,
#  '동아프리카': 4310,
#  '자형': 7821,
#  '도포': 4247,
#  '무표정': 4886,
#  '경멸': 3152,
#  '놀람': 3953,
#  'culture': 556,
#  '세르반테스': 5989,
#  '브로드웨이': 5506,
#  '반세기': 5087,
#  '돈키호테': 4263,
#  'info': 1213,
#  'limited': 1470,
#  '성룡': 5948,
#  '세계관': 5978,
#  '윈터': 7279,
#  '가디언즈': 2933,
#  '곰돌이': 3266,
#  '은희': 7406,
#  '삽화가': 5745,
#  '만화가': 4664,
#  '아키라': 6589,
#  '피콜로': 9415,
#  '평론': 9267,
#  '작당': 7823,
#  '김민정': 3668,
#  '수의': 6168,
#  '야시장': 6708,
#  '비축': 5563,
#  '한국민속촌': 9516,
#  '사또': 5609,
#  '서당': 5833,
#  '사자성': 5659,
#  '한영일': 9581,
#  '문화원': 4920,
#  '배웅': 5167,
#  '견지': 3130,
#  '아티스츠': 6595,
#  '정연승': 8028,
#  '반절': 5096,
#  '컵케이크': 8815,
#  '박형수': 5076,
#  'volte': 2741,
#  '오존': 7037,
#  '고갱': 3204,
#  '예정자': 6978,
#  '마법사': 4607,
#  '교환소': 3404,
#  '모험가': 4819,
#  '줌인터넷': 8280,
#  'venture': 2690,
#  '구주': 3436,
#  '워터마크': 7212,
#  '그루트': 3523,
#  '관의': 3322,
#  '납세자': 3867,
#  '유해무': 7354,
#  '중개업': 8282,
#  '불청객': 5482,
#  '목돈': 4824,
#  '위약금': 7268,
#  '청청': 8603,
#  'dynamics': 707,
#  '흡입구': 9977,
#  '교원그룹': 3387,
#  '교원': 3386,
#  '클리닝': 8930,
#  '해약': 9657,
#  '운영자': 7193,
#  '기소': 3600,
#  'ogq': 1823,
#  '본명': 5356,
#  '키오': 8937,
#  '캣츠': 8798,
#  '도레미': 4224,
#  '제작소': 8112,
#  '크로키': 8910,
#  '여주인공': 6869,
#  '농수': 3964,
#  '공산품': 3285,
#  '콩순이': 8875,
#  '윤선': 7368,
#  '꽃집': 3789,
#  '와해': 7087,
#  '태우': 9005,
#  '김주완': 3729,
#  'fraud': 922,
#  '밥집': 5120,
#  '대학가': 4160,
#  '스승': 6258,
#  '카네이션': 8761,
#  '사인회': 5657,
#  '대동단결': 4119,
#  '출생일': 8703,
#  '자바스크립트': 7789,
#  '일사천리': 7705,
#  'g메일': 1053,
#  '공공사업': 3271,
#  '하노버': 9439,
#  '찬동': 8486,
#  '서동': 5835,
#  '혈전': 9758,
#  '김은지': 3707,
#  '고독감': 3213,
#  '고독': 3212,
#  '고독사': 3214,
#  '웨비': 7250,
#  'allshowtv': 85,
#  '밤하늘': 5117,
#  '암실': 6655,
#  '휘도': 9956,
#  '햇볕': 9679,
#  '공명': 3281,
#  'dts': 695,
#  '유정': 7329,
#  '삼다수': 5718,
#  '지대한': 8348,
#  'nit': 1741,
#  'dtsx': 696,
#  'dios': 635,
#  '변상': 5268,
#  '악동': 6600,
#  '심형탁': 6477,
#  '판매대': 9187,
#  '책가방': 8534,
#  '잠실점': 7836,
#  '사진기': 5667,
#  '홀린': 9820,
#  '마동석': 4598,
#  '닦이': 4049,
#  '실용주의': 6453,
#  '캔디': 8792,
#  '석촌': 5892,
#  '서울까지': 5858,
#  '순례': 6203,
#  '정복': 8013,
#  '포켓몬스터': 9306,
#  '카나페': 8760,
#  '솜사탕': 6094,
#  ...}

# %% [markdown]
# <br/><br/>
# ### TF-IDF 적용
# - TF * IDF는 특정 문서 내에서 단어 빈도가 높을수록, 전체 문서들에는 그 단어를 포함한 문서가 적을수록 TF * IDF값이 높아지는 특징이 있다.
# - 이러한 특징을 이용해서 모든 문서에 나타나는 흔한 단어들을 걸러내며, 특정 단어가 가지는 중요도를 측정하는 데 사용된다.
# - 한마디로 TF * IDF 값은 특정 단어가 가지는 중요도!
# - TF(Term Frequency): 단어 빈도
#    - 해당 문서에서 단어가 나타나는 빈도수
#    - 문서의 길이가 길면 해당 단어의 실제 중요도와는 상관없이 단어의 빈도수는 증가될 확률이 높다.
#    - 위의 문제를 해결하기 위해 다음과 같이 표준화 -> (문서에서 단어가 나타나는 빈도수) / (모든 단어가 나타나는 빈도수)
# - IDF(Inverse Document Frequency): 역문헌 빈도
#    - 해당 단어의 일반적인 중요도를 나타내는 값
#    - log( 전체 문서의 수 / 해당 단어가 포함된 문서들의 수 )

# %%
from sklearn.feature_extraction.text import TfidfTransformer    # Tf * idf 구할 때

# %%
[txt, print, def]

# %%
tfidf_transformer=TfidfTransformer(smooth_idf=True,use_idf=True)        # Tf-idf 가중치를 적용할 수 있도록 변환시켜줌
tf_idf_matrix = tfidf_transformer.fit_transform(word_count_vector)

feature_names=cv.get_feature_names()

dense = tf_idf_matrix.todense()

for i in range(len(dense)):
    doc = dense[i].tolist()[0]           # dense[i].tolist()는 2차원 list, 예를들면 shape: (1,814)
    phrase_scores = [pair for pair in zip(range(0, len(doc)), doc) if pair[1] > 0]      # 0의 값이 아닌것만 모아서 만듦

    sorted_phrase_scores = sorted(phrase_scores, key=lambda t: t[1], reverse=True) # sorted(phrase_scores, key=lambda t: t[1] * -1)라고 해도 됨
    for phrase, score in [(feature_names[word_id], score) for (word_id, score) in sorted_phrase_scores][:20]:
        print('{0: <20} {1}'.format(phrase, score))      # 단어와 단어의 tf-idf 값을 출력
    print()
    ##### 이 부분은 테스트를 위해서 #####
    if i == 3:     
        break
    ###############################
# Out:
# uiot                 0.5972907483137071
# 대치동                  0.19211070405914132
# 네코                   0.16977225009877606
# li                   0.12508570423378704
# txt                  0.10732568133761924
# print                0.08786458557743673
# 척수                   0.08488612504938803
# 엠게임                  0.08339689478536368
# 최진민                  0.08190766452133931
# 유조                   0.0769945105248138
# tomatalk             0.07232817655361297
# 배틀필드                 0.07148305267316886
# 미와                   0.06850459214512016
# 브라보                  0.06850459214512016
# 옵티머스                 0.06850459214512016
# 원빈                   0.06850459214512016
# def                  0.06766184258241213
# 위약금                  0.06552613161707146
# cloi                 0.06254767108902275
# date                 0.0610584408249984
#
# 파워볼                  0.33424322503769366
# 조수용                  0.21057243101073495
# 최진민                  0.1523879434946108
# 배틀필드                 0.13299311432256944
# 이석영                  0.12191035479568865
# 오라떼                  0.12154299092279768
# 예나                   0.09983888540086953
# 임채무                  0.09983888540086953
# 높임말                  0.0954980642964839
# 옵티머스                 0.09143276609676648
# rx                   0.0831206964516059
# 귀뚜라미그룹               0.0831206964516059
# 동래                   0.0803500065698857
# 토익                   0.0803500065698857
# 콰르텟                  0.07871412401204252
# 판교신도시                0.07871412401204252
# qm                   0.0775793166881655
# 삼행                   0.0775793166881655
# 제이지                  0.0775793166881655
# unboxingreview       0.07529177079412763
#
# oktv                 0.7841295084752965
# 바바                   0.19321576323707146
# 교동도                  0.14138636308373903
# 콘크리트                 0.13035401036034341
# 사업단                  0.11631588616769105
# 홈스쿨                  0.10528593144489276
# 교동                   0.10527781971250688
# ollehtv              0.09897045415861733
# otv                  0.09726414619194855
# 위약금                  0.07720968305958802
# 조식                   0.07219606727649788
# 주교                   0.06564381699721017
# 봉선                   0.06126742400295359
# 최진민                  0.058157943083845524
# 제비집                  0.056554545233495616
# ots                  0.05341262605385697
# 메를로                  0.053258191148679954
# itu                  0.05078106597897391
# pvr                  0.04398686851494103
# 영업점                  0.043117095734575124
#
# 수화                   0.3777019681021626
# 청계                   0.2646298630901266
# 아트리                  0.23697050495526206
# 틸론                   0.19244910678816404
# 원지                   0.18135497828208832
# crank                0.1469502174270229
# 외풍                   0.1415739899601806
# qoo                  0.13734617021896822
# 눈동자                  0.13734617021896822
# 두드러기                 0.1363812567790139
# 검지                   0.12815751798600908
# 재택                   0.12274313110111248
# 빅이슈                  0.1181970892084787
# 건영                   0.11767964566310372
# 이길보라                 0.1159240682621618
# 무좀                   0.1093166251591268
# 보이차                  0.10871926655169988
# 대부도                  0.10752454933684605
# 배수관                  0.10752454933684605
# 세면대                  0.10010794801171276

# %% [markdown]
# - 추가
#    - 클로바
#      1. 네콘
#      2. 척수장애인
#      3. 척수 장애인
#      4. 가스잠그미
#      5. 브라보라이프
#    - 카카오
#      1. 산타토익
#      2. 산타 토익
#      3. qm3 (뭔가 관련있는듯)
#      4. qm6 (뭔가 관련있는듯)
#      5. 삼행시
#    - 기가지니
#      1. 바바북
#      2. 바바펜
#      3. 바바키트
#      4. 교동 기가 아일랜드
#      5. 올레tv스카이라이프
#    - 누구
#      1. 아트리체 (아파트 관련) \- '청계' 라는 단어와도 연관(청계천)
#      2. qoo(qoo10 관련 사이트 때문에)
#      3. 범양건영 (아파트 관련)
#
# - 삭제
#    - 클로바
#        1. li
#        2. txt
#        3. 유조
#        4. 엠게임
#        5. date
#    - 카카오
#        6. 조수용 (카카오 공동 대표)
#        7. 배틀필드 (관련성이 전혀 없는 것 같은데 자꾸 나옴)
#        8. 이석영 (카카오 AI 서비스 팀장)
#        9. rx (관련없어보임... 근데 많이 나오긴 함)
#        10. 콰르텟 (전혀 관련없는 "카카오프렌즈 콰르텟 강남점에서 라이언에그번을 맛보다" 이런거 많이 나옴)
#
# - 렘런트유노마켓 blog.naver.com/ppang7942/ 블로그 데이터 삭제하고싶다.

# %% [markdown]
# # <br>
# ## 부정 document

# %% [markdown]
# <br/><br/>
# ### POS tagging하기

# %% [markdown]
# #### 1.  Komoran 사용

# %%
komoran.pos("척수 장애인")
# Out:
# [('척수', 'NNP'), ('장애인', 'NNP')]

# %%
komoran.pos("척수장애인")
# Out:
# [('척수', 'NNP'), ('장애인', 'NNP')]

# %%
komoran.pos("무드등")
# Out:
# [('무드', 'NNG'), ('등', 'NNB')]

# %%
komoran.pos("반려견")
# Out:
# [('반려', 'NNG'), ('견', 'NNG')]

# %%
komoran.pos("샤오미")
# Out:
# [('샤오미', 'NNP')]

# %%
komoran.pos("척수 장애인")
# Out:
# [('척수', 'NNP'), ('장애인', 'NNP')]

# %%
komoran.pos("nugu")
# Out:
# [('nugu', 'SL')]

# %%
komoran.pos("line out")
# Out:
# [('line out', 'NNG')]

# %%
komoran.pos("null")
# Out:
# [('null', 'SL')]

# %%
komoran.pos("스포티지")
# Out:
# [('스포', 'NNP'), ('티', 'NNG'), ('지', 'NNB')]

# %%
komoran.pos("지니뮤직")
# Out:
# [('지니', 'NNP'), ('뮤직', 'NNP')]

# %%
komoran.pos("올레tv스카이라이프")
# Out:
# [('올레', 'NNP'), ('tv', 'SL'), ('스카이', 'NNP'), ('라이프', 'NNP')]

# %%
from konlpy.tag import Komoran

# %%
komoran = Komoran(userdic='./unregistered.txt')

# %%
import re

# 명사와 외래어만 뽑아내기위한 정규표현식
p = re.compile('NN.*|SL')

# %% [markdown]
# results = []
# for i, brand_text in enumerate(positive_text):
#     pos_tagging_list = list(map(komoran.pos, brand_text))
#     print("pos tagging -", i)
#
#     docs = []
#     for doc in pos_tagging_list:
#         want_words = []
#         for word, pos in doc:
#             if p.match(pos):
#                 want_words.append(word)
#         docs.append(want_words)
#     print("noun extract -", i)
#
#     results.append(sum(docs, []))
#     print("finish -", i)

# %%
results = []
for i, brand_text in enumerate(negative_text):
    pos_tagging_list = list(map(komoran.pos, brand_text))
    print("pos tagging -", i)

    docs = []
    for doc in pos_tagging_list:
        want_words = [word for word, pos in doc if p.match(pos)]         
        docs.append(want_words)
    print("noun extract -", i)
    
    results.append(sum(docs, []))
    print("finish -", i)
# Out:
# pos tagging - 0
# noun extract - 0
# finish - 0
# pos tagging - 1
# noun extract - 1
# finish - 1
# pos tagging - 2
# noun extract - 2
# finish - 2
# pos tagging - 3
# noun extract - 3
# finish - 3

# %% [markdown]
# ### pickle로 일단 저장

# %%
import pickle
pickle.dump(results, open('tfidf_neg_list.pickle', "wb"))

# %%
load_result2 = pickle.load(open('tfidf_neg_list.pickle', "rb"))
results = load_result2

# %% [markdown]
# <br/><br/>
# ### stopword 제거

# %%
stopwords = [line.strip() for line in open('./stopwordsKor.txt', encoding='utf-8')]

# %% [markdown]
# final_docs = []
# for doc in results:
#     unique_NN_words = set(doc)
#     final_NN_words = doc
#
#     for word in unique_NN_words:
#         if word in stopwords:
#             while word in final_NN_words: final_NN_words.remove(word)
#     final_docs.append(final_NN_words)

# %% [markdown]
# from tqdm import tqdm_notebook
# stopword_dict = {}
# for s_word in stopwords:
#     stopword_dict[s_word] = 1
#
# final_docs = []
# for i, doc in enumerate(results):
#     unique_NN_words = set(doc)
#     final_NN_words = doc
#
#     for word in tqdm_notebook(unique_NN_words):
#         if stopword_dict.get(word):
#             while True:
#                 try:
#                     final_NN_words.remove(word)
#                 except ValueError:
#                     break
#     print("finish -", i)

# %%
from tqdm import tqdm_notebook
stopword_dict = {}
for s_word in stopwords:
    stopword_dict[s_word] = 1

final_docs = []
for i, doc in enumerate(results):
    unique_NN_words = set(doc)
    final_NN_words = doc
    
    for word in tqdm_notebook(unique_NN_words):
        if stopword_dict.get(word):
            final_NN_words = list(filter(lambda x: x!= word, final_NN_words))
    final_docs.append(final_NN_words)
    #print("finish -", i)
# Out:
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.

# %% [markdown]
# <br/><br/>
# ### document별 단어들을 각각의 document로 바꾸기

# %%
documents = []
for doc_words in final_docs:
    document = " ".join(doc_words)
    documents.append(document)

# %%
documents[0][:200]
# Out:
# '유선 래 연결 와이파이 연결 사용 음성 인식 스피커 일상 차지 역할 흐름 가운데 국내 업체 세계 시장 맥 지적 전문가 국내 업체 시장 확대 이유 길 지적 글 사기 기본 사례 네이버 카카오 날 하루 수준 카메라 인식 로그인 질문 마찬가지 대답 네이버 음악 듣기 결제 상태 지원 별도 이퀄라이저 설정 지하철역 자동차 추천 경로 검색 비교 효과 결과 근처 분식집 '

# %% [markdown]
# <br/><br/>
# ### 벡터화 하기

# %%
from sklearn.feature_extraction.text import CountVectorizer     # 벡터 수 카운트 할 때

# %%
cv=CountVectorizer(max_df=0.85, max_features=10000)     
# 문서 집합에서 단어 토큰을 생성하고 각 단어의 수를 세어 BOW(Bag Of Words) 인코딩한 벡터를 만든다.
# max_df=0.85란 말은 documents들에서 85%이상 나타나는 토큰(단어)를 무시하라는 것, 
# max_df=25란 말은 documents들에서 25번 이상 나타나는 토큰(단어)를 무시하라는 것,
# maximum 단어의 개수를 1만개로 정함 - 빈도수가 높은 단어 순으로 1만개를 자름(메모리 에러 안나려고)
# min_df=1, ngram_range=(1,1) 등은 default 값임  

word_count_vector=cv.fit_transform(documents)      # vectorize된 word_count_vector
feature_names=cv.get_feature_names()

# %%
len(cv.vocabulary_)      # 위에서 max_features를 10000으로 주었지만 단어 수가 그 이하였음
# Out:
# 9971

# %%
cv.vocabulary_
# Out:
# {'듣기': 2976,
#  '이퀄라이저': 7082,
#  '지하철역': 8084,
#  '마인': 3322,
#  '자비스': 7292,
#  '중반': 7959,
#  '실현': 5659,
#  '생태계': 4832,
#  '번성': 4075,
#  '도태': 2830,
#  '시범': 5482,
#  '여원': 6172,
#  '격화': 1451,
#  '조짐': 7814,
#  '진출': 8138,
#  '세컨드': 5034,
#  '메신저': 3490,
#  '계좌': 1534,
#  '개설': 1338,
#  '이모티콘': 6983,
#  '곳도': 1663,
#  '린지': 3261,
#  '전만': 7548,
#  '경쟁자': 1500,
#  '중립': 7956,
#  '선상': 4917,
#  '생물': 4814,
#  'ceo': 134,
#  '주년': 7863,
#  '소회': 5129,
#  '시너지': 5458,
#  '내부': 2328,
#  '논의': 2425,
#  '액션': 5936,
#  '완결': 6487,
#  '베스트': 4115,
#  '브레인': 4443,
#  '노동부': 2382,
#  '권리': 1926,
#  '다라': 2516,
#  '베타서비스': 4125,
#  '제지': 7765,
#  '하루하루': 9424,
#  '실무': 5633,
#  '시각': 5439,
#  '시행착오': 5533,
#  '웹툰': 6726,
#  '회화': 9900,
#  '감안': 1262,
#  '매니저': 3417,
#  '역삼동': 6194,
#  '데모': 2756,
#  '세션': 5023,
#  '테크니컬': 8915,
#  '전산언어학': 7559,
#  '자인': 7314,
#  '최현정': 8447,
#  '연구원': 6213,
#  '킹스': 8809,
#  '골든': 1647,
#  '서클': 4886,
#  '범죄도시': 4091,
#  '제품군': 7767,
#  '만회': 3374,
#  '라인업': 3074,
#  '악의': 5820,
#  '점수': 7612,
#  '필터링': 9397,
#  '진미': 8120,
#  '열흘': 6289,
#  'amp': 25,
#  '상거래': 4736,
#  '전환율': 7598,
#  '격차': 1450,
#  '아니야': 5724,
#  '간단명료': 1219,
#  '클라우드': 8780,
#  '컴퓨팅': 8674,
#  '축적': 8474,
#  '건수': 1408,
#  '정형': 7719,
#  '센서': 5046,
#  '시행': 5532,
#  '소형': 5126,
#  '연속': 6238,
#  '성적': 4982,
#  '구사': 1845,
#  '은어': 6867,
#  '비속어': 4495,
#  '어린아이': 6028,
#  '이해도': 7097,
#  '차원': 8211,
#  '실생활': 5639,
#  '부인': 4325,
#  '융통': 6861,
#  '시간문제': 5442,
#  '연극': 6216,
#  '티켓': 9052,
#  '쏜다': 5702,
#  '견제': 1456,
#  '니혼게이자이신문': 2499,
#  '재팬': 7464,
#  '신제품': 5607,
#  '이례': 6973,
#  '머니': 3455,
#  'exid': 267,
#  '심술': 5669,
#  'yes': 1099,
#  'yeah': 1097,
#  '수초': 5272,
#  '간의': 1227,
#  '맥락': 3443,
#  '스노우': 5328,
#  '캐럴': 8619,
#  '카르': 8581,
#  '토도': 8929,
#  '전술': 7563,
#  '스페인': 5399,
#  '연합군': 6263,
#  '속사정': 5134,
#  '총살': 8426,
#  '총검': 8421,
#  '오은영': 6425,
#  '박사': 3850,
#  '육아': 6846,
#  '한국인': 9492,
#  '파급': 9064,
#  '공산': 1684,
#  '집계': 8157,
#  '매도': 3418,
#  '반박': 3883,
#  '이해진': 7100,
#  '의장': 6921,
#  '살아남기': 4707,
#  '자국': 7271,
#  '국내외': 1880,
#  '역차별': 6200,
#  '다국적': 2506,
#  '투명': 8986,
#  '납부': 2309,
#  '선발': 4912,
#  '주자': 7901,
#  '꼬리표': 2201,
#  '회피': 9899,
#  '국정': 1902,
#  '액수': 5937,
#  '커튼': 8656,
#  '가습기': 1166,
#  '통신업': 8964,
#  '돌입': 2860,
#  '태반': 8874,
#  '자급': 7273,
#  '유통망': 6826,
#  '붕괴': 4431,
#  '통신비': 8962,
#  '아이콘': 5783,
#  '최다': 8433,
#  '거래소': 1373,
#  'kmspico': 485,
#  '악성': 5814,
#  '승모': 5428,
#  '외숙모': 6521,
#  '공항': 1716,
#  '공황': 1720,
#  '네티즌': 2370,
#  '사이에서': 4641,
#  '맞춤법': 3410,
#  '파괴': 9062,
#  '동아': 2903,
#  '이상우': 7004,
#  '단독': 2566,
#  '슈와': 5319,
#  '재테크': 7461,
#  '총집결': 8429,
#  '화도': 9818,
#  '걸음': 1419,
#  'ma': 541,
#  '연간': 6203,
#  '명도': 3528,
#  '지장': 8064,
#  '통신비밀보호법': 8963,
#  '바이오': 3840,
#  '가이드라인': 1185,
#  '근거': 1990,
#  '식별': 5540,
#  '개시': 1344,
#  '구매욕': 1840,
#  '현행법': 9721,
#  '축제': 8475,
#  '현장': 9715,
#  '잠자리': 7363,
#  '호칭': 9778,
#  '정우성': 7683,
#  '초가': 8386,
#  '멸종': 3522,
#  '벙어리': 4107,
#  '웹브라우저': 6725,
#  'ip': 429,
#  '방문자': 3962,
#  '트럼프': 9009,
#  '경기장': 1478,
#  '환승': 9858,
#  '셔틀버스': 5061,
#  '종목': 7834,
#  '선수': 4922,
#  '올림픽': 6464,
#  '하이라이트': 9448,
#  '백과사전': 4030,
#  '평창': 9201,
#  '동계': 2871,
#  '서울까지': 4869,
#  '필립스': 9390,
#  '라이팅': 3073,
#  '사랑합니다': 4585,
#  '중국어': 7947,
#  '학습량': 9469,
#  '지난번': 8019,
#  '지진': 8071,
#  '새벽': 4788,
#  '당사자': 2625,
#  '토론': 8931,
#  '불평': 4423,
#  '개인화': 1349,
#  '순항': 5303,
#  '선거구': 4898,
#  '늑장': 2479,
#  '오명': 6394,
#  '지방': 8034,
#  '광역': 1789,
#  '기초': 2110,
#  '정수': 7672,
#  '조정': 7810,
#  '공직': 1707,
#  '선거법': 4899,
#  '개정안': 1351,
#  '문턱': 3696,
#  '출마자': 8487,
#  '차질': 8216,
#  '여야': 6169,
#  '현영': 9712,
#  '분유': 4381,
#  '겨냥': 1444,
#  '가루': 1141,
#  '기저귀': 2101,
#  '이곳저곳': 6937,
#  '증가세': 7992,
#  '발굴': 3908,
#  '실적': 5648,
#  '둔화': 2950,
#  '산타': 4693,
#  '토익': 8942,
#  '태부족': 8875,
#  '웃어봐': 6652,
#  '투표수': 8997,
#  '한겨레': 9482,
#  '광범위': 1784,
#  '소화': 5128,
#  '약관': 5972,
#  '픽사': 9380,
#  '베이': 4119,
#  '파문': 9078,
#  '파기': 9065,
#  '시민': 5476,
#  '검은사막': 1424,
#  '점령': 7610,
#  '후발': 9920,
#  '핸디캡': 9637,
#  '관측': 1774,
#  '한글판': 9501,
#  '맞대응': 3403,
#  '태세': 8878,
#  '임박': 7221,
#  '고군분투': 1542,
#  '뮤지컬': 3725,
#  '배우': 4017,
#  '노랫말': 2388,
#  '넘버': 2357,
#  'impossible': 414,
#  'dream': 218,
#  '통계청': 8953,
#  'kosis': 488,
#  '비염': 4501,
#  '레이스': 3122,
#  '미용실': 3763,
#  '항구': 9587,
#  '수수료': 5233,
#  '폭우': 9257,
#  '동원': 2907,
#  '참치': 8241,
#  '생도': 4806,
#  '상회': 4783,
#  '소속': 5096,
#  '황치열': 9880,
#  '컴백': 8671,
#  'bb': 70,
#  '동사': 2894,
#  '컨센서스': 8662,
#  '매수': 3424,
#  '직전': 8103,
#  '한차례': 9545,
#  '하향': 9458,
#  '상향': 4779,
#  '전고': 7526,
#  '길드': 2131,
#  '대장': 2701,
#  '줌인터넷': 7934,
#  '인턴십': 7163,
#  'zum': 1110,
#  '기획자': 2122,
#  '인턴': 7162,
#  '사원': 4635,
#  '모집': 3589,
#  '피처': 9371,
#  '국립전파연구원': 1884,
#  '물음표': 3717,
#  '세뇌': 5010,
#  '동물': 2888,
#  '채팅': 8277,
#  '분출': 4385,
#  '참여자': 8239,
#  '명가': 3524,
#  '우승': 6604,
#  '롯데닷컴': 3179,
#  '한국말': 9489,
#  'mt': 593,
#  '돌파구': 2864,
#  '마켓': 3332,
#  '컬리': 8667,
#  '출범': 8489,
#  '유통업': 6827,
#  '영역': 6312,
#  '전환기': 7597,
#  '킬러': 8806,
#  '황성진': 9878,
#  '기관': 2047,
#  '한국소비자원': 9490,
#  '몰입': 3613,
#  '동명': 2886,
#  '이인': 7050,
#  '지칭': 8075,
#  '브이': 4455,
#  '라이브': 3069,
#  'live': 524,
#  '출연': 8494,
#  '방탄소년단': 3988,
#  '지민': 8033,
#  '건의': 1410,
#  '유입': 6814,
#  'nlp': 629,
#  '의욕': 6917,
#  '대중교통': 2706,
#  '비전': 4511,
#  '유명': 6784,
#  '텀블러': 8899,
#  '인형': 7166,
#  '갖가지': 1315,
#  '군부대': 1911,
#  '시설': 5490,
#  '화제': 9839,
#  '남짓': 2304,
#  'ktx': 496,
#  '단적': 2581,
#  'g메일': 351,
#  '이해력': 7098,
#  '만족도': 3368,
#  '가스': 1162,
#  '벨브': 4133,
#  '유기': 6764,
#  '미러링': 3743,
#  '코웨이': 8707,
#  '시선': 5489,
#  '불신': 4414,
#  'drs': 220,
#  '고무': 1573,
#  '진화': 8143,
#  '표출': 9282,
#  '주유소': 7897,
#  '오랫동안': 6380,
#  '탐색': 8862,
#  '재즈': 7456,
#  '텔레그램': 8919,
#  'gm': 330,
#  '수입': 5259,
#  '접근성': 7624,
#  '강자': 1307,
#  'xxx': 1094,
#  '지명': 8031,
#  '목표액': 3607,
#  '연내': 6221,
#  '장면': 7390,
#  '홍채': 9815,
#  '도용': 2816,
#  '제값': 7723,
#  '집토끼': 8170,
#  '유다': 6770,
#  '불가피': 4393,
#  '문맥': 3680,
#  '도출': 2827,
#  '취급': 8520,
#  '저자': 7494,
#  '평판': 9203,
#  '랭킹': 3093,
#  'crank': 165,
#  '패턴': 9151,
#  '내일': 2338,
#  '골자': 1653,
#  '신설': 5587,
#  'view': 988,
#  '개편': 1357,
#  '실비': 5636,
#  '보험': 4229,
#  '청구': 8337,
#  '서치': 4885,
#  '김상범': 2145,
#  '리더': 3205,
#  '전개': 7522,
#  '게재': 1443,
#  '행위': 9648,
#  'my': 603,
#  '길고양이': 2129,
#  '여성': 6164,
#  '가전제품': 1190,
#  '독자': 2841,
#  '엘지': 6137,
#  '속편': 5141,
#  '보일러': 4214,
#  '봉사': 4286,
#  '명예': 3541,
#  '포진': 9236,
#  '경상북도': 1490,
#  '울릉군': 6643,
#  '미현': 3776,
#  '지리': 8029,
#  '승자': 5433,
#  '김연지': 2151,
#  '경계': 1475,
#  'hey': 373,
#  'hot': 387,
#  '사재기': 4649,
#  '수상': 5227,
#  'lg유플러스': 515,
#  '장애인': 7412,
#  '감수': 1258,
#  '이봉': 6990,
#  '우연이': 6608,
#  '선착순': 4931,
#  '수조': 5263,
#  '밤새': 3946,
#  '일례': 7176,
#  '쇼핑카트': 5190,
#  '일라이': 7174,
#  '장애물': 7410,
#  '히스토리': 9963,
#  '준수': 7927,
#  '원본': 6682,
#  '클로': 8788,
#  '유영민': 6804,
#  '과기': 1724,
#  '정통부': 7715,
#  '장관': 7373,
#  '이어': 7030,
#  '방통': 3989,
#  '엇박자': 6089,
#  '청와대': 8351,
#  '자원': 7308,
#  '국산': 1895,
#  '유념': 6766,
#  '김민서': 2140,
#  '촉감': 8417,
#  '비의': 4506,
#  '범인': 4089,
#  '소매': 5087,
#  '감자': 1267,
#  '생원': 4825,
#  '이야기책': 7027,
#  '연예인': 6246,
#  '도서': 2806,
#  'isbn': 441,
#  '특가': 9020,
#  '서서': 4860,
#  '시청자': 5517,
#  'sk브로드밴드': 817,
#  'iptv': 436,
#  '근접': 2004,
#  '외출복': 6528,
#  '비결': 4472,
#  '한국정보화진흥원': 9496,
#  'nia': 627,
#  '논문': 2422,
#  'eu': 261,
#  '유럽연합': 6776,
#  '민간': 3781,
#  'rd': 752,
#  '투자가': 8992,
#  '뒷받침': 2957,
#  '인당': 7119,
#  '소득': 5082,
#  '체감': 8363,
#  '양극': 5987,
#  '지목': 8032,
#  '고지': 1618,
#  '프랑스': 9314,
#  '이탈리아': 7084,
#  '워치': 6659,
#  '전화통': 7596,
#  '상대방': 4744,
#  '마블': 3295,
#  '본질': 4275,
#  '피쳐': 9372,
#  '통신업체': 8965,
#  '하현': 9459,
#  '확신': 9851,
#  '내재': 2339,
#  '의존': 6923,
#  '가능성': 1129,
#  '배분': 4004,
#  '낙동강': 2269,
#  '오리아': 6389,
#  '신세': 5588,
#  '오염': 6422,
#  '에어': 6106,
#  'airvisual': 16,
#  '측정': 8530,
#  '대도시': 2650,
#  '도시': 2809,
#  '구독자': 1829,
#  '형성': 9745,
#  '구별': 1843,
#  '범죄': 4090,
#  '억양': 6059,
#  '원천': 6698,
#  '화상': 9827,
#  '립싱크': 3263,
#  '비음': 4505,
#  '이데일리': 6958,
#  '미애': 3759,
#  '일자': 7199,
#  '출혈': 8508,
#  '거품': 1397,
#  '비상근무': 4491,
#  '최선': 8438,
#  '불감증': 4394,
#  '수위': 5255,
#  '관세': 1763,
#  '위안': 6741,
#  '절하': 7607,
#  '만지': 3369,
#  '환율': 9860,
#  '사설': 4611,
#  '미중': 3767,
#  '무역': 3655,
#  '마찰': 3327,
#  '설주': 4952,
#  '대란': 2654,
#  '뒷수습': 2960,
#  '인민': 7129,
#  '정책': 7709,
#  '이해관계자': 7096,
#  '동네북': 2881,
#  '주의보': 7898,
#  '십상': 5677,
#  '납치': 2313,
#  '감금': 1244,
#  '성폭행': 4991,
#  '과시': 1733,
#  '딜레마': 3012,
#  '대북': 2676,
#  '식량': 5538,
#  '에도': 6092,
#  '비핵화': 4528,
#  '교착': 1813,
#  '고수': 1590,
#  '물가': 3704,
#  '협상': 9730,
#  '우선순위': 6600,
#  '증산': 7999,
#  '타진': 8841,
#  '자산': 7293,
#  '비상': 4490,
#  '포트폴리오': 9248,
#  '집단': 8161,
#  '베팅': 4128,
#  '소송': 5097,
#  '여기저기': 6146,
#  '곡소리': 1637,
#  '뭉칫돈': 3723,
#  '가세': 1159,
#  '버블': 4067,
#  '로펌': 3171,
#  '법무법인': 4096,
#  '대륙': 2659,
#  '도약': 2813,
#  '가업': 1174,
#  '승계': 5425,
#  '오지': 6432,
#  '축복': 8470,
#  '결집': 1467,
#  '병행': 4173,
#  '회담': 9884,
#  '황교안': 9872,
#  '김성식': 2149,
#  '오신환': 6418,
#  '승부': 5429,
#  '손학규': 5162,
#  '민주당': 3791,
#  '중대': 7951,
#  '지대': 8022,
#  '신당': 5564,
#  '최저임금': 8444,
#  '재계': 7434,
#  'oecd': 655,
#  '노동': 2380,
#  '위월': 6745,
#  '수출': 5274,
#  '마이너스': 3317,
#  '반도체': 3876,
#  '어부': 6038,
#  '동산': 2895,
#  '한파': 9551,
#  '가계': 1117,
#  '법정': 4102,
#  '아시아나항공': 5770,
#  '입찰': 7259,
#  '공고': 1666,
#  '종규': 7832,
#  '용병': 6574,
#  '빅데이터': 4530,
#  '삼성카드': 4724,
#  '육박': 6842,
#  'ms': 590,
#  '의기투합': 6901,
#  '정호': 7720,
#  '승부수': 5430,
#  '한진': 9542,
#  '공정위': 1701,
#  '차기': 8195,
#  '총수': 8427,
#  '조원태': 7805,
#  '미달': 3737,
#  '현대': 9697,
#  '상여금': 4758,
#  '대우조선해양': 2694,
#  '노사': 2399,
#  '단협': 2590,
#  '교섭': 1807,
#  '기아': 2082,
#  '사내': 4577,
#  '스타트': 5364,
#  '메디톡스': 3481,
#  '대웅제약': 2695,
#  '보톡스': 4224,
#  'lgu': 514,
#  '광선': 1785,
#  '홈쇼핑': 9804,
#  '옛말': 6362,
#  '삼성물산': 4723,
#  '부문': 4306,
#  '약자': 5979,
#  '본업': 4268,
#  '롯데쇼핑': 3181,
#  '창사': 8252,
#  '풀무': 9292,
#  '원지': 6697,
#  '주사': 7879,
#  '지배': 8035,
#  '확립': 9849,
#  '가려움': 1138,
#  '보습제': 4202,
#  '달래': 2598,
#  '고혈압': 1634,
#  '체크': 8382,
#  '요시': 6551,
#  '시크': 5521,
#  '초간': 8387,
#  '스트레칭': 5384,
#  '쇼크': 5186,
#  '화학': 9844,
#  '울상': 6647,
#  '회복': 9886,
#  '젤메': 7775,
#  '디톡스': 3007,
#  '분쟁': 4384,
#  '먹구름': 3464,
#  '증권업': 7995,
#  '대어': 2687,
#  '표류': 9270,
#  '분식회계': 4378,
#  '심사': 5668,
#  '감리': 1254,
#  '임상': 7223,
#  '골다공증': 1643,
#  '치료제': 8535,
#  '특허': 9032,
#  '호재': 9775,
#  '이식': 7023,
#  '유상증자': 6794,
#  '전봉준': 7556,
#  '결의': 1465,
#  '김원봉': 2155,
#  '신념': 5563,
#  '주검': 7858,
#  '진실': 8125,
#  '노란빛': 2384,
#  '복수': 4243,
#  '스포츠': 5405,
#  '동갑내기': 2868,
#  '웃음꽃': 6653,
#  '승점': 5435,
#  '프리미어리그': 9331,
#  '시티': 5526,
#  '돈방석': 2849,
#  '피플': 9378,
#  '양형': 6014,
#  '사법': 4602,
#  '건설': 1405,
#  '통한': 8976,
#  '한미글로벌': 9516,
#  '총괄': 8422,
#  '부회장': 4356,
#  '농협': 2442,
#  '상호금융': 4781,
#  '한국투자공사': 9498,
#  'mou': 585,
#  '인공위성': 7113,
#  'kaist': 466,
#  '학술': 9468,
#  '마라톤': 3281,
#  '영웅': 6313,
#  '서윤복': 4876,
#  '국립서울현충원': 1883,
#  '안장': 5855,
#  '콩쿠르': 8734,
#  '투어': 8990,
#  '오피니언': 6444,
#  '칼럼': 8614,
#  '사상누각': 4607,
#  '확대경': 9848,
#  '수첩': 5271,
#  '넷마블': 2374,
#  '신작': 5604,
#  '여의도': 6173,
#  '기지개': 2107,
#  '청량리역': 8342,
#  '롯데캐슬': 3184,
#  'skyl': 813,
#  '양가': 5985,
#  '희소성': 9958,
#  '집값': 8155,
#  '대구': 2637,
#  '지하철': 8082,
#  '죽전역': 7923,
#  '도보': 2803,
#  '주상': 7882,
#  '복합': 4254,
#  'mba': 554,
#  '입성': 7244,
#  '비즈니스': 4515,
#  '스토리텔링': 5377,
#  '총망라': 8425,
#  '양성': 5996,
#  '무궁무진': 3627,
#  '특화': 9034,
#  '강의': 1306,
#  '공영': 1693,
#  '타협안': 8845,
#  '파업전야': 9087,
#  '타결': 8813,
#  '뇌물': 2445,
#  '김학의': 2174,
#  '구속영장': 1854,
#  '백성': 4041,
#  '눈높이': 2457,
#  '세종대왕': 5031,
#  '동상': 2896,
#  '수렴': 5213,
#  '이름값': 6976,
#  '서울대': 4870,
#  '자녀': 7277,
#  '부실': 4317,
#  '학회': 9478,
#  '참석': 8237,
#  '김종석': 2164,
#  '기상청': 2076,
#  '구모': 1841,
#  '매출액': 3432,
#  '형제': 9747,
#  '아담': 5725,
#  'wave': 1060,
#  '입수': 7246,
#  '걸림돌': 1418,
#  'qa': 739,
#  'olleh': 666,
#  'giga': 326,
#  '무선랜': 3646,
#  '통장': 8971,
#  '하나에': 9408,
#  '공인인증서': 1698,
#  '하나로': 9407,
#  '젊은이들': 7608,
#  '은행가': 6872,
#  '체크카드': 8384,
#  '아버지': 5756,
#  '입출금': 7262,
#  '출타': 8502,
#  '텔레비': 8920,
#  '고스톱': 1591,
#  '대세': 2683,
#  '대안': 2685,
#  '사드': 4581,
#  '모양새': 3579,
#  '일체': 7205,
#  '슬픔': 5423,
#  '각자': 1211,
#  '중첩': 7981,
#  '활약': 9868,
#  '동맹': 2884,
#  '간첩': 1230,
#  '터미네이터': 8893,
#  '파격': 9059,
#  '트라우마': 9002,
#  '천대': 8296,
#  '완파': 6498,
#  '결재': 1466,
#  'どうした': 1114,
#  '시타': 5523,
#  '무스': 3649,
#  'nhn': 625,
#  'next': 623,
#  'human': 393,
#  'network': 619,
#  '복잡계': 4248,
#  'complex': 156,
#  '지고': 8011,
#  '세계관': 5000,
#  '헤지펀드': 9692,
#  '주연': 7891,
#  '담보': 2613,
#  '공정': 1699,
#  '약점': 5980,
#  '금융인': 2022,
#  '부자': 4327,
#  '중범죄': 7960,
#  '가난': 1127,
#  '경범죄': 1483,
#  '재생산': 7451,
#  '경찰': 1506,
#  '정당화': 7644,
#  '창조': 8258,
#  '독점': 2842,
#  '통제': 8972,
#  '브라더': 4438,
#  '홍수': 9809,
#  '함정': 9568,
#  '유의': 6809,
#  '편향': 9192,
#  '천사': 8302,
#  '악마': 5812,
#  '청력': 8343,
#  '체계': 8366,
#  '노하우': 2412,
#  '장악': 7408,
#  '어른': 6027,
#  '나기': 2229,
#  '원유': 6690,
#  '생산량': 4819,
#  'bd': 74,
#  '사우디아라비아': 4633,
#  '수출량': 5275,
#  'opec': 669,
#  '사무총장': 4598,
#  '균형': 1952,
#  '강변': 1294,
#  '전성시대': 7561,
#  '기술적': 2081,
#  '윤리': 6852,
#  'clova': 147,
#  '소모': 5090,
#  '손잡이': 5157,
#  '장시간': 7401,
#  '배려': 4002,
#  '앙탈': 5901,
#  '의인': 6919,
#  '커플': 8657,
#  '발매': 3916,
#  '되풀이': 2929,
#  '중학교': 7983,
#  '프로그래밍': 9319,
#  '군더더기': 1910,
#  '공산품': 1685,
#  '창출': 8259,
#  '취향저격': 8528,
#  '긴장': 2125,
#  '탕진': 8868,
#  'speaker': 845,
#  '몰두': 3611,
#  '엘리': 6134,
#  '이별': 6989,
#  '템포': 8922,
#  '외계인': 6513,
#  '지식인': 8046,
#  '필살기': 9391,
#  '가방': 1152,
#  '모음': 3582,
#  '칫솔': 8573,
#  '살균': 4699,
#  '시발': 5480,
#  '리가': 3199,
#  '맥북': 3444,
#  '패드': 9141,
#  '언니네': 6062,
#  '아시': 5767,
#  '이웃': 7041,
#  '세입': 5029,
#  '윤종신': 6856,
#  '신기하': 5560,
#  'ml': 576,
#  '에펠탑': 6123,
#  '신나': 5562,
#  '설거지': 4938,
#  '집안일': 8165,
#  '옛날': 6361,
#  '페퍼톤스': 9176,
#  'ready': 756,
#  'type': 932,
#  '참견': 8234,
#  '문물': 3683,
#  'ux': 954,
#  '해답': 9597,
#  '풀리': 9291,
#  '간다': 1217,
#  '캘린더': 8635,
#  '불시': 4413,
#  '요정': 6556,
#  '도의': 2820,
#  '아이러니': 5774,
#  '선생님': 4919,
#  '티맵': 9040,
#  '겨울왕국': 1446,
#  '외출': 6527,
#  '뉴에이지': 2470,
#  '귀뚜라미': 1936,
#  '얼굴': 6072,
#  '증정': 8005,
#  '통일': 8970,
#  '다나': 2509,
#  '라나': 3045,
#  '무트': 3669,
#  '면포': 3519,
#  '메모': 3485,
#  '부축': 4342,
#  '우측': 6619,
#  '기로': 2062,
#  '첨단': 8326,
#  '부가세': 4290,
#  '홀라당': 9797,
#  '제시카': 7744,
#  '구가': 1824,
#  '기능인': 2055,
#  '보아': 4204,
#  '기온': 2091,
#  '이정재': 7059,
#  '송혜교': 5183,
#  '블랙아웃': 4461,
#  '사무실': 4597,
#  '편견': 9180,
#  '절단': 7600,
#  '와인': 6481,
#  '포장지': 9232,
#  '저가': 7474,
#  '임의': 7227,
#  '이탈': 7083,
#  '높이': 2443,
#  '한밤': 9517,
#  '야간': 5947,
#  '리셋': 3230,
#  '아미': 5753,
#  '유혹': 6835,
#  'wake': 1055,
#  'up': 946,
#  'word': 1077,
#  '만듦새': 3355,
#  '애니': 5918,
#  '후면': 9919,
#  '한대': 9507,
#  '거란': 1371,
#  '시멘트': 5474,
#  '변기': 4141,
#  '시공': 5446,
#  '세면대': 5014,
#  '별짓': 4168,
#  '월세': 6711,
#  '철물': 8313,
#  '원주': 6695,
#  '다이소': 2542,
#  '라텍스': 3078,
#  '종이컵': 7840,
#  '덩어리': 2749,
#  '수세미': 5231,
#  '건조': 1412,
#  '여드름': 6151,
#  ...}

# %% [markdown]
# <br/><br/>
# ### TF-IDF 적용
# - TF * IDF는 특정 문서 내에서 단어 빈도가 높을수록, 전체 문서들에는 그 단어를 포함한 문서가 적을수록 TF * IDF값이 높아지는 특징이 있다.
# - 이러한 특징을 이용해서 모든 문서에 나타나는 흔한 단어들을 걸러내며, 특정 단어가 가지는 중요도를 측정하는 데 사용된다.
# - 한마디로 TF * IDF 값은 특정 단어가 가지는 중요도!
# - TF(Term Frequency): 단어 빈도
#    - 해당 문서에서 단어가 나타나는 빈도수
#    - 문서의 길이가 길면 해당 단어의 실제 중요도와는 상관없이 단어의 빈도수는 증가될 확률이 높다.
#    - 위의 문제를 해결하기 위해 다음과 같이 표준화 -> (문서에서 단어가 나타나는 빈도수) / (모든 단어가 나타나는 빈도수)
# - IDF(Inverse Document Frequency): 역문헌 빈도
#    - 해당 단어의 일반적인 중요도를 나타내는 값
#    - log( 전체 문서의 수 / 해당 단어가 포함된 문서들의 수 )

# %%
from sklearn.feature_extraction.text import TfidfTransformer    # Tf * idf 구할 때

# %%
tfidf_transformer=TfidfTransformer(smooth_idf=True,use_idf=True)        # Tf-idf 가중치를 적용할 수 있도록 변환시켜줌
tf_idf_matrix = tfidf_transformer.fit_transform(word_count_vector)

feature_names=cv.get_feature_names()

dense = tf_idf_matrix.todense()

for i in range(len(dense)):
    doc = dense[i].tolist()[0]           # dense[i].tolist()는 2차원 list, 예를들면 shape: (1,814)
    phrase_scores = [pair for pair in zip(range(0, len(doc)), doc) if pair[1] > 0]      # 0의 값이 아닌것만 모아서 만듦

    sorted_phrase_scores = sorted(phrase_scores, key=lambda t: t[1], reverse=True) # sorted(phrase_scores, key=lambda t: t[1] * -1)라고 해도 됨
    for phrase, score in [(feature_names[word_id], score) for (word_id, score) in sorted_phrase_scores][:20]:
        print('{0: <20} {1}'.format(phrase, score))      # 단어와 단어의 tf-idf 값을 출력
    print()
    ##### 이 부분은 테스트를 위해서 #####
    if i == 3:     
        break
    ###############################
# Out:
# out                  0.23413519912775949
# 미니언즈                 0.12807609620495877
# 펌웨어                  0.12807609620495877
# wave                 0.12023158874128191
# nonnull              0.1123673342236481
# 엘지                   0.0922147892675703
# 약관                   0.08709174541937197
# 보호자                  0.08226371861245604
# float                0.07223614342948807
# 목적어                  0.07223614342948807
# 반려                   0.07172261387477692
# 와서                   0.07172261387477692
# 후에                   0.07172261387477692
# 셀리                   0.06960776190284741
# 필립스                  0.06659957002657856
# for                  0.06420990527065606
# int                  0.06420990527065606
# parse                0.06420990527065606
# 선풍기                  0.0632797835480431
# 잠시                   0.0632797835480431
#
# 취약점                  0.12959782932778247
# 보험료                  0.12450596823582745
# 선생님                  0.10079831169938638
# 크림                   0.09782611789957871
# 수영                   0.09359843229228734
# 핫스팟                  0.09359843229228734
# 라섹                   0.0791986734780893
# 새벽                   0.0791986734780893
# 민정                   0.07896001670881406
# 치약                   0.07896001670881406
# 보험                   0.07199879407099027
# 입맛                   0.07199879407099027
# 펌웨어                  0.07199879407099027
# 포터블                  0.07114626756332998
# kakao                0.06768001432184062
# 기내식                  0.06768001432184062
# 채영                   0.06768001432184062
# 파워볼                  0.06768001432184062
# 내일                   0.06479891466389123
# 마무리                  0.06479891466389123
#
# 영성                   0.1893853323774358
# 예제                   0.18664196418765233
# 종교                   0.13064937493135664
# 파이썬                  0.13020241600948712
# lte                  0.12088220443690546
# 취약점                  0.11332706665959888
# 명상                   0.1119851785125914
# 예수                   0.1119851785125914
# 하만                   0.09821679110498568
# 청소                   0.0906616533276791
# 특허                   0.08398888388444355
# 스포                   0.08310651555037252
# iptv                 0.07555137777306592
# 보험                   0.07555137777306592
# 외출                   0.07555137777306592
# 가격표                  0.07101949964153842
# 벽걸이                  0.06799623999575932
# 옛날                   0.06799623999575932
# 올레                   0.06799623999575932
# 장면                   0.06799623999575932
#
# 아리야                  0.2534058055350227
# 아리아                  0.24773293776474753
# 아리                   0.14322060464524466
# 신지                   0.13341677202343616
# 연면적                  0.1290935235744455
# 메이트                  0.12431228196057714
# 티맵                   0.12431228196057714
# 김종민                  0.12128797456676016
# 코요테                  0.12128797456676016
# 무드등                  0.11999564172979958
# 쿠폰                   0.0967706788143545
# 예린                   0.0909659809250701
# 유효                   0.08902902450920615
# 블루원                  0.08490158219673209
# flo                  0.07883718346839409
# 거래량                  0.07649986582189364
# 오버                   0.07649986582189364
# 인재                   0.07649986582189364
# nu                   0.07277278474005609
# tid                  0.07277278474005609
