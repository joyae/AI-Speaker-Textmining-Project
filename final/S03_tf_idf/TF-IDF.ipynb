# %% [markdown]
# # TF-IDF 구하기
# - 벡터화하기 전에 데이터 전처리
#    - document별 형태소 분석
#    - 미등록단어 처리
#    - 명사만 추출
#    - 불용어(stopwords) 처리
# - document별 단어로 tokenize되어 있는 것을 다시 합쳐서 각각 하나의 document로 만들기
# - 벡터화(vectorize) 하기
# - tf-idf 값 구하기

# %%
import pandas as pd

# %%
# CSV 데이터 불러오기
df = pd.read_csv("../../data/naver_blog_clova.csv", index_col=0)

# %%
# 데이터 확인
df.head()
# Out:
#                                       title     publish_datetime  \
# 0                    애기들이 좋아하는 ai스피커 네이버클로바  2019-03-20 23:01:00
# 1                      네이버 클로바 스피커 1년 사용 후기  2019-03-31 19:35:00
# 2              네이버 클로바 사용법 맘스다이어리와 함께 육아정보를  2018-12-14 12:10:00
# 3                   네이버 클로바. 나의 두 번째 Ai 스피커  2018-12-02 14:04:00
# 4  네이버 클로바 스피커 브라운 미니언 : 오히려 부모님 선물로 추천드려요!  2018-09-09 18:18:00
#
#                                                 text  \
# 0  애기들이 좋아하는 ai스피커 네이버클로바\n작년부터 tv에 #인공지능 스피커가 \n...
# 1  네이버 클로바 스피커 1년 사용 후기\n네이버 클로바 1년 사용 후기를 몇 자 적어...
# 2  어제는 눈이 갑자기 많이 내려서 1주일에 한번 가는 문센을 가야하나 말아야하나고민이...
# 3  안녕하세요. 제르디난 입니다.\n올해 초 카카오 미니를 사용해보고 약간의 실망스러움...
# 4  네이버 클로바 스피커 브라운 미니언 : 오히려 부모님 선물로 추천드려요!\n요새 정...
#
#                                                  url
# 0  https://blog.naver.com/sky121400?Redirect=Log&...
# 1  https://blog.naver.com/danjuck?Redirect=Log&lo...
# 2  https://blog.naver.com/ralrapo?Redirect=Log&lo...
# 3  https://blog.naver.com/yarosiku?Redirect=Log&l...
# 4  https://blog.naver.com/ukb0914?Redirect=Log&lo...

# %%
# 블로그 본문 확인
df.text[:5]
# Out:
# 0    애기들이 좋아하는 ai스피커 네이버클로바\n작년부터 tv에 #인공지능 스피커가 \n...
# 1    네이버 클로바 스피커 1년 사용 후기\n네이버 클로바 1년 사용 후기를 몇 자 적어...
# 2    어제는 눈이 갑자기 많이 내려서 1주일에 한번 가는 문센을 가야하나 말아야하나고민이...
# 3    안녕하세요. 제르디난 입니다.\n올해 초 카카오 미니를 사용해보고 약간의 실망스러움...
# 4    네이버 클로바 스피커 브라운 미니언 : 오히려 부모님 선물로 추천드려요!\n요새 정...
# Name: text, dtype: object

# %%
# 블로그 본문 컬럼이 Not null인 총 개수 확인
len(df[df.text.notnull()])
# Out:
# 1052

# %%
# 블로그 본문 컬럼이 Not null인 row를 제외하기
df = df[df.text.notnull()].copy()

# %%
# 블로그 본문에 있는 개행문자(\n, \r)를 제거
df.text = df.text.map(lambda x:x.replace("\n", " ").replace("\r", " "))

# %% [markdown]
# <br/><br/>
# ### POS tagging하기

# %% [markdown]
# #### 1.  Komoran 사용

# %%
from konlpy.tag import Komoran

# %%
komoran = Komoran(userdic='./unregistered.txt')

# %%
pos_tagging_list = list(map(komoran.pos, df.text))

# %%
import re

# 명사와 외래어만 뽑아내기위한 정규표현식
p = re.compile('NN.*|SL')

# %%
docs = []
for doc in pos_tagging_list:
    want_words = []
    for word, pos in doc:
        if p.match(pos):
            want_words.append(word)
    docs.append(want_words)

# %%
docs[:2]
# Out:
# [['애기',
#   'ai',
#   '스피커',
#   '네이버',
#   '클로바',
#   '작년',
#   'tv',
#   '인공지능',
#   '스피커',
#   '출현',
#   '시기상조',
#   '생각',
#   '애플',
#   'siri',
#   '구글',
#   '기능',
#   '인공',
#   '스피커',
#   '라고',
#   '어느날',
#   '형',
#   '네이버',
#   '클로바',
#   '생각',
#   '말',
#   '애',
#   '구매',
#   '권유',
#   '애',
#   '말',
#   '귀',
#   '!!',
#   '집',
#   'ai',
#   '스피커',
#   '폭풍',
#   '검색',
#   '아마존',
#   '알렉사',
#   '해외',
#   '우리나라',
#   '통신',
#   '스피커',
#   'sk',
#   'nugu',
#   'kt',
#   '기가',
#   '지니',
#   'lg',
#   '구글',
#   '구글',
#   '홈',
#   '네이버',
#   '클로바',
#   '경쟁',
#   '만사',
#   '분',
#   '통신',
#   '스피커',
#   'iot',
#   '구축',
#   '고민',
#   '분',
#   '구글',
#   '홈',
#   '것',
#   '중',
#   '네이버',
#   '클로바',
#   '통신',
#   '강제',
#   'iot',
#   '구축',
#   '수',
#   '구글',
#   '홈',
#   '확장',
#   '것',
#   '것',
#   '우리나라',
#   '최적화',
#   '것',
#   '캐릭터',
#   '모양',
#   '장점',
#   '미니언즈',
#   '샐리',
#   '브라운',
#   '이름',
#   '스피커',
#   '존재',
#   '소형',
#   '미니',
#   '스피커',
#   '배터리',
#   '향상',
#   '존재',
#   'sk',
#   'nugu',
#   'vs',
#   '네이버',
#   '클로바',
#   '처음',
#   '클로바',
#   '구매',
#   'ai',
#   '스피커',
#   '집',
#   '활용',
#   '생각',
#   'sk',
#   'nugu',
#   '캔들',
#   '을',
#   '검색',
#   '집',
#   'iptv',
#   'sk',
#   'nugu',
#   '사용',
#   'tv',
#   '제어',
#   '수',
#   '와이프',
#   '캔들',
#   '활용도',
#   '것',
#   '원래',
#   '목적',
#   '애',
#   '것',
#   '차이',
#   '클로바',
#   '내',
#   '장형',
#   '배터리',
#   '배터리',
#   '클로바',
#   '휴대',
#   '고정',
#   '사용',
#   '전기',
#   '단점',
#   '클로바',
#   '구입',
#   '결정',
#   '구입',
#   '애',
#   '모델',
#   '예상외',
#   '곰',
#   '곰',
#   '구입',
#   '일',
#   '뒤',
#   '택배',
#   '세팅',
#   '설명',
#   '휴대폰',
#   '설치',
#   '세팅',
#   '기기',
#   '와이파이',
#   '검색',
#   '비번',
#   '스피커',
#   '이름',
#   '끝',
#   '스피커',
#   '디바',
#   '이스',
#   '호출',
#   '명',
#   '스피커',
#   '수',
#   '이름',
#   '우리집',
#   '곰',
#   '돌이',
#   '브라운',
#   '스피커',
#   '이름',
#   '샐리',
#   '기기',
#   '음성',
#   '가지',
#   '스피커',
#   '목소리',
#   '더',
#   '기호',
#   '선택',
#   '애',
#   '이름',
#   '사용법',
#   '리다',
#   '것',
#   '라고',
#   '손',
#   '모습',
#   '고민',
#   '신기하',
#   '게도',
#   '어른',
#   '소리',
#   '반응',
#   '애',
#   '소리',
#   '반응',
#   '안',
#   '음역',
#   '이해',
#   '애',
#   '발음',
#   '안',
#   '말',
#   '스피커',
#   '애기',
#   '필요',
#   '생각',
#   '장난감',
#   '것',
#   '스피커',
#   '성능',
#   '일',
#   '애',
#   '관심',
#   '스피커',
#   '조금',
#   '처음',
#   '친구',
#   '것',
#   '하루',
#   '종일',
#   '샐리',
#   '소리',
#   '노이로제',
#   '것',
#   '나중',
#   '스피커',
#   '이틀',
#   '동안',
#   '아무도',
#   '아침',
#   '스피커',
#   '노래',
#   '날씨',
#   '등',
#   '어른',
#   '장난감',
#   '것',
#   '네이버',
#   '클로바',
#   '휴대',
#   '장거리',
#   '이동',
#   '등',
#   '여행',
#   '애',
#   '것',
#   '노래',
#   '이야기',
#   '충전',
#   'c',
#   '타입',
#   '외장',
#   '배터리',
#   '르',
#   '사용',
#   '차량',
#   '충전',
#   '사용',
#   '와이파이',
#   '휴대폰',
#   '핫',
#   '스판',
#   '이용',
#   '설정',
#   '처음',
#   '안',
#   '클로바',
#   '단점',
#   '장소',
#   '때',
#   '와이파이',
#   '설정',
#   '집',
#   '차',
#   '캠핑장',
#   '사용',
#   '기기',
#   '와이파이',
#   '핫스팟',
#   '것',
#   '야외',
#   '사용',
#   '집',
#   '와이파이',
#   '기억',
#   '세팅',
#   '것',
#   '설정',
#   '와이파이',
#   '등',
#   '세팅',
#   '것',
#   '단점',
#   '외',
#   '말',
#   '화나',
#   '것',
#   '스피커',
#   '듯',
#   '!!'],
#  ['네이버',
#   '클로바',
#   '스피커',
#   '년',
#   '사용',
#   '후기',
#   '네이버',
#   '클로바',
#   '년',
#   '사용',
#   '후기',
#   '자',
#   '이때',
#   '네이버',
#   '뮤직',
#   '이벤트',
#   '공짜',
#   '요즘',
#   '프로모션',
#   '구입',
#   '당시',
#   '모습',
#   '택배',
#   '박스',
#   '에어',
#   '비닐',
#   '안전',
#   '배',
#   '송',
#   '바',
#   '설명서',
#   '음성',
#   '명령어',
#   '영어',
#   '동화',
#   '냉장고',
#   '영어',
#   '메모',
#   '메모',
#   '등등',
#   '기능',
#   '사실',
#   '년',
#   '정도',
#   '사용',
#   '것',
#   '그중',
#   '사용',
#   '것',
#   '뉴스',
#   '브리핑',
#   '오늘',
#   '날씨',
#   '최',
#   '신곡',
#   '쥬',
#   '버',
#   '동요',
#   '음성',
#   '인식',
#   '안',
#   '분',
#   '대체',
#   '최근',
#   '음성',
#   '업그레이드',
#   '탤런트',
#   '유인나',
#   '씨',
#   '목소리',
#   '설정',
#   '처음',
#   '유인나',
#   '씨',
#   '목소리',
#   '며칠',
#   '사용',
#   '보니',
#   '기본',
#   '음성',
#   '지금',
#   '기본',
#   '음성',
#   '업데이트',
#   '고객',
#   '니즈',
#   '네이버',
#   '클로바',
#   '스피커',
#   '점수',
#   '점수',
#   '부분',
#   '바로',
#   '!!',
#   '쥬',
#   '버',
#   '동요',
#   '네이버',
#   '뮤직',
#   '결제',
#   '분',
#   '쥬',
#   '버',
#   '동요',
#   '끝',
#   '집',
#   '아이',
#   '동요',
#   '음악',
#   '공짜',
#   '결제',
#   '느낌',
#   '느낌',
#   '완전',
#   '꿀',
#   '클로바',
#   '스피커',
#   '단점',
#   '마련',
#   '단점',
#   '배터리',
#   '조루',
#   '거',
#   '전원',
#   '연결',
#   '처음',
#   '카카오',
#   'AI',
#   '스피커',
#   '때',
#   '내장',
#   '배터리',
#   '패스',
#   '네이버',
#   '클로바',
#   '구매',
#   '마나',
#   '것',
#   '말',
#   '배터리',
#   '땅',
#   '때',
#   '시간',
#   '클로바',
#   '배터리',
#   '수',
#   '인형',
#   '마이크',
#   '요건',
#   '클로버',
#   '엉덩이',
#   '부분',
#   '정',
#   '가운데',
#   '전원',
#   '버튼',
#   '네이버',
#   '클로바',
#   '뒤통수',
#   '음',
#   '소거',
#   '블루투스',
#   '볼륨',
#   '조절',
#   '버튼',
#   '일자',
#   '나열',
#   '아래쪽',
#   'C',
#   '타입',
#   '충전',
#   '케이블',
#   '연결',
#   '수',
#   '구멍',
#   '뒤통수',
#   '개인',
#   '개',
#   '중',
#   '을',
#   'AI',
#   '시기',
#   '상조',
#   '라고',
#   '이상',
#   '돈',
#   '구매',
#   '클로바',
#   '년',
#   '사용',
#   '후기']]

# %% [markdown]
# <br/><br/>
# ### stopword 제거

# %%
stopwords = [line.strip() for line in open('./stopwordsKor.txt', encoding='utf-8')]

# %%
final_docs = []
for doc in docs:
    unique_NN_words = set(doc)
    final_NN_words = doc
    
    for word in unique_NN_words:
        if word in stopwords:
            while word in final_NN_words: final_NN_words.remove(word)
    final_docs.append(final_NN_words)

# %% [markdown]
# <br/><br/>
# ### document별 단어들을 각각의 document로 바꾸기

# %%
documents = []
for doc_words in final_docs:
    document = " ".join(doc_words)
    documents.append(document)

# %%
documents[0]
# Out:
# '애기 ai 스피커 네이버 클로바 작년 tv 인공지능 스피커 출현 시기상조 애플 siri 구글 기능 인공 스피커 어느날 네이버 클로바 애 구매 권유 애 귀 ai 스피커 폭풍 검색 아마존 알렉사 해외 우리나라 통신 스피커 sk nugu kt 기가 지니 lg 구글 구글 홈 네이버 클로바 경쟁 만사 통신 스피커 iot 구축 고민 구글 홈 네이버 클로바 통신 강제 iot 구축 구글 홈 확장 우리나라 최적화 캐릭터 모양 장점 미니언즈 샐리 브라운 이름 스피커 존재 소형 미니 스피커 배터리 향상 존재 sk nugu vs 네이버 클로바 처음 클로바 구매 ai 스피커 활용 sk nugu 캔들 검색 iptv sk nugu 사용 tv 제어 와이프 캔들 활용도 원래 목적 애 차이 클로바 장형 배터리 배터리 클로바 휴대 고정 사용 전기 단점 클로바 구입 결정 구입 애 모델 예상외 곰 곰 구입 뒤 택배 세팅 설명 휴대폰 설치 세팅 기기 와이파이 검색 비번 스피커 이름 끝 스피커 디바 이스 호출 스피커 이름 우리집 곰 돌이 브라운 스피커 이름 샐리 기기 음성 스피커 목소리 기호 선택 애 이름 사용법 리다 손 모습 고민 신기하 게도 어른 반응 애 반응 음역 이해 애 발음 스피커 애기 필요 장난감 스피커 성능 애 관심 스피커 조금 처음 친구 하루 종일 샐리 노이로제 나중 스피커 이틀 아무도 아침 스피커 노래 날씨 어른 장난감 네이버 클로바 휴대 장거리 이동 여행 애 노래 이야기 충전 c 타입 외장 배터리 사용 차량 충전 사용 와이파이 휴대폰 핫 스판 이용 설정 처음 클로바 단점 장소 와이파이 설정 캠핑장 사용 기기 와이파이 핫스팟 야외 사용 와이파이 기억 세팅 설정 와이파이 세팅 단점 화나 스피커 듯'

# %% [markdown]
# <br/><br/>
# ### 벡터화 하기

# %%
from sklearn.feature_extraction.text import CountVectorizer     # 벡터 수 카운트 할 때

# %%
cv=CountVectorizer(max_df=0.85, max_features=10000)     
# 문서 집합에서 단어 토큰을 생성하고 각 단어의 수를 세어 BOW(Bag Of Words) 인코딩한 벡터를 만든다.
# max_df=0.85란 말은 documents들에서 85%이상 나타나는 토큰(단어)를 무시하라는 것, 
# max_df=25란 말은 documents들에서 25번 이상 나타나는 토큰(단어)를 무시하라는 것,
# maximum 단어의 개수를 1만개로 정함 - 빈도수가 높은 단어 순으로 1만개를 자름(메모리 에러 안나려고)
# min_df=1, ngram_range=(1,1) 등은 default 값임  

word_count_vector=cv.fit_transform(documents)      # vectorize된 word_count_vector

# %%
len(cv.vocabulary_)      # 위에서 max_features를 10000으로 주었지만 단어 수가 그 이하였음
# Out:
# 8955

# %%
cv.vocabulary_
# Out:
# {'애기': 5377,
#  'ai': 146,
#  '스피커': 4936,
#  '작년': 6694,
#  'tv': 1176,
#  '인공지능': 6474,
#  '출현': 7724,
#  '시기상조': 4969,
#  '애플': 5399,
#  'siri': 1061,
#  '구글': 1904,
#  '기능': 2116,
#  '인공': 6472,
#  '어느날': 5464,
#  '구매': 1915,
#  '권유': 1994,
#  '폭풍': 8317,
#  '검색': 1568,
#  '아마존': 5235,
#  '알렉사': 5348,
#  '해외': 8641,
#  '우리나라': 5997,
#  '통신': 8102,
#  'sk': 1062,
#  'nugu': 877,
#  'kt': 703,
#  '기가': 2104,
#  '지니': 7325,
#  'lg': 722,
#  '경쟁': 1648,
#  '만사': 3199,
#  'iot': 648,
#  '구축': 1957,
#  '고민': 1717,
#  '강제': 1471,
#  '확장': 8838,
#  '최적화': 7667,
#  '캐릭터': 7820,
#  '모양': 3408,
#  '장점': 6780,
#  '미니언즈': 3562,
#  '샐리': 4445,
#  '브라운': 4162,
#  '이름': 6336,
#  '존재': 7151,
#  '소형': 4726,
#  '미니': 3560,
#  '배터리': 3781,
#  '향상': 8675,
#  'vs': 1229,
#  '처음': 7549,
#  '활용': 8860,
#  '캔들': 7824,
#  'iptv': 651,
#  '사용': 4311,
#  '제어': 7073,
#  '와이프': 5882,
#  '활용도': 8861,
#  '원래': 6061,
#  '목적': 3431,
#  '차이': 7483,
#  '장형': 6788,
#  '휴대': 8923,
#  '고정': 1753,
#  '전기': 6864,
#  '단점': 2553,
#  '구입': 1948,
#  '결정': 1612,
#  '모델': 3386,
#  '예상외': 5767,
#  '택배': 8043,
#  '세팅': 4657,
#  '설명': 4570,
#  '휴대폰': 8924,
#  '설치': 4576,
#  '기기': 2113,
#  '와이파이': 5881,
#  '비번': 4200,
#  '디바': 2913,
#  '이스': 6383,
#  '호출': 8767,
#  '우리집': 6001,
#  '돌이': 2777,
#  '음성': 6251,
#  '목소리': 3426,
#  '기호': 2180,
#  '선택': 4558,
#  '사용법': 4315,
#  '리다': 3078,
#  '모습': 3406,
#  '신기하': 5066,
#  '게도': 1577,
#  '어른': 5475,
#  '반응': 3680,
#  '음역': 6260,
#  '이해': 6456,
#  '발음': 3708,
#  '필요': 8448,
#  '장난감': 6743,
#  '성능': 4591,
#  '관심': 1856,
#  '조금': 7103,
#  '친구': 7770,
#  '하루': 8477,
#  '종일': 7164,
#  '노이로제': 2394,
#  '나중': 2273,
#  '이틀': 6452,
#  '아무도': 5239,
#  '아침': 5289,
#  '노래': 2378,
#  '날씨': 2288,
#  '장거리': 6736,
#  '이동': 6319,
#  '여행': 5638,
#  '이야기': 6398,
#  '충전': 7735,
#  '타입': 8007,
#  '외장': 5925,
#  '차량': 7473,
#  '스판': 4922,
#  '이용': 6406,
#  '설정': 4575,
#  '장소': 6763,
#  '캠핑장': 7832,
#  '핫스팟': 8615,
#  '야외': 5424,
#  '기억': 2150,
#  '화나': 8801,
#  '후기': 8898,
#  '이때': 6329,
#  '뮤직': 3548,
#  '이벤트': 6357,
#  '공짜': 1810,
#  '프로모션': 8378,
#  '당시': 2586,
#  '박스': 3651,
#  '에어': 5570,
#  '비닐': 4191,
#  '안전': 5330,
#  '설명서': 4571,
#  '명령어': 3363,
#  '영어': 5730,
#  '동화': 2838,
#  '냉장고': 2353,
#  '메모': 3320,
#  '뉴스': 2459,
#  '브리핑': 4172,
#  '오늘': 5782,
#  '신곡': 5059,
#  '동요': 2821,
#  '인식': 6499,
#  '대체': 2665,
#  '업그레이드': 5536,
#  '탤런트': 8045,
#  '유인나': 6185,
#  '며칠': 3346,
#  '보니': 3916,
#  '기본': 2134,
#  '업데이트': 5537,
#  '고객': 1683,
#  '니즈': 2483,
#  '점수': 6961,
#  '부분': 4046,
#  '결제': 1614,
#  '아이': 5258,
#  '음악': 6255,
#  '느낌': 2466,
#  '마련': 3140,
#  '조루': 7106,
#  '전원': 6910,
#  '연결': 5655,
#  '카카오': 7799,
#  '내장': 2343,
#  '패스': 8229,
#  '마나': 3129,
#  '인형': 6530,
#  '마이크': 3168,
#  '요건': 5936,
#  '클로버': 7965,
#  '엉덩이': 5544,
#  '가운데': 1355,
#  '버튼': 3816,
#  '뒤통수': 2867,
#  '소거': 4677,
#  '블루투스': 4185,
#  '볼륨': 4006,
#  '조절': 7131,
#  '일자': 6568,
#  '나열': 2265,
#  '아래쪽': 5223,
#  '케이블': 7871,
#  '구멍': 1919,
#  '개인': 1506,
#  '시기': 4968,
#  '상조': 4417,
#  '어제': 5499,
#  '주일': 7227,
#  '가야': 1348,
#  '전날': 6869,
#  '수도': 4787,
#  '조심': 7120,
#  '문자': 3508,
#  '결국': 1602,
#  '예방': 5757,
#  '접종': 6977,
#  '장롱': 6749,
#  '면허': 3355,
#  '운전': 6035,
#  '아기': 5208,
#  '외출': 5927,
#  '니사': 2479,
#  '이즈': 6436,
#  '디자인': 2924,
#  '무게': 3447,
#  '이예': 6403,
#  '기계': 2106,
#  '신랑': 5074,
#  '초보자': 7633,
#  '사랑': 4280,
#  '오디오': 5791,
#  '재생': 6802,
#  '일시': 6558,
#  '정지': 7029,
#  '명령': 3360,
#  '공간': 1774,
#  '모바일': 3397,
#  '테더링': 8053,
#  '실내': 5116,
#  '인사': 6487,
#  '요요': 5961,
#  '변경': 3873,
#  '아들': 5220,
#  '애칭': 5398,
#  '최대': 7654,
#  '타이머': 7996,
#  '초록': 7626,
#  '불이': 4146,
#  '근처': 2072,
#  '카페': 7806,
#  '대답': 2613,
#  '해주': 8646,
#  '쇼핑': 4773,
#  '배달': 3769,
#  '민족': 3594,
#  '주문': 7203,
#  '플러스': 8402,
#  '인터넷': 6518,
#  '티비': 8157,
#  'vod': 1224,
#  '영화': 5743,
#  'lot': 749,
#  '조명': 7110,
#  '가습기': 1345,
#  '세상': 4640,
#  '사운드': 4319,
#  '높이': 2433,
#  '핸드폰': 8658,
#  '가능': 1313,
#  '육아': 6216,
#  '생후': 4474,
#  '인지': 6514,
#  '정보': 6996,
#  '클로': 7964,
#  '제휴': 7092,
#  '등록': 2902,
#  '오른쪽': 5809,
#  '상단': 4386,
#  '톱니바퀴': 8096,
#  '스키': 4888,
#  '스토어': 4906,
#  '아지': 5288,
#  '연애': 5686,
#  '상담': 4387,
#  '도서관': 2736,
#  '데이': 2703,
#  '계정': 1678,
#  '연동': 5672,
#  '임산부': 6588,
#  '예비': 5761,
#  '엄마': 5530,
#  '출산': 7705,
#  '예정일': 5774,
#  '생일': 4463,
#  '출생일': 7706,
#  '맞춤': 3257,
#  '제공': 7049,
#  '내일': 2342,
#  '시작': 5016,
#  '자동': 6633,
#  '계산': 1670,
#  '임신': 6591,
#  '혼자': 8782,
#  '주차': 7239,
#  '질문': 7438,
#  '월차': 6098,
#  '확인': 8837,
#  '13년': 21,
#  '데이터': 2706,
#  '분석': 4109,
#  '하니': 8467,
#  '신뢰': 5075,
#  '가요': 1352,
#  '얼마': 5527,
#  '중국어': 7265,
#  '일본어': 6551,
#  '번역': 3823,
#  '외국': 5913,
#  '자장가': 6674,
#  '예전': 5772,
#  '제품': 7087,
#  '추천': 7683,
#  '시나': 4970,
#  '장기간': 6741,
#  '슬립': 4942,
#  '모드': 3391,
#  '오프': 5849,
#  '비서': 4203,
#  'lg유플러스': 728,
#  '서비스': 4499,
#  '참여': 7511,
#  '제르': 7058,
#  '실망': 5121,
#  '분양': 4113,
#  '사무실': 4289,
#  '유용': 6181,
#  '한지': 8586,
#  '호기심': 8760,
#  '장모': 6754,
#  '선물': 4539,
#  '적극': 6837,
#  '개봉': 1498,
#  '리뷰': 3091,
#  '사위': 4321,
#  '라보': 2965,
#  '에디션': 5555,
#  '티브이': 8156,
#  '호환': 8773,
#  '올레': 5869,
#  '노예': 2393,
#  '계약': 1676,
#  '상태': 4420,
#  '포기': 8282,
#  '성품': 4614,
#  '첫인상': 7573,
#  '나름': 2252,
#  '사이즈': 4326,
#  '세대': 4629,
#  '별도': 3889,
#  '상시': 4404,
#  '무선': 3468,
#  '작동': 6695,
#  '현재': 8724,
#  '출시': 7707,
#  '프렌즈': 8372,
#  '바닥': 3614,
#  '똥구멍': 2946,
#  'app': 168,
#  '안내': 5309,
#  '어려움': 5471,
#  '평상시': 8271,
#  '슬림': 4941,
#  '실행': 5149,
#  '단어': 2548,
#  '연발': 5679,
#  '해제': 8645,
#  '언급': 5515,
#  '인테리어': 6522,
#  '소품': 4721,
#  '녀석': 2372,
#  '스테레오': 4900,
#  '감지': 1438,
#  '시대': 4975,
#  '이것저것': 6302,
#  '아랫부분': 5226,
#  '라이트': 2978,
#  '위치': 6125,
#  '샤오미': 4477,
#  'type': 1181,
#  '포트': 8308,
#  '지원': 7360,
#  '추가': 7671,
#  '영상': 5728,
#  '요청': 5969,
#  '소개': 4674,
#  '링크': 3125,
#  '가이드': 1360,
#  '페이지': 8253,
#  '참고': 7508,
#  '니어': 2481,
#  '부모': 4042,
#  '요새': 5955,
#  '회사': 8871,
#  '뽐뿌': 4257,
#  '블루': 4184,
#  '걱정': 1549,
#  '5월': 107,
#  '신세계면세점': 5090,
#  '대란': 2619,
#  'of': 885,
#  '바람': 3618,
#  '버전': 3812,
#  '잠실': 6720,
#  '롯데월드': 3063,
#  '라인': 2981,
#  '실물': 5125,
#  '마음': 3163,
#  '무료': 3461,
#  '이용권': 6407,
#  '증정': 7308,
#  '멜론': 3343,
#  '벅스': 3819,
#  '요미': 5951,
#  '콜라': 7910,
#  '일본': 6550,
#  '인기': 6477,
#  '9월': 123,
#  '도라에몽': 2722,
#  '레이': 3014,
#  '내부': 2330,
#  '어댑터': 5466,
#  'diy': 413,
#  '스티커': 4915,
#  '순정': 4851,
#  '양쪽': 5455,
#  '형식': 8745,
#  '전곡': 6857,
#  '물리': 3530,
#  '음량': 6246,
#  '구성은': 1936,
#  '하단부': 8469,
#  '중심': 7279,
#  '둘레': 2863,
#  '구리': 1914,
#  '단자': 2551,
#  '가시': 1346,
#  '스마트폰': 4870,
#  '충전기': 7736,
#  '사진': 4338,
#  '세트': 4656,
#  '자주': 6678,
#  '표정': 8329,
#  '교체': 1890,
#  '프랑스': 8365,
#  '파리': 8178,
#  '엔비': 5590,
#  '숙소': 4837,
#  '프로그램': 8376,
#  '후회': 8913,
#  '본체': 4003,
#  '혜자': 8752,
#  '케이스': 7872,
#  '역할': 5652,
#  '후디': 8901,
#  '전체': 6931,
#  '조작': 7128,
#  '부의': 4064,
#  '구성': 1934,
#  '외형': 5932,
#  'usb': 1199,
#  '오지': 5839,
#  '입양': 6611,
#  '분위기': 4114,
#  '달라': 2564,
#  '사실은': 4303,
#  '동생': 2813,
#  '어머니': 5482,
#  '정작': 7025,
#  '집안일': 7449,
#  '장윤정': 6774,
#  '발상': 3704,
#  '추석': 7674,
#  '아이디어': 5264,
#  '만족': 3211,
#  '쿠팡': 7925,
#  '로켓': 3054,
#  'on': 892,
#  'off': 886,
#  '방법': 3739,
#  '에어컨': 5572,
#  '포스팅': 8291,
#  '메이': 3327,
#  '스마트': 4868,
#  '기간': 2105,
#  '연장': 5693,
#  '가족': 1374,
#  '내심': 2336,
#  '오늘날': 5783,
#  '입성': 6605,
#  '병아리': 3901,
#  '상자': 4413,
#  '거더': 1528,
#  '미세먼지': 3572,
#  '체크': 7611,
#  '일이': 6566,
#  '10분': 6,
#  '깜빡이': 2224,
#  '외국어': 5914,
#  '사전': 4332,
#  '라디오': 2956,
#  '생활': 4472,
#  '부지런': 4075,
#  '기사': 2140,
#  '집안': 7448,
#  '가전': 1368,
#  '엘지': 5600,
#  '공청': 1811,
#  '하진': 8511,
#  '거리': 1534,
#  '전화': 6938,
#  'sos': 1092,
#  '신청': 5102,
#  '해결': 8623,
#  '성질': 4610,
#  '공기': 1782,
#  '청정': 7592,
#  '스타일': 4894,
#  '건조기': 1558,
#  '납득': 2313,
#  '시비': 4993,
#  '상전': 4416,
#  '냄새': 2346,
#  '식탁': 5052,
#  '여기저기': 5607,
#  '아아': 5251,
#  '성깔': 4588,
#  '얼굴': 5523,
#  '눈빛': 2451,
#  '적응': 6846,
#  '오랜만': 5801,
#  '지능': 7324,
#  '발전': 3709,
#  '방문': 3734,
#  '문도': 3500,
#  '현관': 8703,
#  '사태': 4343,
#  '발생': 3705,
#  '긴급': 2186,
#  '대책': 2664,
#  '회의': 8879,
#  '남편': 2312,
#  '마중': 3175,
#  '마미': 3147,
#  '지도': 7329,
#  '하네': 8464,
#  '오후': 5854,
#  '마무리': 3146,
#  '유행': 6201,
#  '둔감': 2862,
#  '게다': 1576,
#  '지난해': 7323,
#  '가을': 1357,
#  '이용자': 6411,
#  '자리': 6641,
#  '차지': 7488,
#  '먼지': 3307,
#  '편리': 8258,
#  '이점': 6430,
#  '완충': 5894,
#  '방전': 3752,
#  '흥미': 8938,
#  '패키지': 8232,
#  '부품': 4085,
#  '알맹이': 5354,
#  '노트북': 2402,
#  '종료': 7158,
#  '친절': 7775,
#  '심플': 5174,
#  '해지': 8648,
#  '전환': 6941,
#  '마루': 3141,
#  '도요': 2745,
#  '자유': 6665,
#  '객관식': 1521,
#  '감미': 1426,
#  '신의': 5094,
#  '어시스턴트': 5493,
#  '시리': 4985,
#  '삼성전자': 4373,
#  '빅스': 4229,
#  '기반': 2132,
#  '이슈': 6382,
#  'ces': 277,
#  'mwc': 831,
#  '글로벌': 2077,
#  'it': 655,
#  '전시회': 6905,
#  '슈가': 4859,
#  '중순': 7277,
#  '비교': 4188,
#  '출장': 7715,
#  '특징': 8149,
#  '12일': 18,
#  '베타서비스': 3862,
#  '안드로이드': 5316,
#  '아이폰': 5282,
#  '플레이': 8403,
#  '다운로드': 2514,
#  '특화': 8151,
#  'os': 903,
#  '조사': 7111,
#  '이디르': 6328,
#  '사용자': 4317,
#  '캘린더': 7829,
#  '권한': 1996,
#  '허용': 8686,
#  '화면': 8807,
#  '영역': 5735,
#  '키보드': 7971,
#  '입력': 6600,
#  '블로그': 4181,
#  '지식': 7351,
#  'in': 624,
#  'db': 384,
#  '요구': 5937,
#  '소음': 4710,
#  '소요': 4707,
#  '버스': 3811,
#  '지정': 7373,
#  '백종원': 3797,
#  '김치찌개': 2211,
#  '프로': 8374,
#  '야구': 5415,
#  '하이라이트': 8503,
#  '여름': 5612,
#  '베트남': 3863,
#  '환율': 8848,
#  '환전': 8850,
#  '우산': 6002,
#  '커피숍': 7849,
#  '해보면': 8634,
#  '메뉴': 3315,
#  '취향': 7751,
#  '해당': 8628,
#  '쿠폰': 7927,
#  '감상': 1429,
#  '해외여행': 8642,
#  '상대방': 4393,
#  '학원': 8528,
#  '대화': 2679,
#  '프리': 8388,
#  '주제': 7234,
#  '음식': 6253,
#  '오해': 5852,
#  'see': 1040,
#  'you': 1286,
#  'later': 711,
#  '연락처': 5675,
#  '통화': 8114,
#  '일정': 6569,
#  '알람': 5347,
#  '저장': 6832,
#  '도움말': 2749,
#  '왼쪽': 5933,
#  '차별': 7478,
#  '데이트': 2708,
#  '동영상': 2820,
#  '비와': 4208,
#  '기대': 2120,
#  '스페셜': 4924,
#  '보기': 3913,
#  '저의': 6830,
#  '핵심': 8656,
#  '듣기': 2893,
#  '어린이': 5479,
#  '학습': 8525,
#  '다이어리': 2521,
#  '제외': 7075,
#  '동봉': 2810,
#  '다양': 2507,
#  '재미': 6797,
#  '머리': 3299,
#  '기둥': 2125,
#  '안경': 5304,
#  '뒤쪽': 2866,
#  '들로': 2896,
#  '접속': 6974,
#  '로그인': 3029,
#  '실시간': 5135,
#  '맛집': 3245,
#  '서치': 4523,
#  '운세': 6028,
#  '교통': 1892,
#  '상황': 4430,
#  '한마디': 8555,
#  '장르': 6750,
#  '가입자': 1365,
#  '라면': 2961,
#  '로조': 3050,
#  '정이': 7020,
#  '로스': 3044,
#  '플러그': 8401,
#  '가전제품': 1369,
#  '하나로': 8459,
#  '대동단결': 2617,
#  '도움': 2748,
#  '안고': 5305,
#  '설거지': 4563,
#  '해연': 8640,
#  '동해': 2831,
#  '연령': 5676,
#  'lgu': 724,
#  '합작': 8613,
#  '진행': 7432,
#  '스토리': 4905,
#  '준비': 7250,
#  '저도': 6823,
#  '매일': 3278,
#  '시절': 5019,
#  '이웃': 6414,
#  '일기': 6533,
#  '출판': 7720,
#  '성공': 4583,
#  '체험': 7613,
#  '소식': 4705,
#  '볼거리': 4004,
#  '일차': 6572,
#  '니다': 2476,
#  '성장': 4605,
#  '중인': 7285,
#  '갈색': 1413,
#  '토리': 8081,
#  '블랙': 4176,
#  '레드': 3002,
#  '통신사': 8104,
#  'ok': 890,
#  '파닉스': 8173,
#  '회화': 8885,
#  '공부': 1789,
#  '무지': 3485,
#  '봉기': 4015,
#  '지름': 7335,
#  'mm': 812,
#  '이고': 6303,
#  '손바닥': 4741,
#  '부담': 4032,
#  '품질': 8346,
#  '보증서': 3959,
#  '신부': 5080,
#  '앞면': 5370,
#  'led': 717,
#  '360': 89,
#  '표시': 8325,
#  '녹색': 2406,
#  '초록색': 7628,
#  '불빛': 4139,
#  '주황색': 7249,
#  '빨강색': 4250,
#  '부족': 4072,
#  '네트워크': 2368,
#  '어린이집': 5481,
#  '다운': 2513,
#  '동화책': 2839,
#  '준비물': 7251,
#  '기로': 2127,
#  '업체': 5542,
#  '무상': 3465,
#  '작성': 6699,
#  '마트': 3182,
#  '일상': 6554,
#  '등장': 2906,
#  '크기': 7934,
#  '전선': 6898,
#  '요꾸': 5941,
#  '발견': 3694,
#  '완료': 5888,
#  '대로': 2622,
#  '특유': 8145,
#  '말투': 3242,
#  '밧데리': 3726,
#  '팟빵': 8220,
#  '산다': 4350,
#  '이시언': 6391,
#  '나이': 2268,
#  '쪼록': 7468,
#  '첨부': 7569,
#  'music': 827,
#  'naver': 839,
#  'com': 326,
#  'promotion': 971,
#  'clovaspeaker': 322,
#  'ticket': 1160,
#  'doraemonmini': 426,
#  'nhn': 863,
#  'clova': 316,
#  'product': 968,
#  'friends': 518,
#  'doraemon': 425,
#  'html': 595,
#  '평소': 8273,
#  '기회': 2182,
#  '귀여워': 2009,
#  '애장품': 5393,
#  '팝콘': 8219,
#  '통과': 8098,
#  '언니': 5516,
#  '알로하': 5350,
#  '파티': 8192,
#  '컨셉': 7853,
#  '오사카': 5825,
#  '케빈': 7869,
#  '기프트': 2174,
#  '카드': 7789,
#  '제한': 7091,
#  '더더': 2684,
#  '아이템': 5278,
#  '기분': 2137,
#  '인줄': 6512,
#  '라구': 2953,
#  '조합': 7139,
#  '불량품': 4132,
#  '상품': 4422,
#  '시도': 4978,
#  '다음날': 2515,
#  '안녕': 5312,
#  '바냐': 3611,
#  '이세돌': 6380,
#  '알파고': 5357,
#  '대결': 2599,
#  '가도': 1317,
#  '유중': 6188,
#  '상속': 4401,
#  '이기': 6309,
#  '농담': 2425,
#  '변화': 3884,
#  '와중': 5884,
#  '부가': 4022,
#  '메이저': 3328,
#  '사면': 4287,
#  '가치': 1380,
#  '의심': 6287,
#  '합리': 8608,
#  '가격': 1303,
#  '장만': 6752,
#  '포지션': 8297,
#  '웨이브': 6102,
#  '서론': 4490,
#  '편견': 8257,
#  '일수': 6557,
#  '일대일': 6538,
#  '정석': 7005,
#  '사실': 4302,
#  '나는': 2247,
#  '뒷면': 2869,
#  '의미': 6280,
#  '뒷모습': 2870,
#  '포장': 8295,
#  '이나': 6310,
#  '귀여움': 2008,
#  '포인트': 8294,
#  '통수': 8101,
#  '시리얼': 4986,
#  '넘버': 2358,
#  '아웃': 5254,
#  'usbc': 1200,
#  '탑재': 8024,
#  '의문': 6279,
#  '미래': 3567,
#  '미끄럼': 3556,
#  '방지': 3753,
#  '패드': 8224,
#  '처리': 7546,
#  '하단': 8468,
#  '유닛': 6149,
#  '사방': 4291,
#  '구조': 1952,
#  '차용': 7481,
#  '설계': 4565,
#  '좋아서': 7169,
#  '싸구려': 5186,
#  '급진': 2102,
#  '찰떡': 7503,
#  'coupa': 350,
#  'ng': 862,
#  'bgcg': 219,
#  '자취방': 6682,
#  '사은품': 4322,
#  '신규': 5062,
#  '가입': 1363,
#  '다이슨': 2520,
#  '스프': 4933,
#  '에선': 5566,
#  '프래': 8367,
#  '옆쪽': 5751,
#  '외부': 5919,
#  '고려': 1702,
#  '이용하': 6412,
#  '기도': 2123,
#  '기선': 2142,
#  '안보': 5320,
#  '자라': 6636,
#  '연출': 5698,
#  '조카': 7137,
#  '본적': 4001,
#  '종류': 7159,
#  'yg': 1282,
#  '기와': 2155,
#  '비쥬': 4218,
#  '기한': 2176,
#  '일주일': 6571,
#  '일단': 6536,
#  '감기': 1420,
#  'cf': 278,
#  '드라마': 2880,
#  '말씀': 3239,
#  '이유': 6416,
#  'upup': 1196,
#  '옛날': 5779,
#  '노력': 2382,
#  '쿠션': 7921,
#  '타사': 7989,
#  '에드': 5553,
#  '성인': 4602,
#  '컴팩트': 7862,
#  '일다': 6535,
#  'feed': 491,
#  'back': 202,
#  '부스': 4055,
#  '페어': 8249,
#  '진입': 7423,
#  '취소': 7745,
#  '고요': 1742,
#  '마이너스': 3167,
#  '삼성': 4371,
#  '불가': 4123,
#  '관리': 1850,
#  '주시': 7213,
#  '디도': 2912,
#  '생성': 4460,
#  '다만': 2501,
#  '매력': 3268,
#  '발현': 3719,
#  '토이': 8087,
#  '부부': 4045,
#  '정기': 6984,
#  '덕분': 2692,
#  '최신': 7662,
#  '그런지': 2035,
#  '플로': 8408,
#  '드릴': 2888,
#  'bob': 238,
#  '광고': 1864,
#  '지인': 7367,
#  '구매욕': 1917,
#  '아리': 5230,
#  '초소': 7635,
#  '기술': 2145,
#  '출력': 7700,
#  '제일': 7080,
#  '컨트롤': 7854,
#  '유선': 6170,
#  '이어폰': 6400,
#  'aux': 194,
#  '다리': 2499,
#  '일반': 6548,
#  '수행': 4833,
#  '필수': 8445,
#  '불편': 4151,
#  '방식': 3744,
#  '적용': 6845,
#  '표시등': 8326,
#  '지난': 7319,
#  '간엔': 1396,
#  '심층': 5173,
#  '탐구': 8020,
#  '메인': 3332,
#  '기록': 2128,
#  '전송': 6902,
#  '차트': 7491,
#  '기준': 2166,
#  '음원': 6262,
#  '자사': 6651,
#  '대조': 2658,
#  '별개': 3886,
#  '팟캐스트': 8221,
#  '연예인': 5688,
#  '분이': 4117,
#  '마이': 3166,
#  '웬디': 6103,
#  '수동': 4788,
#  '오차': 5841,
#  '보정': 3953,
#  '세부': 4637,
#  '공식': 1796,
#  'home': 582,
#  'lg전자': 729,
#  '코드': 7879,
#  '제로': 7056,
#  '로봇': 3041,
#  '청소기': 7587,
#  '강조': 1472,
#  '허브': 8685,
#  '실험': 5150,
#  '따름': 2934,
#  '구인': 1947,
#  '필립스': 8443,
#  'hk': 577,
#  'smarthome': 1075,
#  '코웨이': 7894,
#  'iocare': 646,
#  ...}

# %% [markdown]
# <br/><br/>
# ### TF-IDF 적용
# - TF * IDF는 특정 문서 내에서 단어 빈도가 높을수록, 전체 문서들에는 그 단어를 포함한 문서가 적을수록 TF * IDF값이 높아지는 특징이 있다.
# - 이러한 특징을 이용해서 모든 문서에 나타나는 흔한 단어들을 걸러내며, 특정 단어가 가지는 중요도를 측정하는 데 사용된다.
# - 한마디로 TF * IDF 값은 특정 단어가 가지는 중요도!
# - TF(Term Frequency): 단어 빈도
#    - 해당 문서에서 단어가 나타나는 빈도수
#    - 문서의 길이가 길면 해당 단어의 실제 중요도와는 상관없이 단어의 빈도수는 증가될 확률이 높다.
#    - 위의 문제를 해결하기 위해 다음과 같이 표준화 -> (문서에서 단어가 나타나는 빈도수) / (모든 단어가 나타나는 빈도수)
# - IDF(Inverse Document Frequency): 역문헌 빈도
#    - 해당 단어의 일반적인 중요도를 나타내는 값
#    - log( 전체 문서의 수 / 해당 단어가 포함된 문서들의 수 )

# %%
from sklearn.feature_extraction.text import TfidfTransformer    # Tf * idf 구할 때

# %%
tfidf_transformer=TfidfTransformer(smooth_idf=True,use_idf=True)        # Tf-idf 가중치를 적용할 수 있도록 변환시켜줌
tf_idf_matrix = tfidf_transformer.fit_transform(word_count_vector)

dense = tf_idf_matrix.todense()

for i in range(len(dense)):
    doc = dense[i].tolist()[0]           # dense[i].tolist()는 2차원 list, 예를들면 shape: (1,814)
    phrase_scores = [pair for pair in zip(range(0, len(doc)), doc) if pair[1] > 0]      # 0의 값이 아닌것만 모아서 만듦


    sorted_phrase_scores = sorted(phrase_scores, key=lambda t: t[1], reverse=True) # sorted(phrase_scores, key=lambda t: t[1] * -1)라고 해도 됨
    for phrase, score in [(feature_names[word_id], score) for (word_id, score) in sorted_phrase_scores][:20]:
        print('{0: <20} {1}'.format(phrase, score))      # 단어와 단어의 tf-idf 값을 출력
    print()
    ##### 이 부분은 테스트를 위해서 #####
    if i == 3:     
        break
    ###############################
# Out:
# 스피커                  0.3098984343915409
# nugu                 0.2645554291179715
# sk                   0.22043403361752695
# 구글                   0.21233337232562116
# 세팅                   0.2099266307961928
# 와이파이                 0.19848448818510178
# 통신                   0.18329517379444307
# 이름                   0.16356646568656333
# 애기                   0.14326284214456464
# 배터리                  0.14069765591348146
# 단점                   0.14002783767846855
# 캔들                   0.13827363937277373
# 존재                   0.12745048394029582
# 어른                   0.1260293750130323
# 우리나라                 0.1260293750130323
# 장난감                  0.12340983469825578
# 구축                   0.11993498417918466
# 사용                   0.10965867046326969
# 구입                   0.10779796862956097
# 처음                   0.09654512049625422
#
# 동요                   0.2666462648454195
# 배터리                  0.22693249566084311
# 점수                   0.2268448274777323
# 뒤통수                  0.21632371392852515
# 공짜                   0.20110573670587753
# 음성                   0.18773600436069088
# 사용                   0.17686944105438587
# 후기                   0.17200586644881327
# 유인나                  0.1683526608347307
# 단점                   0.15056809326378878
# 메모                   0.1482427364802164
# 상조                   0.14569258410960328
# 탤런트                  0.14569258410960328
# 조루                   0.13756277182113108
# 일자                   0.13179457820589222
# 니즈                   0.12366476591742002
# 마나                   0.12366476591742002
# 느낌                   0.12044672467279428
# 엉덩이                  0.11789657230218117
# 기본                   0.11745474186010203
#
# 육아                   0.5938539538446339
# 정보                   0.3308543700090685
# 사용법                  0.3046518050114443
# 사용                   0.1877845571505574
# 아기                   0.17356929946000432
# 맞춤                   0.12576432066959836
# 출생일                  0.11601276578946831
# 이용                   0.11447772070612953
# 생후                   0.10953912119939546
# 신랑                   0.10547241971293445
# 변경                   0.104649515855093
# 예정일                  0.09847235267646966
# 임산부                  0.09847235267646966
# lot                  0.0887948053680446
# 출산                   0.0887948053680446
# 주차                   0.08740558415354384
# 아이                   0.08341552967873031
# 임신                   0.08281246022069087
# 아들                   0.07633881563061802
# 검색                   0.06947028602538542
#
# 사이즈                  0.23646897613766327
# 스테레오                 0.21089735127777076
# 노예                   0.1843027181534072
# 미니                   0.18016318958934363
# app                  0.17901097532012497
# 카카오                  0.17859169524356608
# 계약                   0.17453687050462388
# 에어                   0.16724266268772345
# 슬림                   0.1641846548281629
# 음성                   0.16305439141373004
# 세대                   0.15656973402220337
# 버튼                   0.15023816292500927
# 사용                   0.14934932920471458
# 존재                   0.1487835783231577
# 작동                   0.1439066971460553
# lg유플러스               0.1205299662381156
# ai                   0.11085311640083494
# 모델                   0.10941391094702735
# 스피커                  0.10853108570490082
# 나름                   0.10812373275774823
