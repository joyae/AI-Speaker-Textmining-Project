# %% [markdown]
# # TF-IDF 구하기
# - 벡터화하기 전에 데이터 전처리
#    - document별 형태소 분석
#    - 미등록단어 처리
#    - 명사만 추출
#    - 불용어(stopwords) 처리
# - document별 단어로 tokenize되어 있는 것을 다시 합쳐서 각각 하나의 document로 만들기
# - 벡터화(vectorize) 하기
# - tf-idf 값 구하기

# %%
import pandas as pd

# %%
# CSV 데이터 불러오기
clova_df = pd.read_csv("../../data/sentiment/sentiment_clova.csv", index_col=0)
kakao_df = pd.read_csv("../../data/sentiment/sentiment_mini.csv", index_col=0)
geni_df = pd.read_csv("../../data/sentiment/sentiment_gigagenie.csv", index_col=0)
nugu_df = pd.read_csv("../../data/sentiment/sentiment_nugu.csv", index_col=0)

# %%
# 데이터 합치기
# 긍정 document
pos_c_text = clova_df.positive_text[clova_df.positive_text.notnull()]
pos_k_text = kakao_df.positive_text[kakao_df.positive_text.notnull()]
pos_g_text = geni_df.positive_text[geni_df.positive_text.notnull()]
pos_n_text = nugu_df.positive_text[nugu_df.positive_text.notnull()]

# %%
# 데이터 합치기
# 부정 document
neg_c_text = clova_df.negative_text[clova_df.negative_text.notnull()]
neg_k_text = kakao_df.negative_text[kakao_df.negative_text.notnull()]
neg_g_text = geni_df.negative_text[geni_df.negative_text.notnull()]
neg_n_text = nugu_df.negative_text[nugu_df.negative_text.notnull()]

# %%
clova_text = [pos_c_text, neg_c_text]
kakao_text = [pos_k_text, neg_k_text]
geni_text = [pos_g_text, neg_g_text]
nugu_text = [pos_n_text, neg_n_text]

# %%
len(clova_text), len(kakao_text), len(geni_text), len(nugu_text)
# Out:
# (2, 2, 2, 2)

# %%
clova_text[1]
# Out:
# 3        유선랜을 연결하지 않고 와이파이 연결만으로 사용이 가능하다. 그러나 음성인식 스피...
# 5        이 가운데 국내 업체들만 세계 시장에서 맥을 못추고 있다는 지적이 나오고 있다. ...
# 6                                하지만 아직 갈 길이 멀다는 지적도 나온다.
# 12       글을 쓰면서도 가끔은 이거 사기치는 건 아닌가? 아주 기본적인 사례입니다. 네이버...
# 16       여긴 어디야라는 질문도 마찬가지로 대답하지 못했다. 다만 네이버음악듣기 결제를 하...
# 18       올해 안으로 가입자 만명을 모으는 게 목표다. 구글홈은 검색엔진 구글과 연동돼 정...
# 19                           인공지능이 학습하는 데이터가 계속 쌓이기 때문이다.
# 31       앱은 서비스별로 따로 존재하는데 말만으로도 특정 기능을 실현시킬 수 있는 단계가 ...
# 32       네이버는 현재 진행 중인 차 시범 판매 행사가 끝나도 당분간 국내 정식판매 계획은...
# 39                                        이같은 일이 처음은 아니다.
# 41       구글 홈은 북미에서 달러만여원에 판매 중이다.두 회사 간 경쟁은 현지 제휴 시장에...
# 44       카카오톡은 왜 해외 진출 하지 않느냐는 질문을 자주 받는다. 전 안된다고 본다. ...
# 45       구글 어시스턴트 한국어 서비스는 이날 국내 판매가 시작된 LG전자 스마트폰 V을 ...
# 50       IT공룡들이 앞다퉈 경쟁하는 걸 보니 궁금해졌다. 써봐야 알지. 웨이브를 찾고 웨...
# 51                                       비공개 테스트후 안드로이드 .
# 52       구글은 구글 홈 출시 일정이 확정되지 않았지만 출시 가능성을 열어두고 있다.장 매...
# 53                  어렵고 복잡한 명령어를 내리면 여지없이 도와드릴 수 없다고 말한다.
# 54              구글 어시스턴트가 탑재된 구글 홈은 아직까지 국내에 정식 출시되지 않았다.
# 55                   지난달 안드로이드폰 업데이트 이후 다운로드 수가 만명을 돌파했다.
# 56       다음으로 킹스맨 골든서클 그리고 위는 범죄도시입니다.라는 답이 돌아왔다. 잘 모르...
# 57           경쟁 통신사에 비해 늦은 제품군 출시를 만회하기 위한 라인업 강화라는 분석이다.
# 61                이 인증마크가 붙은 분야에서 소비자는 동일한 플랫폼 경험을 하게 된다.
# 66                                  엠비덱스는 한마디로 말하면 로봇팔이다.
# 70                                        판매 물량에는 제한이 없다.
# 72                  웨이브 스피커에 탑재된 클로바 AI 입장에선 다소 뜬금없는 요구다.
# 73       하지만 이를 위해선 해결해야할 문제들도 만만치 않다. 특히 앨범이 다르지만 같은 ...
# 76               하지만 이런 기술들을 개별적으로 공개를 하는 건 의미가 없다고 생각했죠.
# 82       아직은 가상비서로서의 기능이 떨어지기 때문입니다. 음악 재생은 AI스피커 입장에서...
# 86       무료 스티커 공개 이후 열흘 만에 만 다운로드 돌파. AMP 사용하는 전자상거래 ...
# 87                            가격은 만원대지만 국내에서는 구입 할 수가 없다.
#                               ...
# 6847                                                오류투성이
# 6849                                               로그인 안됌
# 6855                                                연결 안됨
# 6857                                                불편하네요
# 6859                                        꼭 로그인을 해야돼나요?
# 6872                                      예전보다 음성인식이 안되네요
# 6876                                             마음에안들어요.
# 6890                      로그인이 안 되네요 이거 어떻하죠????? 계속 그러네요
# 6897                                  저기요이거연결이잘안돼는데 하아...
# 6969    여기서 사는거 서비스센터갔더니 정품이아니고 등록도 안되어있다고 AS안됩니다. 그래서...
# 7027                                사운드는 보통 유인나 목소리지원은 안됨
# 7069                        와이파이 안쓰는집에서는 음알이끈기고 안좋네요 후회해요
# 7116     배송당일날 전화로 반품해준다고서 다음날 또 불가하다고 문자옴.상담은 왜하고 배송요...
# 7126    이거 엘지유플러스에 등록하려고하는데 자급제라고 등록이안된다고합니다. 이거정품이 아닌...
# 7172                                       그렇게 막 좋지는 않습니다
# 7228    판매에는 문제가없지만 클로바 자체가 문제가 많내요.언어전달도 잘안되고 사용언어 인식...
# 7234                                            !음성인식이늦어요
# 7263                              음질이 최악이네여 반품 귀찮 다시 사야할듯
# 7267     전 휴대폰이랑 연동이 되어 있어서 휴대폰에 소리가 들어가서 응답하는건 줄 알았는데...
# 7268    일단 물건 자체는 좋습니다.하지만 새 물건이 아닌건 확실한 거 같아요.클로바 바닥도...
# 7271    아직 적응중이라 별점 많이 못 주었네요클로바 하고 부르면 반응하는게 신기하긴 합니다...
# 7272    일단 소리는 풍부해서 좋습니다노트북 스피커로만 소리를 들어서 그렇게 느껴질 수도 있...
# 7305    기여워요 소리도 잘나고 말귀를 가끔 못알아듣지만 왠만하면 두번만에 알아들어요 ㅋㅋㅋ...
# 7339                                        라디오도 안돼고 별루에요
# 7341                   발음이 너무 빨라 알아들을 수가 없네요. 사자마자 후회됐는데.
# 7371                                       가끔 오류가 나서 불편해요
# 7376    저녁시완충해놓고아침시일어났는데베타리프로라말함.이렇게빨리다는건가요?전혀사용안함.언니네...
# 7381                       단 스티커가 오래됐는지 접착력이 없어서 자꾸 떼어져요.
# 7417    모든 리모컨 호환된다더니..ㅜ.ㅜ안되요.저희집 TV는 없네요.그래서 등록이 안되요....
# 7529                                   유플러스 티비와 연결이 안됩니다.
# Name: negative_text, Length: 2781, dtype: object

# %%
'blog.naver.com/ppang7942/'로 시작하는 url 페이지의 데이터 거르기

# %% [markdown]
# # <br>
# ## 클로바

# %% [markdown]
# <br/><br/>
# ### POS tagging하기

# %% [markdown]
# #### 1.  Komoran 사용

# %%
from konlpy.tag import Komoran

# %%
komoran = Komoran(userdic='./unregistered.txt')

# %%
import re

# 명사와 외래어만 뽑아내기위한 정규표현식
p = re.compile('NN.*|SL')

# %%
results = []
for i, brand_text in enumerate(clova_text):
    pos_tagging_list = list(map(komoran.pos, brand_text))
    print("pos tagging -", i)

    docs = []
    for doc in pos_tagging_list:
        want_words = [word for word, pos in doc if p.match(pos)]         
        docs.append(want_words)
    print("noun extract -", i)
    
    results.append(sum(docs, []))
    print("finish -", i)
# Out:
# pos tagging - 0
# noun extract - 0
# finish - 0
# pos tagging - 1
# noun extract - 1
# finish - 1

# %% [markdown]
# ### pickle로 일단 저장

# %%
import pickle
pickle.dump(results, open('tfidf_clova_list.pickle', "wb"))

# %%
load_result = pickle.load(open('tfidf_clova_list.pickle', "rb"))
results = load_result

# %% [markdown]
# <br/><br/>
# ### stopword 제거

# %%
stopwords = [line.strip() for line in open('./stopwordsKor.txt', encoding='utf-8')]

# %%
from tqdm import tqdm_notebook
stopword_dict = {}
for s_word in stopwords:
    stopword_dict[s_word] = 1

final_docs = []
for i, doc in enumerate(results):
    unique_NN_words = set(doc)
    final_NN_words = doc
    
    for word in tqdm_notebook(unique_NN_words):
        if stopword_dict.get(word):
            final_NN_words = list(filter(lambda x: x!= word, final_NN_words))
    final_docs.append(final_NN_words)
    print("finish -", i)
# Out:
# finish - 0
# finish - 1

# %% [markdown]
# <br/><br/>
# ### document별 단어들을 각각의 document로 바꾸기

# %%
documents = []
for doc_words in final_docs:
    document = " ".join(doc_words)
    documents.append(document)

# %%
documents[0][:200]
# Out:
# '직장인 김 모 미국 출장 당시 인공지능 AI 스피커 구글 홈 사 아내 아들 영어 공부 부탁 김 영어 유치원 아들 구글 홈 대화 학부모 조언 스피커 정보 확인 검색 음악 알람 아이 흥미 영어 사용 대학 강모 네이버 스피커 웨이브 이벤트 선물 내년 교환 학생 계획 강 웨이브 영어 회화 기능 활용 거란 강 네이버 번역 파파 활용 기본 회화 습득 활용 웨이브 대화'

# %%
documents[1]
# Out:
# '유선 래 연결 와이파이 연결 사용 음성 인식 스피커 일상 차지 역할 흐름 가운데 국내 업체 세계 시장 맥 지적 전문가 국내 업체 시장 확대 이유 길 지적 글 사기 기본 사례 네이버 카카오 날 하루 수준 카메라 인식 로그인 질문 마찬가지 대답 네이버 음악 듣기 결제 상태 지원 별도 이퀄라이저 설정 지하철역 자동차 추천 경로 검색 비교 효과 결과 근처 분식집 검색 질문 검색 결과 웨이브 탑재 리 마인 기능 질문 답 결론 시점 웨이브 자비스 한참 수준 가입자 게 목표 구글 홈 검색 엔진 구글 연동 정보 검색 판매량 공개 미국 시장 점유 중반 파악 인공지능 학습 데이터 서비스 존재 특정 기능 실현 단계 서비스 필요 생태계 변화 적응 번성 도태 종이 마련 네이버 진행 시범 판매 행사 국내 정식 판매 계획 입장 처음 구글 홈 북미 달러 여원 판매 회사 경쟁 현지 제휴 시장 격화 조짐 카카오톡 해외 진출 질문 국가 세컨드 메신저 의미 국가 메신저 전국 민이 플랫폼 게 국가 플랫폼 의미 계좌 개설 이모티콘 다운 설치 게 유통 파워 곳도 존재 국내 업체 카카오 네이버 린지 전만 모바일 메신저 사업 경쟁자 사업자 무한 경쟁 데이터 비용 말씀 거지 플랫폼 중립 플랫폼 중립 동일 선상 카카오 네이버 대표 교체 설 이야기 날짜 기업 생물 대화 대화 게 CEO 주년 소회 회사 성과 게 성과 길 업데이트 소프트웨어 업데이트 하드웨어 공급 준비 게 카메라 게 포털 카카오 시너지 내부 포털 사이트 매각 게 언급 사이트 포털 카카오 식 이름 논의 게 매각 논의 플랫폼 액션 필요 끝 액션 완결 카카오 베스트 카카오 브레인 투자 구조 당장 연결 계획 투자 논의 국회 고용 노동부 연결 권리 이야기 퇴근 연결 권리 의미 아 젠 다라 기술 활용 현재 시점 베타 타사 번역 서비스 번역 베타서비스 출시 모바일 웹 페이지 A B 번역 게 발전 부분 Q 기계 룰 베이스 A 질문 B 답 주시 노력 제지 이슈 게 논의 답 카카오 하루하루 생활 실무 하루하루 회의 이슈 해결 Q 수익 모델 시각 임 대표 시행착오 웹툰 웹 소설 기반 A 구글 어시스턴트 한국어 서비스 이날 국내 판매 시작 LG전자 스마트폰 V 시작 안드로이드 IT 공룡 경쟁 보니 웨이브 웨이브 반응 와이파이 연결 웨이브 연동 블루투스 연결 웨이브 뉴스 웨이브 웨이브 필요 이유 웨이브 안내 대로 네이버 영어 회화 강점 구글 어시스턴트 한국어 지원 시작 감안 메리트 공개 테스트 안드로이드 구글 구글 홈 출시 일정 확정 출시 매니저 구글 홈 한국 출시 계획 출시 현재 계획 의미 설명 역삼동 구글 코리아 본사 진행 구글 어시스턴트 데모 세션 혁 구글 테크니컬 프로그램 매니저 전산언어학 자인 최현정 구글 연구원 구글 어시스턴트 소개 구글 어시스턴트 LG전자 V 시작 안드로이드 스마트폰 확대 명령어 도 드릴 구글 어시스턴트 탑재 구글 홈 국내 정식 출시 지난달 안드로이드 폰 업데이트 다운로드 돌파 킹스 골든 서클 범죄도시 답 답 경쟁 통신사 제품군 출시 만회 라인업 강화 분석 인증 마크 분야 소비자 플랫폼 경험 한마디 로봇 팔 판매 물량 제한 웨이브 스피커 탑재 클로바 AI 입장 금 요구 해결 앨범 곡 중복 악의 해당 곡 점수 신곡 로그 분석 방법 한계 콘텐츠 기반 필터링 활용 기술 개별 공개 의미 가상 비서 기능 음악 재생 AI 스피커 입장 질의 음성 인식 음원 스트리밍 서비스 연결 돈 내야 사용자 곡 진미 사용 무료 스티커 공개 열흘 다운로드 돌파 AMP 사용 전자 상거래 웹사이트 구매 전환율 AMP 페이지 샹 가격 만원 대지 국내 구입 계약 기준 가구 확대 전망 기기 격차 정식 판매 시일 시작 내용 카카오 미니 아니야 전송 취소 현재 문자 전송 기능 질문 대답 음성 인식 차이 세상 존재 질문 음성 인식 차이 음원 콘텐츠 차이 인지 비용 면 웨이브 날씨 운세 주가 비교 간단명료 질문 제품 답변 차이 답변 이해 구동 클라우드 컴퓨팅 클라우드 서버 축적 이용자 대화 건수 기준 돌파 정형 어린이 음성 인식 개선 웨이브 카카오 미니 마이크 센서 장착 클로버 반응 발견 행사 가가 천원 셈 정가 천원 카카오 미니 정가 천원 정식 판매 시점 시행 행사 공개 소형 스피커 임 전원 연결 상태 최대 연속 사용 라이언 캐릭터 예약 구매자 지급 예약 판매 성적 영향 음성 인식 서비스 한국어 구사 능력 기본 오케이 구글 명령어 홈 버튼 소환 국내 트위터 이용자 자체 은어 비속어 자료 질 아마존 기업 에코 보급 테크 기업 반응 사용자 서비스 사투리 이해 어린아이 명령 이해도 인공지능 비서 기능 부가 수준 돈 서비스 차원 게 수준 웨이브 대비 프렌즈 스피커 상태 음악 감상 클로바 작동 실생활 기능 부족 명령 충전 배터리 방 음악 재생 영어 인식 팝송 검색 무리 노래 이때 클로바 곡 노래 오늘 날씨 정보 데이터베이스 부족 발음 테 고리 정보 분류 수준 과거 말귀 분식집 미미 분식 가게 인식 가게 떡볶이 집으로 분류 미미 분식 미미 분식 정보 근처 떡볶이 질문 미미 분식 인공지능 스피커 성표 인식 불편 아무도 구글 코리아 적극 부인 어린아이 수준 영어 조금 지원 기능 융통 구글 홈 미니 결론 당장 한국어 지원 부분 부분 생태계 확장 필요 시간문제 가요 카카오 미니 g 프렌즈 g 배터리 전원 연결 전용 어댑터 필요 외부 배터리 휴대 제품 흥 연극 티켓 쏜다 가격 천원 카카오 미니 출시 진행 예약 판매 한정 수량 정식 출시 분도 준비 물량 대가 아마존 측 이유 공개 웨이브 견제 해석 니혼게이자이신문 아마존 재팬 웨이브 판매 중단 출시 지난달 달 신제품 고려 이례 노래 제목 대답 프렌즈 프렌즈 라인 연동 쇼 머니 수준 듯 EXID 스트레스 해 질문 답 심술 바보 장난 프렌즈 노력 모니카 질문 Yes 대신 Yeah 대답 번역 완벽 내용 마디 대화 콘텐츠 제휴 부족 수초 간의 맥락 연결 호출 영어 대화 장점 대표 표제어 일자리 기본소득 반복 제기 경기도 화성시 만평 규모 조성 유튜브 페이스북 세 누가 이유 플랫폼 차원 경쟁력 스노우 매출 스노우 채 다운로드 다운로드 수치 작년 대비 약 가구 순 데이터 해결 프렌즈 대화 카카오 미니 캐럴 카카오 미니 현재 인터넷 국내 누적 판매량 돌파 제품 상태 카르 토도 요새 전술 가치 영국 스페인 연합군 공격 속사정 이때 총살 총검 기회 능력 쓸모 오은영 박사 글 육아 채널 검색 창 필요 구글 어시스턴트 한국인 안드로이드 폰 기반 서비스 파급 공산 스피커 목적 성공 지속 보장 구글 지난해 출시 제품 조사 대상 점유 확보 구글 홈 지난해 출시 해 분기 조사 집계 비트코인 한국 기업 해외 시장 매도 반박 존 리 구글 코리아 대표 이해진 의장 계속 국회 지적 페이스북 구글 한국 돈 얼마 트래픽 비용 세금 고용 유럽 미국 기업 살아남기 자국 기업 법 상황 세계 시장 국내외 기업 역차별 인터넷 업계 다국적 기업 구글 투명 매출 공개 세금 납부 요구 선발 주자 DB 구축 음성 인식 기술 자체 상대 꼬리표 빅스 비 국내 해외 이용자 만족 평가 구글 페이스북 해외 기업 국내 법 적용 세금 회피 네이버 카카오 차별 지적 가운데 네이버 공개 구글 비판 이해진 네이버 의장 국정 감사 페이스북 구글 한국 돈 액수 트래픽 비용 세금 고용 지적 조명 커튼 가습기 오프 OFF 상태 전환 한마디 기기 제어 이동 통신업 반발 성사 여부 불투명 일주일 남지 가운데 인증 절차 돌입 대학 태반 통신 사 단말기 자급 도입 찬성 하지 유통망 붕괴 우려 통신비 절감 효과 확인 이유 회의 제기 네이버 모바일 업데이트 검색 창 오른쪽 마이크 아이콘 사용 국내 최다 가상 화폐 거래 지원 거래소 회원 평균 이용자 동시 접속 윈도우 정품 인증 툴 KMSpico 홈페이지 툴 가상 화폐 채굴 악성 코드 승모 외숙모 절 공항 장애 공황 장애 네티즌 사이에서 맞춤법 파괴 빌 런 기능 동아 닷 컴 IT 전문 이상우 단독 공식 페이스북 핫 경제 슈와 재테크 방법 총집결 클릭 지난해 정식 판매 시작 대가 매진 음성 검색 트렌드 검색 결과 고도 필요 지적 제기 시일 상용 예상 자율 주행 자동차 인터페이스 음성 각광 이미지 검색 이용자 이름 검색 결과 제공 문자 기반 검색 이용자 검색어 자체 입력 검색 품질 클로바 질문 이용자 답 수준 저녁 클로바 질문 이해 답 오디오 재생 자체 AI  ...

# %% [markdown]
# <br/><br/>
# ### 벡터화 하기

# %%
from sklearn.feature_extraction.text import CountVectorizer     # 벡터 수 카운트 할 때

# %%
cv=CountVectorizer(max_df=0.60, max_features=20000, stop_words=stopwords)
# 문서 집합에서 단어 토큰을 생성하고 각 단어의 수를 세어 BOW(Bag Of Words) 인코딩한 벡터를 만든다.
# max_df=0.85란 말은 documents들에서 85%이상 나타나는 토큰(단어)를 무시하라는 것, 
# max_df=25란 말은 documents들에서 25번 이상 나타나는 토큰(단어)를 무시하라는 것,
# maximum 단어의 개수를 1만개로 정함 - 빈도수가 높은 단어 순으로 1만개를 자름(메모리 에러 안나려고)
# min_df=1, ngram_range=(1,1) 등은 default 값임  

word_count_vector=cv.fit_transform(documents)      # vectorize된 word_count_vector
feature_names=cv.get_feature_names()
# Out:
# /Users/Taewoo/anaconda2/envs/python36/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:301: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['_flash_removecallback', 'gyste7gb', 'kbs', 'mbc뉴스', 'news1', 'sbs', 'sbs화면캡처무기수', '무단', '전재'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %%
len(cv.vocabulary_)      # 위에서 max_features를 10000으로 주었지만 단어 수가 그 이하였음
# Out:
# 20000

# %%
cv.vocabulary_
# Out:
# {'출장': 16705,
#  '학부모': 18761,
#  '습득': 10969,
#  '조선일보': 15579,
#  'naver': 3130,
#  '왓슨': 12701,
#  'cc': 789,
#  '에이브': 11909,
#  '고의': 6102,
#  '인공신경망': 14202,
#  '스파크': 10930,
#  '김진형': 6877,
#  '정보기술': 15273,
#  'airi': 146,
#  '원장': 13113,
#  '김범수': 6801,
#  '어벤져스': 11752,
#  '코리': 17091,
#  '아선': 11368,
#  '민규': 8880,
#  '점프': 15210,
#  'ua': 5064,
#  '캡틴': 16979,
#  '아메리카': 11354,
#  '헐크': 19304,
#  '토르': 17606,
#  '팬서': 18065,
#  '닥터': 7365,
#  '스트레인지': 10916,
#  '눈앞': 7253,
#  '여종': 12056,
#  '원혁': 13140,
#  'aiot': 139,
#  '히어로': 19984,
#  '특장': 17824,
#  '수요처': 10729,
#  'tvskt': 5016,
#  '예정지': 12405,
#  '라운드': 7984,
#  '레노': 8043,
#  '확산': 19695,
#  '이통': 14132,
#  '성장세': 10385,
#  '광화문': 6328,
#  '사옥': 9898,
#  '설명회': 10333,
#  'vod': 5330,
#  '단장': 7391,
#  '최준': 16617,
#  '상무': 10065,
#  '종로구': 15705,
#  '놀이학습': 7212,
#  '연계': 12104,
#  '박명순': 8986,
#  '유닛': 13315,
#  '협업': 19440,
#  '막바지': 8346,
#  '촉진': 16575,
#  '야구': 11610,
#  '골프': 6146,
#  '오다': 12434,
#  '연례': 12133,
#  '대회': 7560,
#  'io': 2044,
#  '네스': 7118,
#  '감탄': 5695,
#  '윤곽': 13504,
#  '조리법': 15551,
#  '탐지': 17464,
#  '손짓': 10607,
#  '개막': 5770,
#  '신호탄': 11202,
#  '교감': 6331,
#  '주력': 15783,
#  '심혈': 11276,
#  'ott': 3339,
#  'abc': 13,
#  '파닉스': 17888,
#  '수학': 10763,
#  '가위바위보': 5600,
#  '상호작용': 10108,
#  '순발력': 10790,
#  '한영사전': 18970,
#  '주문형': 15795,
#  '비디오': 9749,
#  '스케줄': 10868,
#  '영아': 12297,
#  '융합기술원': 13545,
#  '상당수': 10059,
#  '출원': 16700,
#  '결말': 5923,
#  '동화책': 7813,
#  '극장': 6573,
#  '만개': 8350,
#  '조리': 15549,
#  '단말': 7375,
#  '서브': 10206,
#  '오락': 12454,
#  '만족감': 8374,
#  '원통형': 13131,
#  '신비': 11148,
#  '그래픽': 6543,
#  '포즈': 18267,
#  '입체감': 14515,
#  '퀘스트': 17222,
#  '스타크': 10889,
#  '세로': 10430,
#  '댄스': 7562,
#  'oled': 3308,
#  '퍼펙트': 18096,
#  '강조': 5749,
#  '전작': 15125,
#  '진일보': 16240,
#  '자유자재': 14618,
#  '절약': 15179,
#  '여가': 12000,
#  '이선희': 13898,
#  '매경': 8425,
#  'luxmen': 2693,
#  '제호': 15501,
#  '경품': 5995,
#  '뉴스레터': 7260,
#  '전재': 15127,
#  '배포': 9200,
#  'ptts': 3703,
#  'personalizedtext': 3455,
#  'speech': 4474,
#  '포터블': 18283,
#  '과도기': 6230,
#  '이점': 14045,
#  '필두': 18606,
#  '리스': 8218,
#  '점유율': 15200,
#  '미정': 8859,
#  '이기범': 13745,
#  '블로터': 9725,
#  '역량': 12081,
#  '사이버': 9915,
#  '저작권': 14960,
#  '강구': 5706,
#  '바이두': 8959,
#  '파고': 17878,
#  '관영': 6274,
#  '내수': 7075,
#  '장벽': 14770,
#  '언어권': 11804,
#  '공략': 6169,
#  'fcc': 1449,
#  '승인': 10985,
#  '안팎': 11506,
#  '타깃': 17367,
#  '처지': 16416,
#  '김성환': 6816,
#  'fn': 1494,
#  '파스': 17920,
#  '도지': 7673,
#  '혜미': 19475,
#  '가트너': 5626,
#  '예고': 12362,
#  '중심축': 15959,
#  '리츠': 8234,
#  '이마': 13802,
#  '가전사': 5609,
#  '연구소': 12112,
#  '커밍': 16991,
#  '갈무리': 5661,
#  '미디어렙': 8815,
#  '나스': 6968,
#  '대수': 7502,
#  '터치스크린': 17537,
#  '오인': 12553,
#  '오인하': 12554,
#  '정립': 15259,
#  '법률': 9269,
#  '준호': 15886,
#  '저변': 14947,
#  '활력': 19733,
#  'tvkt': 5011,
#  '대교': 7456,
#  '고심': 6086,
#  'lte': 2677,
#  '임미숙': 14450,
#  'hci': 1658,
#  '부연': 9579,
#  '댁내': 7561,
#  '변동': 9330,
#  '고위': 6098,
#  '노미': 7160,
#  'kfc': 2284,
#  '포스코': 18245,
#  '시뮬레이션': 11027,
#  '점퍼': 15209,
#  '하늘색': 18648,
#  '셔츠': 10482,
#  '흑인': 19932,
#  '헤드셋': 19311,
#  '월마트': 13154,
#  '신입': 11175,
#  '가상현실': 5576,
#  '전역': 15100,
#  '증강현실': 16021,
#  'ar': 298,
#  '이용한': 13993,
#  '정보통신기술': 15280,
#  'education': 1339,
#  'technology': 4753,
#  '패스트푸드': 18053,
#  '물류': 8773,
#  'ups': 5159,
#  '도심': 7655,
#  '돌발': 7711,
#  '포항': 18290,
#  '제철소': 15490,
#  '가열': 5593,
#  '강사': 5725,
#  '캠프': 16976,
#  '우아': 12935,
#  '참가자': 16356,
#  '입사': 14499,
#  '공채': 6213,
#  '근무': 6585,
#  '개발원': 5780,
#  '설립': 10330,
#  '삼성sds': 10011,
#  '삼성경제연구소': 10012,
#  '망치': 8413,
#  '삼성그룹': 10013,
#  '특급': 17802,
#  '수강': 10664,
#  '복습': 9464,
#  '미로': 8826,
#  '차장': 16326,
#  '밀레니얼': 8906,
#  '젊은층': 15190,
#  'mmorpg': 2944,
#  '동료': 7739,
#  '최고경영자': 16591,
#  '분담': 9622,
#  '부채': 9597,
#  '계약서': 6021,
#  '요소': 12807,
#  '상표': 10100,
#  'nlskrl': 3226,
#  '명칭': 8571,
#  '실체': 11243,
#  '이달': 13761,
#  '알리미': 11520,
#  '중추': 15999,
#  '원어민': 13099,
#  '대우건설': 7514,
#  '협약': 19439,
#  '리딩': 8201,
#  '기업가': 6707,
#  '형석': 19462,
#  '매매': 8433,
#  '증권사': 16025,
#  '기대감': 6670,
#  'report': 3900,
#  'briefing': 626,
#  '인포테인먼트': 14309,
#  'iviin': 2125,
#  'vehicle': 5286,
#  'infotainment': 1979,
#  'away': 404,
#  '이종': 14062,
#  '견인': 5918,
#  'pg': 3467,
#  '투자비': 17722,
#  '외형': 12778,
#  '성장률': 10383,
#  '하회': 18741,
#  'statistics': 4549,
#  'ktb': 2400,
#  '증시': 16035,
#  '전자신문': 15123,
#  'copyright': 1115,
#  '마이크로소프트': 8321,
#  '보크': 9438,
#  '격돌': 5906,
#  '상호': 10107,
#  'sktkt': 4313,
#  '양사': 11656,
#  '세질': 10459,
#  '외신': 12765,
#  '윈도': 13259,
#  '오피스': 12595,
#  '마이크로': 8319,
#  'alexa': 178,
#  'cortana': 1123,
#  '아웃룩': 11388,
#  '모건': 8572,
#  '스탠리': 10895,
#  '추산': 16643,
#  '막강': 8344,
#  '지위': 16134,
#  '비와': 9772,
#  '간담회': 5642,
#  '패트릭': 18055,
#  '부사장': 9554,
#  '피력': 18545,
#  '장이': 14813,
#  '정환': 15389,
#  '서유기': 10235,
#  '유일': 13414,
#  '석간': 10260,
#  '문화일보': 8765,
#  '정체': 15369,
#  '십수': 11279,
#  '울트론': 13016,
#  '어벤저스': 11751,
#  '중론': 15934,
#  '고유': 6099,
#  '만장': 8371,
#  '한나절': 18895,
#  '생산성': 10141,
#  '상층부': 10097,
#  '불평등': 9677,
#  '플리커': 18529,
#  'jorg': 2199,
#  'schubert': 4120,
#  '실험': 11248,
#  '미지수': 8861,
#  '촉발': 16574,
#  '작용': 14679,
#  '혼란': 19564,
#  '야기': 11613,
#  '제록스': 15415,
#  '성숙': 10366,
#  '발언': 9092,
#  'items': 2112,
#  '관심사': 6271,
#  '생활환경': 10162,
#  '송창': 10638,
#  'cto': 1160,
#  '엔터테인먼트': 11973,
#  'ivi': 2124,
#  'invehicle': 2031,
#  '주얼': 15818,
#  '화형': 19690,
#  '집결': 16273,
#  '머신': 8467,
#  '러닝': 8026,
#  '리서치': 8215,
#  '영입': 12319,
#  '책임자': 16406,
#  '간판': 5650,
#  '인간의': 14195,
#  '목격': 8635,
#  '퍼스트': 18090,
#  '세계로': 10409,
#  '순다': 10787,
#  '기조연설': 6734,
#  '이아이': 13955,
#  'bringing': 629,
#  'benefits': 502,
#  'of': 3289,
#  'everyone': 1413,
#  '모토': 8625,
#  '수립': 10686,
#  '전사': 15072,
#  '포부': 18235,
#  '기조': 6733,
#  '유명세': 13344,
#  '딥마인드': 7936,
#  '에이': 11905,
#  '기법': 6682,
#  '임무': 14449,
#  '대두': 7473,
#  '텐서': 17581,
#  '칩셋': 16852,
#  'tputensor': 4927,
#  'processing': 3665,
#  'unit': 5137,
#  'tpu': 4925,
#  '프로세서': 18461,
#  '일상생활': 14388,
#  '모회사': 8633,
#  '조직': 15651,
#  '먹거리': 8471,
#  '만능': 8353,
#  '커넥트': 16984,
#  'everything': 1414,
#  '파트너': 17970,
#  'inside': 1996,
#  '임지훈': 14471,
#  '추구': 16632,
#  '방향성': 9158,
#  '수입원': 10742,
#  '근간': 6577,
#  '운용': 12986,
#  '이동하': 13780,
#  '성형': 10401,
#  '제네시스': 15404,
#  '포스코건설': 18247,
#  'gs건설': 1623,
#  '체결': 16505,
#  '냉난방': 7097,
#  '자회사': 14658,
#  '이사회': 13865,
#  '분산': 9631,
#  '김병학': 6802,
#  '인류': 14219,
#  '유수': 13375,
#  '소셜': 10536,
#  '질병': 16262,
#  '저커버그': 14971,
#  '게시': 5893,
#  '하버드': 18673,
#  '디렉터': 7903,
#  'fair': 1434,
#  '실용': 11235,
#  '테크놀로지': 17572,
#  '현황': 19421,
#  '시사': 11035,
#  '스페이스': 10935,
#  '오즈': 12564,
#  '필터버블': 18619,
#  '테러': 17561,
#  '문헌': 8759,
#  '정보통신산업진흥원': 15281,
#  '정기간행물': 15239,
#  '정보통신정책연구원': 15282,
#  '반석': 9044,
#  '명기': 8540,
#  '업적': 11830,
#  '출사표': 16689,
#  '승산': 10981,
#  '서울경제': 10220,
#  '집사': 16280,
#  '영화에서처럼': 12345,
#  '이한': 14148,
#  '영토': 12332,
#  '승기': 10975,
#  'mashine': 2764,
#  'learning': 2482,
#  '개방': 5781,
#  '초창기': 16566,
#  '군웅': 6467,
#  '양상': 11659,
#  '철민': 16449,
#  '연재물': 12178,
#  '서경': 10178,
#  'cube': 1162,
#  '민선': 8885,
#  '포문': 18230,
#  'genie': 1582,
#  '맞불': 8417,
#  'line': 2586,
#  '박차': 9020,
#  '접점': 15222,
#  '이동성': 13773,
#  '이상호': 13887,
#  '탄생': 17430,
#  '여분': 12027,
#  '만엔': 8368,
#  '닷새': 7432,
#  '가정환경': 5610,
#  '명명': 8547,
#  '일부분': 14380,
#  '관전': 6281,
#  '연예': 12168,
#  '조이': 15622,
#  '캐스': 16955,
#  '통칭': 17681,
#  '잠정': 14718,
#  '부름': 9547,
#  '팅커벨': 17877,
#  '레베카': 8050,
#  '크리스탈': 17268,
#  '일평균': 14432,
#  '본문': 9487,
#  '전투': 15147,
#  '사무': 9874,
#  '미래상': 8822,
#  '뇌리': 7233,
#  '각인': 5635,
#  '자로': 14558,
#  '이목': 13815,
#  '원뿔': 13084,
#  '환상': 19713,
#  '두산': 7827,
#  '백과': 9202,
#  '문재인': 8748,
#  '오산': 12519,
#  '독창': 7701,
#  '예보': 12375,
#  '이튿날': 14138,
#  '강수': 5733,
#  '물음': 8784,
#  '배추': 9193,
#  '파종': 17957,
#  '납득': 7048,
#  '미흡': 8874,
#  '궁금증': 6481,
#  '언론사': 11799,
#  '본연': 9493,
#  '곡명': 6129,
#  '생존': 10151,
#  '박흥순': 9031,
#  '한국경제tv': 18808,
#  '김경민': 6771,
#  '추격': 16631,
#  '각축전': 5638,
#  '귀추': 6519,
#  '양강': 11640,
#  '구도': 6384,
#  '자와': 14608,
#  '여세': 12032,
#  '도전장': 7670,
#  '올가을': 12629,
#  '의사': 13677,
#  '자지': 14635,
#  '열풍': 12245,
#  '핫이슈': 19089,
#  'echo': 1325,
#  'lcd': 2469,
#  '후속작': 19860,
#  '활용도': 19738,
#  '괄목': 6294,
#  '파나소닉': 17884,
#  '베를린': 9287,
#  '국제가전박람회': 6451,
#  'ifa': 1896,
#  '잠재력': 14717,
#  '산적': 9982,
#  '도달': 7625,
#  '산도': 9957,
#  '배제': 9191,
#  '문지현': 8755,
#  '음식점': 13615,
#  '시중': 11066,
#  '특색': 17814,
#  '김기진': 6781,
#  '매경이코노미': 8426,
#  '동승': 7764,
#  '김승미': 6823,
#  '진격': 16215,
#  '쉬리': 10809,
#  '커스': 16995,
#  '위드': 13195,
#  '반포': 9066,
#  '주공': 15766,
#  '제안서': 15439,
#  '현관문': 19350,
#  '엘리베이터': 11982,
#  '박람회': 8984,
#  '밀레': 8905,
#  '지멘스': 16086,
#  '매개': 8422,
#  '연해': 12210,
#  '영수': 12291,
#  '전무': 15050,
#  '목적지': 8647,
#  '협의': 19441,
#  '지배력': 16094,
#  '선희': 10323,
#  'weconomy': 5385,
#  '한겨레신문': 18792,
#  '지성': 16103,
#  '마이크로소프트웨어': 8322,
#  '인사이트': 14234,
#  '셰어': 10485,
#  '에디터톤': 11854,
#  '위키': 13249,
#  '디아': 7915,
#  'kakaomini': 2239,
#  '중요도': 15982,
#  '원칙': 13127,
#  '협회': 19447,
#  '개최': 5803,
#  '페미니즘': 18119,
#  'edit': 1334,
#  'marathon': 2747,
#  '편집자': 18176,
#  '기부': 6686,
#  '준비물': 15880,
#  '분장': 9641,
#  '교육장': 6356,
#  '서울시': 10227,
#  '중구': 15911,
#  '태평로': 17515,
#  '태성': 17494,
#  '지참': 16154,
#  '참가비': 16355,
#  '수용': 10730,
#  '정원': 15320,
#  '신청서': 11186,
#  '박현정': 9028,
#  '혜정': 19483,
#  '판촉': 18005,
#  '전이': 15112,
#  '각사': 5633,
#  'vat': 5279,
#  'makers': 2730,
#  '맞대결': 8416,
#  '김태균': 6884,
#  '부가가치세': 9522,
#  '한정수': 18998,
#  '제보': 15424,
#  '모형': 8632,
#  '누리꾼': 7240,
#  'mutli': 3076,
#  '살충제': 10001,
#  '달걀': 7407,
#  '파동': 17891,
#  '비오': 9771,
#  '김건모': 6768,
#  'rain': 3803,
#  '시간대': 10996,
#  '모닝콜': 8583,
#  '안성맞춤': 11489,
#  '잔물결': 14692,
#  '미지': 8860,
#  '오대석': 12436,
#  '통로': 17658,
#  '발판': 9104,
#  '인종': 14272,
#  '외연': 12768,
#  '카카오택시': 16908,
#  '라이벌': 7989,
#  '영재': 12321,
#  '비즈': 9781,
#  '경향신문': 5996,
#  '도요타': 7660,
#  '제조사': 15479,
#  '개국': 5763,
#  '취약점': 16749,
#  '수단': 10677,
#  '합종연횡': 19082,
#  '폭스바겐': 18302,
#  '감당': 5671,
#  '구기자': 6381,
#  '황창규': 19773,
#  'mwc': 3087,
#  '전시장': 15089,
#  '노키아': 7185,
#  '콤비네이션': 17174,
#  '실리콘밸리': 11217,
#  'gs': 1619,
#  '샌프란시스코': 10124,
#  '레스': 8052,
#  '특파원': 17829,
#  '전략적': 15043,
#  '하운드': 18697,
#  'asr': 334,
#  'nlu': 3228,
#  '신현규': 11200,
#  '희영': 19964,
#  '유가증권': 13277,
#  '한경': 18793,
#  '글방': 6603,
#  '한국경제': 18807,
#  '부각': 9523,
#  '친밀감': 16814,
#  '절제': 15183,
#  '방영': 9140,
#  '외양': 12767,
#  '반향': 9068,
#  '흥행': 19953,
#  '신청자': 11187,
#  '귀띔': 6507,
#  '친근감': 16812,
#  '홍익대': 19615,
#  '리나': 8194,
#  '친밀': 16813,
#  '춘추전국시대': 16677,
#  '시애틀': 11053,
#  '카카오i': 16905,
#  '가인': 5603,
#  '서희': 10257,
#  '한국일보': 18857,
#  '토요': 17624,
#  '패권': 18035,
#  '출발점': 16688,
#  '관심거리': 6269,
#  '저울': 14957,
#  'tviptv': 5010,
#  '고동진': 6049,
#  '부장': 9587,
#  '직후': 16212,
#  '하만': 18666,
#  '방위': 9142,
#  '전장': 15126,
#  '공조': 6208,
#  '장형': 14842,
#  '연평균': 12195,
#  '원로': 13072,
#  'idc': 1871,
#  '통신망': 17665,
#  'ap': 265,
#  '두뇌': 7820,
#  '기린': 6677,
#  '고용량': 6095,
#  '호황': 19557,
#  '바가': 8927,
#  '어치': 11774,
#  '게라': 5888,
#  '송금': 10619,
#  '세제': 10454,
#  'sk플래닛': 4331,
#  '아바타': 11361,
#  'sm': 4357,
#  '한류': 18918,
#  '일환': 14438,
#  '빅뱅': 9796,
#  '원년': 13061,
#  '김성규': 6811,
#  'voda': 5331,
#  '갈래': 5656,
#  '출격': 16680,
#  '양쪽': 11689,
#  '첫발': 16465,
#  '계기': 6006,
#  '박희진': 9032,
#  '월스트리트저널': 13157,
#  '칼럼니스트': 16939,
#  '모스': 8604,
#  'walt': 5364,
#  'mossberg': 2998,
#  '포식': 18254,
#  '메디아': 8486,
#  '패러다임': 18041,
#  '출간': 16678,
#  '담론': 7423,
#  '전시회': 15090,
#  'phillips': 3477,
#  'miele': 2891,
#  'siemens': 4261,
#  '전인': 15113,
#  'mobile': 2957,
#  'first': 1483,
#  '지형': 16184,
#  '초래': 16539,
#  '단기간': 7370,
#  '폭풍': 18310,
#  '승리': 10978,
#  '편재': 18169,
#  'ubiquity': 5070,
#  '간파': 5649,
#  '왕좌': 12726,
#  'voice': 5333,
#  '함의': 19056,
#  '뉴시스': 7264,
#  'msi': 3037,
#  '시세표': 11043,
#  '한때': 18911,
#  '자가': 14528,
#  '큐어': 17229,
#  '내달': 7064,
#  '확충': 19700,
#  '행진': 19243,
#  'cbs': 786,
#  '노컷뉴스': 7183,
#  '소진하': 10565,
#  '장보기': 14775,
#  'mbn': 2793,
#  '자문': 14570,
#  '박철': 9024,
#  'cjpark': 906,
#  '차익': 16325,
#  '동동': 7736,
#  '잉크': 14524,
#  '마르지': 8285,
#  '마진': 8330,
#  '카트': 16918,
#  '스포츠경향': 10941,
#  '닮은꼴': 7422,
#  '촉각': 16569,
#  '야마하': 11617,
#  '디지털타임스': 7925,
#  '김수연': 6820,
#  '전초전': 15146,
#  'nhk': 3208,
#  'ntt': 3260,
#  '코모': 17098,
#  '대동소이': 7472,
#  '진영': 16239,
#  '도요타자동차': 7661,
#  '패밀리마트': 18047,
#  '승패': 10991,
#  '섹션': 10467,
#  '입증': 14512,
#  '실시': 11231,
#  '로엔엔터테인먼트': 8117,
#  '키트': 17348,
#  '계발': 6012,
#  '전래': 15040,
#  '이솝': 13910,
#  '우화': 12971,
#  '주제가': 15842,
#  '태교': 17479,
#  '다변': 7321,
#  '강정수': 5748,
#  '어린': 11735,
#  '식료품': 11101,
#  '식구': 11092,
#  '요리법': 12796,
#  '브라이언': 9691,
#  '실린더': 11219,
#  '결성': 5927,
#  '오자': 12556,
#  '예금': 12363,
#  '해방': 19149,
#  '우후죽순': 12973,
#  '단답': 7371,
#  '프라이버시': 18427,
#  '해법': 19151,
#  '이대호': 13767,
#  '초청': 16567,
#  '취임': 16751,
#  '근원': 6590,
#  '할애': 19040,
#  '청사진': 16484,
#  '일문일답': 14371,
#  'cxo': 1174,
#  '송지호': 10637,
#  '체질': 16522,
#  '독단': 7688,
#  '크루': 17263,
#  '통상': 17661,
#  '경영진': 5974,
#  '텐센트': 17582,
#  '모빌리티': 8599,
#  '관점': 6283,
#  '포도': 18219,
#  '카카오페이지': 16909,
#  '조율': 15618,
#  '로망': 8093,
#  '사인': 9920,
#  '어비스': 11755,
#  '퍼블리싱': 18087,
#  '이진수': 14089,
#  'bm': 559,
#  '코어': 17123,
#  '역풍': 12096,
#  '남궁훈': 7016,
#  '빅딜': 9794,
#  '막판': 8348,
#  '철학': 16457,
#  '벤처': 9312,
#  '금융사': 6625,
#  '은행업': 13582,
#  '마한': 8343,
#  '위기의식': 13190,
#  '로드맵': 8091,
#  '드라이브': 7855,
#  '콘트롤': 17156,
#  '타워': 17387,
#  '리드': 8199,
#  '이노베이션': 13754,
#  '구조도': 6415,
#  '한국기원': 18822,
#  '교류': 6337,
#  '보도자료': 9387,
#  '방송사': 9133,
#  '반론': 9040,
#  '운동장': 12976,
#  '토탈': 17634,
#  '싸움': 11288,
#  '특혜': 17833,
#  '견해': 5922,
#  '저장소': 14965,
#  'gpu': 1606,
#  '공해': 6223,
#  '유의미': 13409,
#  '대략': 7475,
#  '해나': 19125,
#  '기자회견': 6725,
#  '면담': 8519,
#  '취조실': 16754,
#  '쇼파': 10659,
#  '허심탄회': 19281,
#  '하나라': 18634,
#  '연임': 12174,
#  '주총': 15853,
#  '리소스': 8217,
#  '파킹': 17966,
#  '중시': 15954,
#  '냉정': 7105,
#  '즐거움': 16017,
#  '만약': 8367,
#  '정체성': 15370,
#  '정통': 15376,
#  '공헌': 6224,
#  '위챗': 13243,
#  '릴레이': 8258,
#  '콘셉트': 17149,
#  '큐브': 17227,
#  '후진': 19877,
#  '런닝': 8037,
#  '대면': 7485,
#  '컨퍼런스': 17025,
#  '주관': 15767,
#  '단락': 7374,
#  '당부': 7440,
#  '금지법': 6631,
#  '프레이밍': 18449,
#  '특정시': 17825,
#  '데스크': 7603,
#  '동남아': 7731,
#  '보더': 9386,
#  '자카르타': 14646,
#  '다국어': 7299,
#  '예의': 12400,
#  '명분': 8550,
#  '빌더': 9809,
#  '예능': 12367,
#  '모스트': 8605,
#  '포퓰러': 18289,
#  'dri': 1289,
#  '심층': 11270,
#  '과장': 6239,
#  '우상': 12923,
#  '가사도': 5573,
#  '우미': 12918,
#  '오리지널': 12484,
#  '오브': 12514,
#  '자국민': 14537,
#  '저금리': 14935,
#  '허무': 19271,
#  '점진': 15207,
#  '각축': 5637,
#  '프랑스어': 18434,
#  '포르투갈어': 18226,
#  '힌디어': 19992,
#  '인도네시아어': 14213,
#  '디스코': 7913,
#  '레이지': 8067,
#  '명암': 8558,
#  '달리기': 7412,
#  '도봉구': 7649,
#  '허지': 19293,
#  '미술관': 8839,
#  '큐레이터': 17224,
#  '개인의': 5791,
#  '피로': 18546,
#  'filter': 1469,
#  'bubble': 659,
#  '임현석': 14482,
#  '무형': 8725,
#  '수급': 10670,
#  '난제': 7011,
#  '직면': 16196,
#  '실감': 11209,
#  '성황': 10404,
#  '리에': 8226,
#  '한정판': 18999,
#  '피겨': 18531,
#  '항이': 19115,
#  '양국': 11642,
#  'skcc': 4301,
#  '만발': 8358,
#  '일종': 14420,
#  '한국ibm': 18798,
#  '한국판': 18884,
#  '활용법': 19739,
#  '성향': 10400,
#  '기아자동차': 6703,
#  '어인': 11766,
#  '박지영': 9017,
#  '다기능': 7302,
#  'good': 1599,
#  '온대': 12611,
#  '미련': 8825,
#  '달력': 7410,
#  '고구마': 6036,
#  '용례': 12847,
#  '한라산': 18914,
#  '강수량': 5734,
#  '삼촌': 10042,
#  '고무장갑': 6066,
#  '편지': 18172,
#  '감미': 5677,
#  '사심': 9892,
#  'iu': 2121,
#  '이경은': 13722,
#  '다용도': 7336,
#  '읽기': 14439,
#  '장충동': 14830,
#  '평안도': 18189,
#  '평양': 18190,
#  'ddp': 1198,
#  '주식회사': 15813,
#  'csmo': 1155,
#  '리진': 8232,
#  '반칙': 9063,
#  '작별': 14668,
#  '김인경': 6850,
#  '가용': 5596,
#  '격변': 5909,
#  '김유성': 6841,
#  '특유': 17821,
#  '시연회': 11058,
#  '연중': 12184,
#  '수록': 10684,
#  '띄어쓰기': 7957,
#  '역동': 12080,
#  '양의': 11674,
#  '판도': 17990,
#  '버락': 9239,
#  ...}

# %% [markdown]
# <br/><br/>
# ### TF-IDF 적용
# - TF * IDF는 특정 문서 내에서 단어 빈도가 높을수록, 전체 문서들에는 그 단어를 포함한 문서가 적을수록 TF * IDF값이 높아지는 특징이 있다.
# - 이러한 특징을 이용해서 모든 문서에 나타나는 흔한 단어들을 걸러내며, 특정 단어가 가지는 중요도를 측정하는 데 사용된다.
# - 한마디로 TF * IDF 값은 특정 단어가 가지는 중요도!
# - TF(Term Frequency): 단어 빈도
#    - 해당 문서에서 단어가 나타나는 빈도수
#    - 문서의 길이가 길면 해당 단어의 실제 중요도와는 상관없이 단어의 빈도수는 증가될 확률이 높다.
#    - 위의 문제를 해결하기 위해 다음과 같이 표준화 -> (문서에서 단어가 나타나는 빈도수) / (모든 단어가 나타나는 빈도수)
# - IDF(Inverse Document Frequency): 역문헌 빈도
#    - 해당 단어의 일반적인 중요도를 나타내는 값
#    - log( 전체 문서의 수 / 해당 단어가 포함된 문서들의 수 )

# %%
komoran.pos("번개장터")
# Out:
# [('번개장터', 'NNG')]

# %%
from sklearn.feature_extraction.text import TfidfTransformer    # Tf * idf 구할 때

# %%
tfidf_transformer=TfidfTransformer(smooth_idf=True,use_idf=True)        # Tf-idf 가중치를 적용할 수 있도록 변환시켜줌
tf_idf_matrix = tfidf_transformer.fit_transform(word_count_vector)

feature_names=cv.get_feature_names()

dense = tf_idf_matrix.todense()

for i in range(len(dense)):
    doc = dense[i].tolist()[0]           # dense[i].tolist()는 2차원 list, 예를들면 shape: (1,814)
    phrase_scores = [pair for pair in zip(range(0, len(doc)), doc) if pair[1] > 0]      # 0의 값이 아닌것만 모아서 만듦

    sorted_phrase_scores = sorted(phrase_scores, key=lambda t: t[1], reverse=True) # sorted(phrase_scores, key=lambda t: t[1] * -1)라고 해도 됨
    for phrase, score in [(feature_names[word_id], score) for (word_id, score) in sorted_phrase_scores][:20]:
        print('{0: <20} {1}'.format(phrase, score))      # 단어와 단어의 tf-idf 값을 출력
    print()
    ##### 이 부분은 테스트를 위해서 #####
    if i == 3:     
        break
    ###############################
# Out:
# 배포                   0.27243329240656544
# 전재                   0.2429411903869102
# 오디오북                 0.1961224784307075
# 협업                   0.16441846875957808
# 연계                   0.15815139708040132
# led                  0.14598590499729355
# 강조                   0.12460413103304348
# 파트너                  0.11686245425288397
# vod                  0.11575650042714689
# 저작권                  0.10469696216977617
# ces                  0.10248505451830203
# 자회사                  0.10137910069256495
# ybm                  0.09732393666486236
# 장터                   0.0954806802886339
# 전자신문                 0.09400607518765114
# 번개                   0.0921628188114227
# 알리미                  0.09179416753617699
# lte                  0.08515844458175456
# 개방                   0.08442114203126318
# 개최                   0.08331518820552611
#
# timestamp            0.24214029368137843
# 조곤                   0.24214029368137843
# datetime             0.20178357806781538
# plc                  0.20178357806781538
# 황치열                  0.20178357806781538
# 뉴트리라이트               0.1614268624542523
# findxa               0.12107014684068922
# typeday              0.12107014684068922
# 갈리아                  0.12107014684068922
# 류준열                  0.12107014684068922
# 성냥                   0.12107014684068922
# 썰매                   0.12107014684068922
# 장식물                  0.12107014684068922
# 풍이                   0.12107014684068922
# duke                 0.08071343122712615
# freqnone             0.08071343122712615
# isbn                 0.08071343122712615
# iymd                 0.08071343122712615
# redemption           0.08071343122712615
# tdatetime            0.08071343122712615

# %% [markdown]
# # <br>
# ## 카카오

# %% [markdown]
# <br/><br/>
# ### POS tagging하기

# %% [markdown]
# #### 1.  Komoran 사용

# %%
from konlpy.tag import Komoran

# %%
komoran = Komoran(userdic='./unregistered.txt')

# %%
import re

# 명사와 외래어만 뽑아내기위한 정규표현식
p = re.compile('NN.*|SL')

# %%
results = []
for i, brand_text in enumerate(kakao_text):
    pos_tagging_list = list(map(komoran.pos, brand_text))
    print("pos tagging -", i)

    docs = []
    for doc in pos_tagging_list:
        want_words = [word for word, pos in doc if p.match(pos)]         
        docs.append(want_words)
    print("noun extract -", i)
    
    results.append(sum(docs, []))
    print("finish -", i)
# Out:
# pos tagging - 0
# noun extract - 0
# finish - 0
# pos tagging - 1
# noun extract - 1
# finish - 1

# %% [markdown]
# ### pickle로 일단 저장

# %%
import pickle
pickle.dump(results, open('tfidf_kakao_list.pickle', "wb"))

# %%
load_result2 = pickle.load(open('tfidf_kakao_list.pickle', "rb"))
results = load_result2

# %% [markdown]
# <br/><br/>
# ### stopword 제거

# %%
stopwords = [line.strip() for line in open('./stopwordsKor.txt', encoding='utf-8')]

# %%
from tqdm import tqdm_notebook
stopword_dict = {}
for s_word in stopwords:
    stopword_dict[s_word] = 1

final_docs = []
for i, doc in enumerate(results):
    unique_NN_words = set(doc)
    final_NN_words = doc
    
    for word in tqdm_notebook(unique_NN_words):
        if stopword_dict.get(word):
            final_NN_words = list(filter(lambda x: x!= word, final_NN_words))
    final_docs.append(final_NN_words)
    #print("finish -", i)

# %% [markdown]
# <br/><br/>
# ### document별 단어들을 각각의 document로 바꾸기

# %%
documents = []
for doc_words in final_docs:
    document = " ".join(doc_words)
    documents.append(document)

# %%
documents[0][:200]
# Out:
# '이해인 카카오 미니 확인 전송 가능 네이버 웨이브 음악 서비스 당 결제 카카오 미니 출시 추석 연휴 예고 국내 인터넷 서비스 투 톱 AI 인공지능 스피커 경쟁 카카오 카카오 미니 네이버 웨이브 예약 판매 분도 채 준비 물량 소진 관심 몸 상황 웨이브 네이버 기술력 기반 음성 인식 출력 스피커 장점 카카오 미니 국내 최적화 서비스 무장 기본 제품 음성 명령 '

# %% [markdown]
# <br/><br/>
# ### 벡터화 하기

# %%
from sklearn.feature_extraction.text import CountVectorizer     # 벡터 수 카운트 할 때

# %%
cv=CountVectorizer(max_df=0.85, max_features=20000, stop_words=stopwords)     
# 문서 집합에서 단어 토큰을 생성하고 각 단어의 수를 세어 BOW(Bag Of Words) 인코딩한 벡터를 만든다.
# max_df=0.85란 말은 documents들에서 85%이상 나타나는 토큰(단어)를 무시하라는 것, 
# max_df=25란 말은 documents들에서 25번 이상 나타나는 토큰(단어)를 무시하라는 것,
# maximum 단어의 개수를 1만개로 정함 - 빈도수가 높은 단어 순으로 1만개를 자름(메모리 에러 안나려고)
# min_df=1, ngram_range=(1,1) 등은 default 값임  

word_count_vector=cv.fit_transform(documents)      # vectorize된 word_count_vector
feature_names=cv.get_feature_names()
# Out:
# /Users/Taewoo/anaconda2/envs/python36/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:301: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['_flash_removecallback', 'gyste7gb', 'kbs', 'mbc뉴스', 'news1', 'sbs', 'sbs화면캡처무기수', '무단'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %%
len(cv.vocabulary_)      # 위에서 max_features를 10000으로 주었지만 단어 수가 그 이하였음
# Out:
# 20000

# %%
cv.vocabulary_
# Out:
# {'이해인': 14595,
#  '예고': 13110,
#  '무장': 9235,
#  '외출': 13445,
#  '사용성': 10256,
#  '물리': 9289,
#  '고사': 6904,
#  '만화': 8943,
#  '치어리더': 17271,
#  '레이싱': 8657,
#  '헤르츠': 19448,
#  '전략적': 15421,
#  '음폭': 14165,
#  '현장감': 19524,
#  '음역': 14159,
#  '프로세서': 18698,
#  '고음': 6924,
#  '감시': 6572,
#  '손상': 10962,
#  '극장': 7356,
#  '이기범': 14262,
#  '블로터': 10087,
#  '아카데미': 12164,
#  '역량': 12873,
#  '진화': 16590,
#  '사이버': 10268,
#  '귀사': 7307,
#  'cbs': 566,
#  '노컷뉴스': 7854,
#  '김수영': 7565,
#  '네모': 7799,
#  '상당수': 10413,
#  'goodhertz': 1749,
#  'tm': 3974,
#  '하만카돈': 18889,
#  'ch': 608,
#  '레인지': 8664,
#  '드라이버': 8469,
#  '증강': 16333,
#  '시브': 11610,
#  '에이': 12712,
#  'passive': 2953,
#  'radiator': 3246,
#  '유닛': 13916,
#  'general': 1666,
#  '어도비': 12539,
#  'adobe': 58,
#  '응답자': 14175,
#  '재미': 15256,
#  '주식회사': 16132,
#  '커넥트': 17449,
#  '관광': 7066,
#  '명소': 9104,
#  '플러그인': 18744,
#  '에이전시': 12723,
#  '의뢰': 14193,
#  '여자친구': 12854,
#  '광화문': 7131,
#  '걷기': 6715,
#  '상권': 10408,
#  '단발': 8037,
#  '복수': 9864,
#  '관이': 7086,
#  '입장료': 14915,
#  '윤정희': 14093,
#  '만족도': 8935,
#  '디지털타임스': 8534,
#  '연중': 12966,
#  '풀뿌리': 18625,
#  '내자': 7768,
#  '강구': 6591,
#  '조짐': 16000,
#  '바이두': 9440,
#  '장악': 15187,
#  '파급': 18225,
#  '내수': 7758,
#  '장벽': 15167,
#  '장애물': 15190,
#  '언어권': 12625,
#  '언론': 12620,
#  'fcc': 1448,
#  '승인': 11537,
#  '안팎': 12274,
#  '타깃': 17776,
#  '처지': 16807,
#  '김성환': 7562,
#  '스쿨': 11374,
#  'fn': 1528,
#  '파이낸셜뉴스': 18268,
#  '도지': 8307,
#  '혜미': 19584,
#  '기관': 7431,
#  '가트너': 6516,
#  '클라우드': 17711,
#  '가전제품': 6503,
#  '중심축': 16268,
#  '리츠': 8808,
#  '생태계': 10510,
#  '점유율': 15575,
#  '이마': 14317,
#  '가전사': 6501,
#  '연구소': 12900,
#  '커밍': 17456,
#  '미디어렙': 9320,
#  '나스': 7673,
#  '터치스크린': 17916,
#  '레노버': 8636,
#  'lg유플러스': 2572,
#  'uai': 4118,
#  '어벤져스': 12565,
#  '마블': 8860,
#  '오인': 13268,
#  '첨단': 16881,
#  '오인하': 13269,
#  '이어': 14445,
#  '법률': 9699,
#  '정보기술': 15649,
#  '비결': 10097,
#  '오디오북': 13183,
#  '대교': 8101,
#  '아람': 12043,
#  '출판사': 17199,
#  '놀이학습': 7873,
#  '옥수수': 13319,
#  '가까이': 6442,
#  '박명순': 9462,
#  '자녀': 14960,
#  '가정주부': 6504,
#  '월트': 13795,
#  '디즈니': 8530,
#  '컴퍼니': 17499,
#  '엔드': 12764,
#  '아이언맨': 12130,
#  '헐크': 19441,
#  '재산권': 15266,
#  '박차': 9479,
#  '아울북': 12105,
#  '결말': 6771,
#  '유명': 13941,
#  '무궁무진': 9200,
#  '조원': 15969,
#  '이경': 14243,
#  '유목민': 13943,
#  'vibe': 5316,
#  '개인의': 6658,
#  '저격': 15314,
#  '패턴': 18373,
#  '포부': 18520,
#  '방랑': 9570,
#  '청취': 16939,
#  '산이': 10326,
#  '코리안': 17549,
#  '일원': 14825,
#  '축적': 17159,
#  '노하우': 7857,
#  '다변': 7979,
#  '자처': 15042,
#  '어스': 12576,
#  'airs': 123,
#  '체감': 16947,
#  '함정': 19231,
#  '연관': 12896,
#  '단추': 8049,
#  '원리': 13721,
#  '필터링': 18843,
#  'collaborative': 752,
#  'filter': 1483,
#  'learning': 2553,
#  '추출': 17149,
#  '번복': 9680,
#  '적중': 15376,
#  '호언': 19623,
#  '신뢰도': 11756,
#  '액션': 12390,
#  'lp': 2617,
#  '발굴': 9525,
#  '즉각': 16323,
#  '장범준': 15166,
#  '노래방': 7830,
#  '후렴': 19884,
#  '안목': 12240,
#  '좋아': 16062,
#  '고르고': 6891,
#  '금물': 7384,
#  '적도': 15362,
#  'bgm': 439,
#  '무용': 9231,
#  'ivi': 2279,
#  '김인경': 7582,
#  '귀성': 7308,
#  '이데일리': 14287,
#  '김유성': 7579,
#  '주현미': 16183,
#  '짝사랑': 16651,
#  '눈빛': 7908,
#  '행선지': 19378,
#  '게이': 6742,
#  '드라이브': 8470,
#  '원내': 13711,
#  '벙어리': 9709,
#  '외신': 13439,
#  'ui': 4145,
#  '환경로': 19767,
#  '비즈니스': 10148,
#  '인사이더': 14678,
#  '대결': 8098,
#  '사이더': 10266,
#  '원조': 13762,
#  'amazon': 172,
#  'echo': 1212,
#  '홈오토메이션': 19677,
#  '스팟': 11461,
#  'spot': 3683,
#  '파이어': 18275,
#  '핫이슈': 19267,
#  '체험기': 16983,
#  '지식': 16416,
#  '화제': 19745,
#  '예능': 13116,
#  '비행': 10159,
#  '출연진': 17187,
#  '아유미': 12110,
#  '보에': 9824,
#  '출연자': 17186,
#  '싱글': 11957,
#  '외로움': 13431,
#  '말동무': 8948,
#  '샤프': 10527,
#  '로보': 8689,
#  '베스트': 9718,
#  '에몽가': 12675,
#  '우스갯소리': 13599,
#  '형성': 19574,
#  '좋은': 16064,
#  '포탈': 18551,
#  '호흡': 19649,
#  '이태원역': 14579,
#  '대중교통': 8178,
#  '강수': 6608,
#  '남한산성': 7734,
#  '이병헌': 14348,
#  '출연': 17185,
#  '줄거리': 16204,
#  '문법': 9259,
#  '초록': 17005,
#  '수초': 11174,
#  '개천절': 6666,
#  '캘린더': 17436,
#  '텔레비전': 17960,
#  '묵묵부답': 9247,
#  '역부족': 12875,
#  '마스': 8872,
#  '책임자': 16792,
#  '야심작': 12438,
#  '맹하': 9021,
#  '한국일보': 19058,
#  '로맨틱': 8686,
#  '코미디': 17555,
#  '중추': 16306,
#  '성숙': 10689,
#  '주년': 16098,
#  '즈음': 16322,
#  '통신업체': 18026,
#  '애완동물': 12368,
#  '이보': 14350,
#  '현대자동차': 19496,
#  '벤처기업': 9732,
#  '유도': 13919,
#  '메르세데스': 9050,
#  '벤츠': 9733,
#  '애플리케이션': 12380,
#  '형주': 19578,
#  '세계일보': 10730,
#  '포문': 18518,
#  'kb': 2390,
#  '국민은행': 7241,
#  '인원': 14700,
#  '계좌': 6865,
#  '매거진': 8976,
#  '걸림돌': 6719,
#  '보안과': 9821,
#  '근거리': 7361,
#  '미터': 9365,
#  '쌍둥이': 11976,
#  '취지': 17239,
#  '향상': 19395,
#  '연예': 12949,
#  '조이': 15974,
#  '박성훈': 9469,
#  'cic': 654,
#  '신원': 11812,
#  '공동대표': 6987,
#  '서울대': 10575,
#  '학과': 18955,
#  '베인': 9726,
#  '보스턴': 9817,
#  '컨설팅': 17475,
#  '컨설턴트': 17474,
#  '부사장': 9946,
#  '역임': 12884,
#  '합류': 19239,
#  'cso': 895,
#  'ma': 2640,
#  '임직원': 14875,
#  '시너지': 11573,
#  '밑그림': 9407,
#  '설립': 10655,
#  '유효': 14056,
#  '창출': 16763,
#  '겸임': 6786,
#  'ciccompany': 656,
#  'company': 772,
#  '이준호': 14531,
#  '사업부': 10246,
#  '복안': 9868,
#  '총괄': 17055,
#  '자문': 14982,
#  '군사': 7268,
#  '증시': 16348,
#  '호조세': 19632,
#  '궤도': 7298,
#  '강세': 6606,
#  '나스닥': 7674,
#  '상승세': 10431,
#  'sk하이닉스': 3567,
#  '반도체': 9493,
#  '바이오': 9444,
#  '유럽연합': 13930,
#  'eu': 1358,
#  '선진국': 10644,
#  '부양': 9961,
#  '각국': 6520,
#  '점진': 15580,
#  '대치': 8185,
#  '지정학': 16453,
#  '부각': 9925,
#  '긴축': 7527,
#  '신흥': 11864,
#  '매수': 8993,
#  '감내': 6560,
#  '조정': 15983,
#  '당주': 8093,
#  '막바지': 8914,
#  '랠리': 8614,
#  '배제': 9633,
#  '현명': 19506,
#  '투자가': 18077,
#  '자수': 14999,
#  'live': 2593,
#  '독점': 8325,
#  '전문은행': 15436,
#  '우상': 13586,
#  '체크': 16979,
#  '수상': 11105,
#  '경력': 6796,
#  '주간': 16079,
#  '입상': 14904,
#  '한경': 19003,
#  '글방': 7374,
#  '한국경제': 19015,
#  '정면': 15634,
#  '승부': 11527,
#  '서울경제': 10572,
#  '승부수': 11529,
#  '병아리': 9782,
#  '형상화': 19573,
#  'mah': 2648,
#  '만엔': 8930,
#  '저울': 15338,
#  '편의': 18465,
#  '싸움': 11966,
#  '지민': 16397,
#  '구기자': 7177,
#  '대한민국': 8195,
#  '과학자': 7061,
#  '연재물': 12960,
#  '서경': 10532,
#  'cube': 910,
#  '이승우': 14426,
#  '에브리': 12685,
#  '슬로건': 11502,
#  '접점': 15595,
#  '시각': 11552,
#  '이드': 14299,
#  '제네시스': 15773,
#  'gs건설': 1806,
#  '포스코건설': 18525,
#  '롯데정보통신': 8737,
#  '곳곳': 6969,
#  '브레인': 10067,
#  '이사회': 14369,
#  '진두지휘': 16544,
#  '응용': 14180,
#  '머신': 9025,
#  '분산': 10010,
#  '럭스': 8630,
#  '웹툰': 13816,
#  '엔터테인먼트': 12775,
#  '재팬': 15294,
#  '조정연': 15986,
#  '합종연횡': 19260,
#  '양해각서': 12521,
#  'mou': 2763,
#  '체결': 16949,
#  '여름철': 12819,
#  '생활양식': 10517,
#  '소모품': 10840,
#  '김병학': 7554,
#  '연합전선': 12984,
#  '가습기': 6479,
#  '금호타이어': 7405,
#  'wp': 6361,
#  'ws': 6366,
#  'kw': 2531,
#  '아이젠': 12133,
#  'rv': 3429,
#  'kc': 2396,
#  '후속': 19899,
#  '세단': 10735,
#  '설계': 10651,
#  '승차': 11544,
#  '감과': 6558,
#  'suv': 3794,
#  '내구': 7746,
#  '비대칭': 10107,
#  '빙판': 10185,
#  '세탁기': 10782,
#  'ls전선': 2628,
#  '해상': 19320,
#  '풍력': 18639,
#  '해저': 19341,
#  '로드아일랜드': 8681,
#  '앞바다': 12341,
#  '건설': 6703,
#  '육지': 14075,
#  '송전': 11027,
#  '고속도로': 6911,
#  '시속': 11620,
#  '고속': 6910,
#  '이동하': 14294,
#  'gslt': 1800,
#  '위성방송': 13836,
#  '영동고속도로': 13041,
#  '기지국': 7499,
#  '서울반도체': 10577,
#  '신입': 11820,
#  '시스': 11622,
#  '모집': 9153,
#  '동부대우전자': 8379,
#  '벽걸이': 9745,
#  '드럼': 8475,
#  '허그': 19404,
#  '본상': 9888,
#  '진흥회': 16594,
#  'jidpo': 2320,
#  '권위': 7291,
#  '벽면': 9746,
#  '허리': 19410,
#  '세탁물': 10783,
#  '스탠드': 11406,
#  '신라면세점': 11753,
#  'kcsi': 2402,
#  '한국능률협회': 19031,
#  '한식': 19144,
#  '뷔페': 10052,
#  '풀잎': 18626,
#  '반찬': 9509,
#  '수간': 11058,
#  'hmr': 1976,
#  '출사표': 17180,
#  '마스터': 8875,
#  '키친': 17759,
#  '글라소': 7366,
#  '비타민': 10154,
#  '아트': 12176,
#  '에디션': 12665,
#  '코카콜라': 17586,
#  '오리지널': 13209,
#  '신진': 11838,
#  '임지': 14874,
#  '내세': 7757,
#  '멀티': 9033,
#  '트리플': 18129,
#  '신세계백화점': 11788,
#  '위크': 13865,
#  '브루노': 10070,
#  '산드로': 10309,
#  'dkny': 1080,
#  '스튜어트': 11432,
#  '여개': 12801,
#  'cj제일제당': 674,
#  '의형': 14233,
#  '조미료': 15918,
#  '다시다': 7989,
#  '시원': 11643,
#  '매콤': 9005,
#  '계량': 6854,
#  '롯데백화점': 8731,
#  '잠실점': 15105,
#  '브리': 10071,
#  '리치': 8809,
#  '성수동': 10688,
#  '레프': 8672,
#  '엘라': 12781,
#  '골자': 6959,
#  '협약': 19552,
#  '밀착': 9403,
#  '기아': 7469,
#  '롯데': 8724,
#  '기아자동차': 7470,
#  '비소': 10128,
#  '점원': 15574,
#  '가스': 6476,
#  '전문점': 15439,
#  '체인점': 16969,
#  '호텔': 19640,
#  '영화관': 13096,
#  '패드': 18359,
#  '냉난방': 7778,
#  '관리비': 7076,
#  '유수': 13973,
#  '논의': 7868,
#  '허준': 19426,
#  '속보': 10933,
#  '출하': 17203,
#  '구문': 7190,
#  '버거킹': 9669,
#  '와퍼': 13379,
#  '앵커': 12408,
#  '흉내': 19951,
#  '중화': 16313,
#  '정환': 15756,
#  '서유기': 10586,
#  'copyright': 841,
#  '석간': 10606,
#  '문화일보': 9279,
#  '오희': 13314,
#  '이상네트웍스': 14372,
#  '매수세': 8994,
#  '여분': 12824,
#  '기대감': 7440,
#  '노동조합': 7826,
#  '인상률': 14681,
#  '양측': 12514,
#  '조합원': 16006,
#  '노사': 7842,
#  '분당': 9998,
#  '본회의': 9899,
#  '보로': 9807,
#  '기금': 7435,
#  '차등': 16670,
#  '토대': 17973,
#  '양사': 12483,
#  '중남미': 16239,
#  'att': 335,
#  '전시회': 15471,
#  'ifa': 2106,
#  '남미': 7714,
#  '웨이보': 13801,
#  '월스트리트저널': 13789,
#  'wsj': 6367,
#  '공실': 7009,
#  '선임': 10638,
#  '권리': 7286,
#  '발언': 9544,
#  '공산당': 7000,
#  '기관지': 7432,
#  '인민일보': 14671,
#  '애국': 12350,
#  'sbscnbc': 3454,
#  'im': 2136,
#  '손영': 10969,
#  'ceo': 598,
#  '서밋': 10549,
#  '물결': 9283,
#  '혁명기': 19469,
#  '원동력': 13718,
#  '주지의': 16164,
#  'dt': 1161,
#  '공언': 7011,
#  '장기': 15137,
#  '신용등급': 11808,
#  'aa': 1,
#  '종가': 16035,
#  '루프': 8753,
#  '해독': 19302,
#  '럭비': 8629,
#  'luck': 2633,
#  'be': 425,
#  'copyrights': 842,
#  '자릿수': 14974,
#  '성장률': 10702,
#  '최정희': 17116,
#  '월초': 13794,
#  '최고점': 17090,
#  '공정거래위': 7020,
#  '반납': 9490,
#  '윤구': 14082,
#  '동부증권': 8381,
#  '에프': 12742,
#  '매출액': 9001,
#  '거래액': 6683,
#  '용역비': 13532,
#  '김동희': 7547,
#  '가시': 6480,
#  '경쟁사': 6825,
#  '블리치': 10095,
#  '달빛조각사': 8061,
#  'rpg': 3420,
#  '롤프': 8723,
#  '정호': 15754,
#  '유진': 14020,
#  '순이익': 11242,
#  'pe': 2967,
#  '동종': 8410,
#  '김성은': 7560,
#  '여력': 12816,
#  '세관': 10731,
#  '포스터': 18529,
#  'aiartificial': 96,
#  'intelligence': 2197,
#  '매카시': 9004,
#  '학문': 18967,
#  '관념': 7070,
#  '클라크': 17714,
#  '스탠리': 11407,
#  '큐브릭': 17657,
#  '스페이스': 11466,
#  '오디세이': 13181,
#  'hal': 1856,
#  '스콧': 11373,
#  '블레이드': 10084,
#  '인형사': 14748,
#  '스티븐': 11445,
#  '스필버그': 11495,
#  '스파이크': 11458,
#  '존스': 16025,
#  '인류': 14662,
#  '상상력': 10424,
#  '연착륙': 12970,
#  '패로': 18364,
#  '매치': 9003,
#  '도약': 8293,
#  '백색': 9649,
#  '부엌': 9963,
#  '채비': 16774,
#  '중장': 16294,
#  '기적': 7491,
#  '관점': 7091,
#  '만해': 8941,
#  '정보통신산업진흥원': 15657,
#  '그럼에도': 7329,
#  '불구하고': 10029,
#  '중장기': 16296,
#  'itpv': 2270,
#  '주먹': 16112,
#  '컨셉트': 17478,
#  '월말': 13786,
#  '베를린': 9715,
#  '오락': 13188,
#  '브리핑': 10074,
#  '상호': 10464,
#  '주유소': 16144,
#  '린카': 8827,
#  '탑승': 17864,
#  '요소요소': 13480,
#  '좌우': 16067,
#  'g세대': 1849,
#  '연비': 12931,
#  '마력': 8849,
#  '토크': 17995,
#  '차감': 16662,
#  '구도': 7179,
#  'sone': 3645,
#  '모티브': 9162,
#  '이태원': 14578,
#  '라인업': 8593,
#  '반석': 9497,
#  '명기': 9092,
#  '업적': 12644,
#  '간판': 6542,
#  '원뿔': 13731,
#  '상무': 10419,
#  '전무': 15432,
#  '유형': 14052,
#  '의구심': 14188,
#  '호감': 19595,
#  '파격': 18219,
#  '차액': 16686,
#  '리에': 8800,
#  '생활환경': 10519,
#  '은혜': 14130,
#  '리더': 8773,
#  '수단': 11076,
#  '순환': 11252,
#  '데일리안': 8247,
#  '공짜': 7028,
#  '김태균': 7610,
#  '이례': 14309,
#  '승자': 11538,
#  '삼은': 10383,
#  '필통': 18844,
#  '제품군': 15856,
#  '제보': 15795,
#  '총집결': 17076,
#  '계승': 6858,
#  '연출': 12973,
#  '밀레': 9394,
#  '컨퍼런스': 17485,
#  '전시장': 15470,
#  '참관객': 16717,
#  '상징': 10451,
#  '전인': 15493,
#  '키보드': 17745,
#  '모터쇼': 9157,
#  '출간': 17168,
#  '특색': 18154,
#  '각사': 6523,
#  '반격': 9487,
#  '플래그': 18737,
#  '대열': 8158,
#  '풍경': 18636,
#  '진격': 16530,
#  '스키': 11381,
#  '지위': 16440,
#  '팩트': 18379,
#  '인용': 14699,
#  '영감': 13032,
#  '상거래': 10402,
#  '컴퓨팅': 17502,
#  '식료품': 11698,
#  '급부상': 7411,
#  'ms': 2769,
#  'pixabay': 3017,
#  '신경전': 11726,
#  '적과의': 15359,
#  '동침': 8416,
#  '아웃룩': 12107,
#  '안방': 12242,
#  '가공': 6439,
#  '홈사': 19675,
#  '저자': 15340,
#  '지성': 16412,
#  '탈바꿈': 17840,
#  '앰비언트': 12404,
#  'ambient': 175,
#  'computing': 787,
#  '궁금증': 7280,
#  '일거수일투족': 14758,
#  '관찰': 7095,
#  '오픈넷': 13303,
#  '김가연': 7532,
#  '변호사': 9758,
#  '종말': 16043,
#  '인권': 14642,
#  '강정수': 6618,
#  '암시': 12317,
#  '맞대결': 8968,
#  '몸집': 9189,
#  '칩셋': 17321,
#  '합작': 19256,
#  '퀄컴': 17652,
#  'mwc': 2784,
#  '명근': 9091,
#  '스포츠동아': 11475,
#  'yg': 6398,
#  'plug': 3047,
#  '내주': 7771,
#  '돌입': 8341,
#  '기점': 7492,
#  '전예': 15484,
#  '약자': 12458,
#  '털사': 17920,
#  '구심점': 7203,
#  '진기': 16539,
#  '기진': 7500,
#  '이정현': 14517,
#  '김경': 7533,
#  '추첨': 17148,
#  '전도': 15409,
#  '코치': 17583,
#  '탈피': 17848,
#  '박수': 9471,
#  '잔액': 15084,
#  '송금': 11002,
#  'kth': 2524,
#  '중점': 16300,
#  '필재': 18840,
#  '단장': 8044,
#  '친화': 17303,
#  '한창': 19182,
#  '발신': 9541,
#  'rcs': 3279,
#  '연합회': 12986,
#  'ces': 602,
#  '자로': 14971,
#  '청소': 16921,
#  '이재우': 14502,
#  'smartthinq': 3600,
#  'hub': 2036,
#  '시제품': 11654,
#  '조율': 15970,
#  '소요': 10880,
#  '스페인': 11468,
#  '구호': 7226,
#  '엘지': 12792,
#  'hi': 1949,
#  'art': 283,
#  '작명': 15062,
#  '핸디': 19362,
#  '니스': 7942,
#  '청소기': 16922,
#  '도모': 8271,
#  '독자': 8324,
#  '치중': 17279,
#  '합의점': 19253,
#  '종의': 16054,
#  '개설': 6651,
#  '유통망': 14038,
#  'mm': 2736,
#  '액세서리': 12387,
#  '이목': 14329,
#  '판박이': 18320,
#  '원작': 13754,
#  '임현석': 14889,
#  'voda': 6105,
#  '민선': 9379,
#  '대우건설': 8162,
#  '권영수': 7289,
#  '부회장': 9985,
#  '문선': 9261,
#  '경영진': 6818,
#  '참석': 16723,
#  '사용량': 10254,
#  '관제': 7092,
#  '밥솥': 9562,
#  '블라인드': 10077,
#  '기질': 7501,
#  '최다인': 17092,
#  '건설사': 6705,
#  '입주': 14916,
#  '집약': 16623,
#  '주거': 16084,
#  '비약': 10135,
#  '증대': 16339,
#  '오피스텔': 13312,
#  '현대건설': 19479,
#  '목동': 9172,
#  '송담': 11007,
#  '충남': 17209,
#  '에마': 12674,
#  '은평': 14123,
#  '힐스테이트': 19999,
#  '영통': 13086,
#  '천세': 16826,
#  'sk건설': 3558,
#  '보라매': 9802,
#  'sk뷰': 3561,
#  '공조': 7024,
#  '황창규': 19827,
#  '대림산업': 8128,
#  '한화건설': 19198,
#  '롯데캐슬': 8740,
#  'giga': 1696,
#  'genie': 1670,
#  '빌트': 10175,
#  '자이': 15025,
#  'xi': 6377,
#  '샌프란시스코': 10483,
#  '콘퍼런스': 17610,
#  '하나로': 18856,
#  '전장': 15509,
#  '유성': 13969,
#  '초과': 16995,
#  '호재': 19628,
#  '공산': 6999,
#  '카카': 17366,
#  'mf': 2705,
#  'per': 2971,
#  '산출': 10332,
#  '윤필': 14096,
#  '매니지먼트': 8985,
#  '호조': 19631,
#  '컨센서스': 17476,
#  '부합': 9983,
#  'buy': 505,
#  '드래곤': 8473,
#  '메가': 9038,
#  '맞벌이': 8969,
#  '갯수': 6678,
#  '화표': 19753,
#  'deview': 1023,
#  '담당자': 8068,
#  '쇼파': 11054,
#  '으뜸': 14106,
#  '판별': 18321,
#  '지칭': 16466,
#  '귀차니즘': 7312,
#  '빨래': 10192,
#  '억지': 12612,
#  '사이에서': 10272,
#  '전환율': 15548,
#  '주파수': 16180,
#  '연주곡': 12963,
#  '클라이막스': 17713,
#  '만곡': 8916,
#  '텐션': 17954,
#  '분초': 10019,
#  '저작권법': 15343,
#  '협의': 19553,
#  '니지': 7947,
#  '김윤희': 7581,
#  '차기': 16665,
#  '비교표': 10100,
#  '체계': 16950,
#  '받침': 9520,
#  '데일리': 8246,
#  '칼럼니스트': 17396,
#  '데이비드': 8244,
#  '야후': 12445,
#  '칼럼': 17395,
#  '기고': 7428,
#  '능성': 7935,
#  '마비': 8861,
#  '전초전': 15525,
#  '거인': 6690,
#  '선봉': 10629,
#  '가세': 6472,
#  '천대': 16815,
#  '상급': 10409,
#  '기종': 7495,
#  '사옥': 10251,
#  '자존심': 15037,
#  '판도': 18312,
#  '무더기': 9204,
#  '스마트워치': 11318,
#  'cpnd': 867,
#  '김승미': 7567,
#  '현관': 19474,
#  '클립스': 17735,
#  '통상': 18018,
#  '칸막이': 17393,
#  '자원': 15016,
#  'made': 2644,
#  'xl': 6379,
#  '후속작': 19900,
#  '메이드': 9055,
#  '가상현실': 6469,
#  '드림': 8480,
#  '순다': 11225,
#  '최고경영자': 17085,
#  '물꼬': 9285,
#  '선구': 10618,
#  '달마': 8059,
#  '오큘러스': 13285,
#  '티브이': 18190,
#  '문지현': 9266,
#  '취합': 17242,
#  '눈독': 7906,
#  '한몫': 19110,
#  '개최': 6667,
#  '도전장': 8304,
#  '내민': 7752,
#  '자신감': 15004,
#  '표출': 18602,
#  '이규섭': 14256,
#  '융합기술원': 14104,
#  '비지니스': 10150,
#  '오스': 13246,
#  '기조연설': 7494,
#  '선희': 10649,
#  'weconomy': 6312,
#  '애니멀': 12352,
#  '한겨레신문': 19002,
#  '치타': 17282,
#  'hw': 2051,
#  '삼매': 10352,
#  '먹거리': 9028,
#  '삼성동': 10359,
#  '코엑스': 17575,
#  '송창': 11031,
#  '최고기술책임자': 17086,
#  'cto': 903,
#  '원천': 13765,
#  '내실': 7762,
#  '김민정': 7553,
#  '전자책': 15506,
#  '안경': 12218,
#  '글라스': 7367,
#  'vr': 6280,
#  '주도자': 16103,
#  '오다': 13171,
#  '스콘': 11371,
#  '컨벤션': 17473,
#  '고동진': 6881,
#  '만물': 8925,
#  '비욘드': 10140,
#  '오찬': 13280,
#  '당구': 8080,
#  '청하': 16943,
#  ...}

# %% [markdown]
# <br/><br/>
# ### TF-IDF 적용
# - TF * IDF는 특정 문서 내에서 단어 빈도가 높을수록, 전체 문서들에는 그 단어를 포함한 문서가 적을수록 TF * IDF값이 높아지는 특징이 있다.
# - 이러한 특징을 이용해서 모든 문서에 나타나는 흔한 단어들을 걸러내며, 특정 단어가 가지는 중요도를 측정하는 데 사용된다.
# - 한마디로 TF * IDF 값은 특정 단어가 가지는 중요도!
# - TF(Term Frequency): 단어 빈도
#    - 해당 문서에서 단어가 나타나는 빈도수
#    - 문서의 길이가 길면 해당 단어의 실제 중요도와는 상관없이 단어의 빈도수는 증가될 확률이 높다.
#    - 위의 문제를 해결하기 위해 다음과 같이 표준화 -> (문서에서 단어가 나타나는 빈도수) / (모든 단어가 나타나는 빈도수)
# - IDF(Inverse Document Frequency): 역문헌 빈도
#    - 해당 단어의 일반적인 중요도를 나타내는 값
#    - log( 전체 문서의 수 / 해당 단어가 포함된 문서들의 수 )

# %%
from sklearn.feature_extraction.text import TfidfTransformer    # Tf * idf 구할 때

# %%
tfidf_transformer=TfidfTransformer(smooth_idf=True,use_idf=True)        # Tf-idf 가중치를 적용할 수 있도록 변환시켜줌
tf_idf_matrix = tfidf_transformer.fit_transform(word_count_vector)

feature_names=cv.get_feature_names()

dense = tf_idf_matrix.todense()

for i in range(len(dense)):
    doc = dense[i].tolist()[0]           # dense[i].tolist()는 2차원 list, 예를들면 shape: (1,814)
    phrase_scores = [pair for pair in zip(range(0, len(doc)), doc) if pair[1] > 0]      # 0의 값이 아닌것만 모아서 만듦

    sorted_phrase_scores = sorted(phrase_scores, key=lambda t: t[1], reverse=True) # sorted(phrase_scores, key=lambda t: t[1] * -1)라고 해도 됨
    for phrase, score in [(feature_names[word_id], score) for (word_id, score) in sorted_phrase_scores][:20]:
        print('{0: <20} {1}'.format(phrase, score))      # 단어와 단어의 tf-idf 값을 출력
    print()
    ##### 이 부분은 테스트를 위해서 #####
    if i == 3:     
        break
    ###############################
# Out:
# lg유플러스               0.19084881455971134
# 생태계                  0.16639331319653225
# 편의                   0.14193781183335316
# 클라우드                 0.13810165475677605
# 기아                   0.13138837987276608
# 진화                   0.12131846754675119
# 연구소                  0.1179618301047462
# 시너지                  0.10549431960587058
# 비즈니스                 0.10165816252929348
# 시각                   0.10117864289472134
# 오디오북                 0.09974008399100491
# 설계                   0.09878104472186064
# 가전제품                 0.09638344654899995
# 조원                   0.09494488764528354
# 카카오i                 0.09158825020327856
# 보일러                  0.08583401458841289
# 자녀                   0.08535449495384075
# 향상                   0.08535449495384075
# iptv                 0.08343641641555219
# 패턴                   0.08247737714640792
#
# 개각                   0.21110016546037466
# ssid                 0.1266600992762248
# 그늘                   0.1266600992762248
# 낙엽                   0.1266600992762248
# 다이어터                 0.1266600992762248
# 부대찌개                 0.1266600992762248
# 산양유                  0.1266600992762248
# 유시민                  0.1266600992762248
# 유통기한                 0.1266600992762248
# 주꾸미                  0.1266600992762248
# 홍게                   0.1266600992762248
# doubt                0.08444006618414986
# lsg                  0.08444006618414986
# octtwo               0.08444006618414986
# query                0.08444006618414986
# sorry                0.08444006618414986
# 고한                   0.08444006618414986
# 구래동                  0.08444006618414986
# 구림                   0.08444006618414986
# 극악                   0.08444006618414986
