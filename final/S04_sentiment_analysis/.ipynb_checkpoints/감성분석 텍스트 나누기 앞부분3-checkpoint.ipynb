# %%
import pandas as pd
import numpy as np
import pickle
import re
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### 데이터 합치기 - 뉴스, 블로그, 리뷰(플레이스토어 + 11번가)

# %% [markdown]
# #### [ 뉴스 ]

# %%
clova_news_df = pd.read_csv("../../data/naver_news/nugu_speaker_news.csv", index_col=0)
clova_news_df['source'] = 'news'
clova_news_df.head()
# Out:
#                                      title publisher         date  \
# 0  SK텔레콤, 인공지능 대중화 선언…AI 스피커 '누구(NUGU)' 공개     아시아경제  2016.08.31.
# 1   “스피커가 말을 한다”…SK텔레콤, 인공지능 서비스 ‘NUGU’ 출시      매일경제  2016.08.31.
# 2        (특징주)아이리버, SKT AI 스피커 ‘누구’ 출시에 강세     뉴스토마토  2016.08.31.
# 3              "내일 날씨 어때" 물으면 "우산 챙겨요" 답한다    파이낸셜뉴스          NaN
# 4       SKT, AI 서비스 출시…말하면 알아서 답하는 너 '누구'니     머니투데이  2016.08.31.
#
#                                                  url  \
# 0  https://news.naver.com/main/read.nhn?mode=LSD&...
# 1  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2  http://www.newstomato.com/ReadNews.aspx?no=685880
# 3  https://news.naver.com/main/read.nhn?mode=LSD&...
# 4  https://news.naver.com/main/read.nhn?mode=LSD&...
#
#                                                texts source
# 0  [아시아경제 박소연 기자]SK텔레콤이 인공지능(AI) 스피커를 선보이며 'AI 대중...   news
# 1  사용자의 명령을 수행하고 묻는 말에 대답하는 스피커가 등장했다. 이 스피커는 손을 ...   news
# 2                                                NaN   news
# 3  SKT, 음성인식 기반 AI개인비서 서비스 '누구' 선보여가전제품 제어는 물론 음악...   news
# 4  [머니투데이 이정혁 기자, 이해인 기자] [사투리까지 알아듣는 등 주인이 원하는 것...   news

# %% [markdown]
# <br/><br/>
# #### [ 블로그 ]

# %%
clova_blog_df = pd.read_csv("../../data/naver_blog/nugu_speaker_blog.csv", encoding='utf-16', index_col=0)
clova_blog_df['source'] = 'blog'
clova_blog_df.head()
# Out:
#                                                title     publish_datetime  \
# 0  SKT 음성인식 스피커 "NUGU (누구)" 출시 (like 아마존에코, Amazo...  2016-08-31 11:02:00
# 1                         로봇 비서?…SKT, 음성인식AI ‘누구’ 공개  2016-08-31 16:09:00
# 2  [2016.8.31 뉴스클리핑] ▲'핀테크 고속도로' 개통…금융권 공동 오픈플랫폼 ...  2016-08-31 12:26:00
# 3                                                NaN                  NaN
# 4         “ ‘누구’ 신나는 음악좀 틀어줘” SKT, 생활속 AI 로봇 서비스....  2016-08-31 21:19:00
#
#                                                 text  \
# 0  \n안녕하세요. 제이전트(Jgent)입니다.드디어 1년 반여년 이상 준비했던 SKT...
# 1  1일부터 서비스…인공지능 대중화 시대 선언\n“비 오는 초가을 날씨에 어울리는 노래...
# 2  세계 첫 사례…핀테크 기업들 빠른 서비스 개발 가능 핀테크 기업이 새로운 서비스를 ...
# 3                                                NaN
# 4  \nSK텔레콤이 지난달 31일 서울시 중구 을지로 본사에서 인공지능 개인비서 로봇 ...
#
#                                                  url source
# 0  https://blog.naver.com/zoophila?Redirect=Log&l...   blog
# 1  https://blog.naver.com/duoprism?Redirect=Log&l...   blog
# 2             http://blog.kissoft.co.kr/220801153255   blog
# 3            http://blog.daum.net/dandakhan/16619935   blog
# 4  https://blog.naver.com/chase65?Redirect=Log&lo...   blog

# %% [markdown]
# <br/>
# #### [ 플레이스토어 리뷰 ]

# %%
clova_review_df = pd.read_csv('../../data/playstore_review_skt_nugu.csv')
clova_review_df['source'] = 'review'
clova_review_df.head()
# Out:
#           name  ratings          date  helpful vote  \
# 0          임이응        4   2019년 5월 7일             4
# 1          당당쥐        1   2019년 4월 8일            26
# 2     777 BANG        4  2019년 4월 23일             5
# 3  king sun Da        1   2019년 5월 9일             0
# 4      KANGMAN        3   2019년 5월 3일             1
#
#                                              comment  source
# 0  안녕하세요. 누구 캔들을 잘 사용하고 있어요. 그런데 제가 아리아를 불렀을 때 아리...  review
# 1  자꾸 연결이 잘 안되어서 미치겠어요. 처음부터 안됬으면 버리기라도 하지 잘되다가 자...  review
# 2  좋고 편리하긴 한데 뭔가 기본적인 것들이 빠져 있음. 업데이트 후 예약 설정해놓은걸...  review
# 3  아니 어제까지 잘되던데 검색을 하면 연결 기기가 없다고 합니까??? 공유기 초기화,...  review
# 4  티맵 쓰면서 정말 잘 활용하고 있어요 그런데 QM3의 T2C에서 티맵 실행하고 아리...  review

# %% [markdown]
# <br/>
# #### [ 11번가 리뷰 ]

# %%
_11st_clova_review_df = pd.read_csv('../../data/review_data_nugu.csv', index_col=0)
_11st_clova_review_df['source'] = 'review'
_11st_clova_review_df.head()
# Out:
#    index                                               nugu  score  source
# 0      1  와이파이 연결은 자기가알아서 척척 하네요. 무드등 기능 일단좋고,핸펀 블루투스음악보...      5  review
# 1      2  배송 빠르구요. 제품 하자없어요. 음향 선명하고 맑습니다. 말귀 잘 알아듣구요. 엄...      4  review
# 2      3  스피커 상태나 제품도 온전한 것으로 왔는데, 글쎄 제조일이 17년도여서 실망했어요....      3  review
# 3      4                   귀도 어둡고, 머리도 나쁘고, 그저 노래만 부를 줄 아는군      2  review
# 4      5  솔직한 사용기 입니다. 일단 음성인식 블루투스 스피커 + 무드등을하나 산다고 해도 ...      1  review

# %% [markdown]
# <br/>
# #### [ 데이터 합치기 ]

# %%
clova_df = pd.DataFrame({"date": pd.concat([clova_news_df.date, clova_blog_df.publish_datetime, 
                                            clova_review_df.date, pd.Series([None] * len(_11st_clova_review_df))]),
                         "texts":pd.concat([clova_news_df.texts, clova_blog_df.text, 
                                            clova_review_df.comment, _11st_clova_review_df.nugu]),
                         'source':pd.concat([clova_news_df.source, clova_blog_df.source, 
                                             clova_review_df.source, _11st_clova_review_df.source])
                        })

# %%
clova_df = clova_df[clova_df.texts.notnull()].copy()
clova_df.reset_index(inplace=True, drop=True)
clova_df
# Out:
#               date                                              texts  source
# 0      2016.08.31.  [아시아경제 박소연 기자]SK텔레콤이 인공지능(AI) 스피커를 선보이며 'AI 대중...    news
# 1      2016.08.31.  사용자의 명령을 수행하고 묻는 말에 대답하는 스피커가 등장했다. 이 스피커는 손을 ...    news
# 2              NaN  SKT, 음성인식 기반 AI개인비서 서비스 '누구' 선보여가전제품 제어는 물론 음악...    news
# 3      2016.08.31.  [머니투데이 이정혁 기자, 이해인 기자] [사투리까지 알아듣는 등 주인이 원하는 것...    news
# 4              NaN  음성인식 전용 스피커 출시…IoT 연결 가전제품도 제어연내 음식 주문 서비스 가능…...    news
# 5      2016.08.31.  [이데일리 김현아 기자]음성인식 기반 인공지능 서비스 ‘누구’(NUGU) 출시 관련...    news
# 6              NaN  ㆍ인공지능 서비스 ‘NUGU’ 공개ㆍ음성인식 기반 대화하듯 사용ㆍ음악 재생·일정 안...    news
# 7      2016.08.31.  [현장 분석] 탈통신 서비스 '누구'와 두비두'가 던진 화두는 개방과 글로벌 [오마...    news
# 8              NaN  2m서 떨어져 얘기해도 깨끗SK텔레콤 모델이 '누구 콜' 서비스 출시를 홍보하고 있...    news
# 9      2019.05.16.  마이크로소프트, 클라우드 플랫폼 애저 기반 다양한 AI서비스 공개AI스피커 대신 P...    news
# 10     2019.04.22.  '감성대화' 음악·날씨, 뉴스, 운세 등 제공【서울=뉴시스】서울 강남구청. (사진=...    news
# 11             NaN  [서울신문]SKT, 연구 5년 만에 ‘누구’ 출시 “딥러닝 기술 활용해 스스로 진화...    news
# 12             NaN  [동아일보]‘스마트홈’ 서비스-가전 2題《 집이 똑똑해지고 있다. 이동통신회사는 ‘...    news
# 13             NaN  박일환 SK텔레콤 디바이스지원단장(가운데)이 31일 서울 중구 을지로 본사 사옥에서...    news
# 14     2016.09.01.  SK텔레콤이 음성인식 인공지능 서비스 ‘누구’와 전용기기를 공개하며 ‘AI 대중화 ...    news
# 15     2016.09.01.  31일 SK텔레콤에서 모델들이 인공지능 서비스 '누구(NUGU)'를 소개하고 있다....    news
# 16     2016.09.03.  [아이뉴스24 편집국] 이번 주는 유럽 최대 가전 전시회인 'IFA'가 지난 2일 ...    news
# 17     2016.09.04.  빅데이터와 인공지능(AI) 기술을 활용해 사용자의 취향을 파악하고, 취향에 맞춰 콘...    news
# 18             NaN  원하는 음악 골라주고.. SKT AI 스피커 '누구' 선봬말만 하면 음악 선곡은 기...    news
# 19     2016.09.05.  디지털데일리는 클라우드 관련 소식을 한 눈에 볼 수 있는 ‘주간 클라우드 동향 리포...    news
# 20     2016.09.05.  [동아일보]음성을 인식해 집안 전자기기 제어부터 음악 재생, 일정 관리 등을 해 주...    news
# 21             NaN  SK텔레콤의 음성인식 기반 인공지능 서비스 ‘누구’(사진)를 사용할 때 부를 수 있...    news
# 22             NaN  [동아일보]음악 청취, 외국인 가수 인식 못해…일정 물으면 바로 응답해 ‘쓸만’음성...    news
# 23     2016.09.09.  SK텔레콤 조영훈 Home 본부장아마존社의 음성인식 블루투스 스피커 ‘아마존 에코’...    news
# 24     2016.09.12.  음악 틀고 가전 제어 AI스피커인터넷 쇼핑·음식 배달 주문도[ 추가영 기자  ] S...    news
# 25             NaN  내달 21일까지 공모, 3개팀에 연구비 2억\n\n\n\n\n\n\n\n\n\n\n...    news
# 26     2016.09.12.  SK텔레콤은 음성인식 인공지능 서비스 '누구'와 연동할 수 있는 신규 서비스 및 디...    news
# 27     2016.09.12.  SK텔레콤은 자사 인공지능(AI) 서비스 '누구(NUGU)'와 연동 가능한 신규 서...    news
# 28     2016.09.13.  "아이유 노래 듣고싶어" 얘기하면 음악찾아 재생SK텔레콤이 인공지능(AI) 기반 서...    news
# 29     2016.09.16.  SKT '누구' 필두 KT ·LGU+ 인공지능 스피커 개발글로벌 IT 기업 개인 가...    news
# ...            ...                                                ...     ...
# 10172         None                                             그냥그래요.  review
# 10173         None                                             괜찮습니다.  review
# 10174         None                                             그냥그래요.  review
# 10175         None                                             그냥그래요.  review
# 10176         None                                             그냥그래요.  review
# 10177         None                                             그냥그래요.  review
# 10178         None                                             만족합니다.  review
# 10179         None                                            ？오입니다 ㅋ  review
# 10180         None                                             그냥그래요.  review
# 10181         None                                             그냥그래요.  review
# 10182         None                                             그냥그래요.  review
# 10183         None                                             그냥그래요.  review
# 10184         None                                             그냥그래요.  review
# 10185         None                                             그냥그래요.  review
# 10186         None                                             그냥그래요.  review
# 10187         None                                            배송 늦었네요  review
# 10188         None                                             그냥그래요.  review
# 10189         None                                            사용전 입니다  review
# 10190         None                                             그냥그래요.  review
# 10191         None                                            잘 받았습니다  review
# 10192         None                                             정말 좋네요  review
# 10193         None                                              잘받았어요  review
# 10194         None                                              싸게샀어요  review
# 10195         None                                             잘 샀습니다  review
# 10196         None                                              아직사용전  review
# 10197         None                                              너무좋아요  review
# 10198         None                                              쓸만합니다  review
# 10199         None                                             아주 좋아요  review
# 10200         None                                              배송개느림  review
# 10201         None                                              좋습니다.  review
#
# [10202 rows x 3 columns]

# %% [markdown]
# <br/><br/>
# ### 텍스트 전처리

# %%
def clear_content(temp):
    #want_remove = ['flash 오류를 우회하기 위한 함수 추가', 'function _flash_removeCallback', 
    #               '\n', '\.\.', '[\w]+ 기자', '\xa0', '\r', '\t']
    content = re.sub('[a-zA-Z0-9]+[a-zA-Z0-9+-_.]+@[a-zA-Z0-9-]+\.[a-zA-Z0-9-.]+', ' ', temp) # 이메일주소 없애기
    content = re.sub('(https?:\/\/)?([\da-z\.-]+)\.([a-z\.]{2,6})([\/\w_\.-]*)*\/?', ' ', content) # URL 없애기
    #content = re.sub('|'.join(want_remove), ' ', content)
    content = re.sub('\n|\r|\xa0', ' ', content)
    ㅠcontent = re.sub('[\(]', ' ', content) # 커머스(전자상거래)와' -> '커머스전자상거래와' 이렇게 변하던것을 -> '커머스 전자상거래'
    content = re.sub('~', ' ', content)
    #content = re.sub('[^\.\?\!\^^\♥\♡\w\d\s]','', content) # 불필요한 기호 없애기
    content = re.sub('\d', '', content)
    content = re.sub('[^\.\?\!\^^\♥\♡\w\s]','', content) # 불필요한 기호 없애기
    while '  ' in content: content = content.replace('  ', ' ') # 빈칸 없애주기 
    content = content.strip()
    return content

# %% [markdown]
# <br/><br/>
# ### 모델을 이용해서 네이버 블로그 데이터(中 clova) sentence별 긍정/부정 나누기

# %%
clova_df["preprocessed_text"] = clova_df['texts'].map(clear_content)

# %%
clova_df.head()
# Out:
#           date                                              texts source  \
# 0  2016.08.31.  [아시아경제 박소연 기자]SK텔레콤이 인공지능(AI) 스피커를 선보이며 'AI 대중...   news
# 1  2016.08.31.  사용자의 명령을 수행하고 묻는 말에 대답하는 스피커가 등장했다. 이 스피커는 손을 ...   news
# 2          NaN  SKT, 음성인식 기반 AI개인비서 서비스 '누구' 선보여가전제품 제어는 물론 음악...   news
# 3  2016.08.31.  [머니투데이 이정혁 기자, 이해인 기자] [사투리까지 알아듣는 등 주인이 원하는 것...   news
# 4          NaN  음성인식 전용 스피커 출시…IoT 연결 가전제품도 제어연내 음식 주문 서비스 가능…...   news
#
#                                    preprocessed_text
# 0  아시아경제 박소연 기자SK텔레콤이 인공지능AI 스피커를 선보이며 AI 대중화 시대 ...
# 1  사용자의 명령을 수행하고 묻는 말에 대답하는 스피커가 등장했다. 이 스피커는 손을 ...
# 2  SKT 음성인식 기반 AI개인비서 서비스 누구 선보여가전제품 제어는 물론 음악추천 ...
# 3  머니투데이 이정혁 기자 이해인 기자 사투리까지 알아듣는 등 주인이 원하는 것 척척사...
# 4  음성인식 전용 스피커 출시IoT 연결 가전제품도 제어연내 음식 주문 서비스 가능T맵...

# %%
del_idx = []
for num, i in enumerate(clova_df['preprocessed_text']):
    if i == '' or i == None or i == ' ':
        del_idx.append(num)
print(del_idx)
# Out:
# [849, 1003, 2882, 3040, 3165, 3299, 6158, 6160]

# %%
clova_df.loc[clova_df.index[del_idx]]
# Out:
#                      date                                              texts  \
# 849   2016-10-04 01:13:00                                               \n\n
# 1003  2016-12-20 16:59:00                                               \n\n
# 2882  2018-08-05 18:09:00       https://blog.naver.com/csjrlove/221327546634
# 3040  2018-08-29 17:51:00  http://m.momsdiary.co.kr/w/event/com_event/skt...
# 3165  2018-09-20 16:37:00                                           \n \n\n
# 3299  2018-10-26 15:26:00                                               \n\n
# 6158        2018년 10월 31일                                                  😊
# 6160          2018년 4월 5일                                                  👍
#
#       source preprocessed_text
# 849     blog
# 1003    blog
# 2882    blog
# 3040    blog
# 3165    blog
# 3299    blog
# 6158  review
# 6160  review

# %%
final_clova_df = clova_df.drop(clova_df.index[del_idx]).copy()

# %%
# 빈 데이터들을 다 삭제하고 난 뒤, 인덱스를 다시 0부터 순서대로 부여해 줌
final_clova_df.reset_index(drop=True, inplace=True)

# %%
final_clova_df.head()
# Out:
#           date                                              texts source  \
# 0  2016.08.31.  [아시아경제 박소연 기자]SK텔레콤이 인공지능(AI) 스피커를 선보이며 'AI 대중...   news
# 1  2016.08.31.  사용자의 명령을 수행하고 묻는 말에 대답하는 스피커가 등장했다. 이 스피커는 손을 ...   news
# 2          NaN  SKT, 음성인식 기반 AI개인비서 서비스 '누구' 선보여가전제품 제어는 물론 음악...   news
# 3  2016.08.31.  [머니투데이 이정혁 기자, 이해인 기자] [사투리까지 알아듣는 등 주인이 원하는 것...   news
# 4          NaN  음성인식 전용 스피커 출시…IoT 연결 가전제품도 제어연내 음식 주문 서비스 가능…...   news
#
#                                    preprocessed_text
# 0  아시아경제 박소연 기자SK텔레콤이 인공지능AI 스피커를 선보이며 AI 대중화 시대 ...
# 1  사용자의 명령을 수행하고 묻는 말에 대답하는 스피커가 등장했다. 이 스피커는 손을 ...
# 2  SKT 음성인식 기반 AI개인비서 서비스 누구 선보여가전제품 제어는 물론 음악추천 ...
# 3  머니투데이 이정혁 기자 이해인 기자 사투리까지 알아듣는 등 주인이 원하는 것 척척사...
# 4  음성인식 전용 스피커 출시IoT 연결 가전제품도 제어연내 음식 주문 서비스 가능T맵...

# %% [markdown]
# - 각 문헌을 sentence별로 나누기

# %%
import nltk.tokenize
final_clova_df['sentence_text'] = final_clova_df['preprocessed_text'].map(nltk.tokenize.sent_tokenize)

# %%
final_clova_df.head()
# Out:
#           date                                              texts source  \
# 0  2016.08.31.  [아시아경제 박소연 기자]SK텔레콤이 인공지능(AI) 스피커를 선보이며 'AI 대중...   news
# 1  2016.08.31.  사용자의 명령을 수행하고 묻는 말에 대답하는 스피커가 등장했다. 이 스피커는 손을 ...   news
# 2          NaN  SKT, 음성인식 기반 AI개인비서 서비스 '누구' 선보여가전제품 제어는 물론 음악...   news
# 3  2016.08.31.  [머니투데이 이정혁 기자, 이해인 기자] [사투리까지 알아듣는 등 주인이 원하는 것...   news
# 4          NaN  음성인식 전용 스피커 출시…IoT 연결 가전제품도 제어연내 음식 주문 서비스 가능…...   news
#
#                                    preprocessed_text  \
# 0  아시아경제 박소연 기자SK텔레콤이 인공지능AI 스피커를 선보이며 AI 대중화 시대 ...
# 1  사용자의 명령을 수행하고 묻는 말에 대답하는 스피커가 등장했다. 이 스피커는 손을 ...
# 2  SKT 음성인식 기반 AI개인비서 서비스 누구 선보여가전제품 제어는 물론 음악추천 ...
# 3  머니투데이 이정혁 기자 이해인 기자 사투리까지 알아듣는 등 주인이 원하는 것 척척사...
# 4  음성인식 전용 스피커 출시IoT 연결 가전제품도 제어연내 음식 주문 서비스 가능T맵...
#
#                                        sentence_text
# 0  [아시아경제 박소연 기자SK텔레콤이 인공지능AI 스피커를 선보이며 AI 대중화 시대...
# 1  [사용자의 명령을 수행하고 묻는 말에 대답하는 스피커가 등장했다., 이 스피커는 손...
# 2  [SKT 음성인식 기반 AI개인비서 서비스 누구 선보여가전제품 제어는 물론 음악추천...
# 3  [머니투데이 이정혁 기자 이해인 기자 사투리까지 알아듣는 등 주인이 원하는 것 척척...
# 4  [음성인식 전용 스피커 출시IoT 연결 가전제품도 제어연내 음식 주문 서비스 가능T...

# %% [markdown]
# - 나눈 sentence들을 각각 형태소 분석하기

# %%
# 미등록단어 지정하여 Komoran 형태소 분석 
from konlpy.tag import Komoran

#dicpath = './unregistered_dic_blog_test.txt'
#komoran = Komoran(userdic= dicpath)
dicpath = './unregistered.txt'
komoran = Komoran(userdic=dicpath)

# %%
final_clova_df['pos_sentence_text'] = final_clova_df['sentence_text'].map(lambda l: [komoran.pos(sentence) for sentence in l])

# %%
#[" ".join([wors[0] for word in sent]) for sent in final_df['pos_sentence_text']]
def pos_by_sentence(l):
    result = []
    for sent in l:
        result.append(" ".join([word[0] for word in sent]))
    return result

final_clova_df['pos_sentence_text'] = final_clova_df['pos_sentence_text'].map(pos_by_sentence)

# %%
final_clova_df.head()

# %% [markdown]
# #### sentence별 긍정(1) / 부정(-1)으로 나누기

# %%
def label_by_sentence(doc):
    loaded_vectorizer = pickle.load(open('./pretrained_vectorizer.pickle', 'rb'))
    loaded_model = pickle.load(open('./pretrained_model.pickle', 'rb'))
    
    tfidf_features = loaded_vectorizer.transform(doc)
    pred_labels = loaded_model.predict(tfidf_features)
    return pred_labels

final_clova_df['label_sentence_text'] = final_clova_df['pos_sentence_text'].map(label_by_sentence)

# %%
final_clova_df.to_csv("누구.csv", encoding='utf-8')
