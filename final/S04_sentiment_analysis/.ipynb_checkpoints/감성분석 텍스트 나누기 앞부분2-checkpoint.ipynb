# %%
import pandas as pd
import numpy as np
import pickle
import re
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### 데이터 합치기 - 뉴스, 블로그, 리뷰(플레이스토어 + 11번가)

# %% [markdown]
# #### [ 뉴스 ]

# %%
clova_news_df = pd.read_csv("../../data/naver_news/gigagenie_speaker_news.csv", index_col=0)
clova_news_df['source'] = 'news'
clova_news_df.head()
# Out:
#                                     title publisher         date  \
# 0        이통3사, 인공지능 '가속페달'..."영토확장 경쟁 치열"      뉴데일리  2016.12.05.
# 1  황창규 AI사업 진입… “KT, 국내 최고 수준 음성인식 기술 보유”      베타뉴스  2016.12.05.
# 2           KT, 상품·네트워크·영업 전 분야 `인공지능` 적용      전자신문          NaN
# 3    [5G가 여는 新독서시대]②"아리아, 책 읽어줘"…오디오북의 선전      이데일리          NaN
# 4                 [화웨이 리스크] AI스피커 시장 '요동'       EBN         5일 전
#
#                                                  url  \
# 0  http://biz.newdaily.co.kr/news/article.html?no...
# 1             http://www.betanews.net/article/652254
# 2  https://news.naver.com/main/read.nhn?mode=LSD&...
# 3  https://news.naver.com/main/read.nhn?mode=LSD&...
# 4              http://www.ebn.co.kr/news/view/985789
#
#                                                texts source
# 0                                                NaN   news
# 1                                                NaN   news
# 2  KT가 `인공지능(AI)`을 적용한 기업영업 솔루션을 개발한다. 스마트로봇 `기가지...   news
# 3  AI스피커도 키즈 오디오북 인기조정래 '천년의 질문' 오디오북으로 선공개오디오북 1...   news
# 4                                                NaN   news

# %% [markdown]
# <br/><br/>
# #### [ 블로그 ]

# %%
clova_blog_df = pd.read_csv("../../data/naver_blog/gigagenie_speaker_blog.csv", encoding='utf-16', index_col=0)
clova_blog_df['source'] = 'blog'
clova_blog_df.head()
# Out:
#                                                title     publish_datetime  \
# 0       내년엔 수많은 AI 비서들이 줄 섭니다…네이버·KT·LGU+에 삼성전자까지 가세  2016-12-16 15:25:00
# 1                       "사물을 연결하라"...그 다음은? [이코노믹리뷰]  2016-12-16 16:23:00
# 2  2017, 'AI비서'들이 거실로 몰려온다/국내 이통3사, 일제히 경쟁 돌입…IPT...  2016-12-19 02:10:00
# 3                              지금 ICT업계 핫이슈는 음석인식 기술  2016-12-19 16:56:00
# 4                                           인공지능 스피커  2016-12-22 09:58:00
#
#   text                                                url source
# 0  NaN  http://blog.naver.com/PostView.nhn?blogId=sbki...   blog
# 1  NaN  http://blog.naver.com/PostView.nhn?blogId=hone...   blog
# 2  NaN  http://blog.naver.com/PostView.nhn?blogId=hico...   blog
# 3  NaN  http://blog.naver.com/PostView.nhn?blogId=just...   blog
# 4  NaN  http://blog.naver.com/PostView.nhn?blogId=hmmo...   blog

# %% [markdown]
# <br/>
# #### [ 플레이스토어 리뷰 ]

# %%
clova_review_df = pd.read_csv('../../data/playstore_review_kt_gigagenie.csv')
clova_review_df['source'] = 'review'
clova_review_df.head()
# Out:
#          name  ratings          date  helpful vote  \
# 0         황원욱        2  2019년 5월 12일             0
# 1        이름없음        2  2019년 5월 10일             2
# 2      경기도보안관        5  2019년 5월 10일             0
# 3         이영희        3   2019년 5월 9일             0
# 4  Sherliss Y        2  2019년 5월 12일             0
#
#                                              comment  source
# 0  좋아하는 노래만 듣고싶은데 플레이리스트를 따로 설정해놓고 노래를 들을수 있는 방법은...  review
# 1  기가지니 블루투스연결은 안되나요? 블루투스 연결하려하면 기기설정을 확인하라고뜨고 연...  review
# 2  한가지 물어볼사항이 있는데요 kt간편로그인에 등록된 아이디가 있는데 제가 kt간편로...  review
# 3  에어컨 티비 켤때만 편한듭 솔직히 잘 못알아들어요. 그리고 문안인사 설정취소했는데도...  review
# 4  업데이트후 앱 우측하단에 음성명령을 텍스트로 써서 하는 기능이 사라진거같은데 왜 없...  review

# %% [markdown]
# <br/>
# #### [ 11번가 리뷰 ]

# %%
_11st_clova_review_df = pd.read_csv('../../data/review_data_gigagenie.csv', index_col=0)
_11st_clova_review_df['source'] = 'review'
_11st_clova_review_df.head()
# Out:
#    index                                               nugu  score  source
# 0      1  배송이랑 등이랑 다잘왓구요 ㅎ 전등은 놓을데가 없어서 아직 못쓰고 잇네요 ㅎ 음악듣...      5  review
# 1      2  기가지니버디 성능 완정 말짱 꽝! 할 줄 아는게 없다! 클로바 적극 추천. 기가지니...      2  review
# 2      3  쇼핑비교사이트에서 비교하고 제일 저렴하게 구매했습니다.잘받았습니다.기본 10자 이상...      5  review
# 3      4  배송 빠르고 제품 아담하고 좋습니다.출력이 낮은 제품이기에 음량은 다소 약한 느낌이...      4  review
# 4      5  음질은 아주 좋다고 하긴 어렵지만 다른 음성인식 스피커들 보단 좀 괜찮은거 같아요....      5  review

# %% [markdown]
# <br/>
# #### [ 데이터 합치기 ]

# %%
clova_df = pd.DataFrame({"date": pd.concat([clova_news_df.date, clova_blog_df.publish_datetime, 
                                            clova_review_df.date, pd.Series([None] * len(_11st_clova_review_df))]),
                         "texts":pd.concat([clova_news_df.texts, clova_blog_df.text, 
                                            clova_review_df.comment, _11st_clova_review_df.nugu]),
                         'source':pd.concat([clova_news_df.source, clova_blog_df.source, 
                                             clova_review_df.source, _11st_clova_review_df.source])
                        })

# %%
clova_df = clova_df[clova_df.texts.notnull()].copy()
clova_df.reset_index(inplace=True, drop=True)
clova_df
# Out:
#              date                                              texts  source
# 0             NaN  KT가 `인공지능(AI)`을 적용한 기업영업 솔루션을 개발한다. 스마트로봇 `기가지...    news
# 1             NaN  AI스피커도 키즈 오디오북 인기조정래 '천년의 질문' 오디오북으로 선공개오디오북 1...    news
# 2     2019.04.26.  아마존과 구글이 이끌어…국내에선 통신사 주도(지디넷코리아=권혜미 기자)스마트폰 다음...    news
# 3     2019.05.18.  기가지나 테이블TV에 연동해 실제 녹음 진행[아이뉴스24 김문기 기자] "인공지능 ...    news
# 4            5일 전  [커버스토리 : 기적을 만드는 최강 영업팀36] KT AI사업단 AI플랫폼사업팀[한...    news
# 5     2019.05.12.  AI스피커 이용서비스 1위가 음악 감상[CBS노컷뉴스 김수영 기자]AI스피커 누구네...    news
# 6     2019.04.20.  ‘키즈 콘텐츠’가 인공지능(AI) 스피커 시장 선점을 위한 핵심 서비스로 떠오르고 ...    news
# 7             NaN  SKT 화면 있는 ‘누구 네모’ 출시말로 물으면 화면에도 정보 표시화면 통한 통화·...    news
# 8             NaN  통신3社 잇따라 출시 SK텔레콤은 지난달 말 새 인공지능(AI) 스피커 '누구 네모...    news
# 9     2016.12.07.  황창규 회장이 ‘인공지능(AI)’ 기술을 ICT 융합한 사업에 속도를 내고 있다. ...    news
# 10    2016.12.12.  [성상훈기자] KT가 음성명령 기능이 탑재된 인공지능 스피커와 가정용 셋톱박스를 합...    news
# 11            NaN  KT, 인공지능 스피커 출시 전망IPTV 셋톱박스 형태로 IoT 허브 역할[아시아경...    news
# 12            NaN  SKT, 백과사전·T맵 기능 `업그레이드`…KT·LGU+도 내년 출시 "회사까지 얼...    news
# 13    2016.12.14.  SK텔리콤 ‘누구’ T맵·백과사전 검색 가능해져KT 내년 초 출시…세계 최초 인공지...    news
# 14            NaN  SKT ‘누구’ 내비게이션 추가KT ‘기가지니’ 내년초 선보여국내에도 음성인식과 인...    news
# 15    2016.12.15.  (서울=연합뉴스) 고현실 기자 = SK텔레콤에 이어 KT와 LG유플러스도 음성인식 ...    news
# 16            NaN  KT·LGU+도 서비스 계획SK텔레콤의 ‘누구’로 촉발된 국내 음성인식 인공지능(A...    news
# 17    2016.12.16.  국내 음성인식 인공지능(AI) 스피커 시장의 춘추전국 시대가 열리고 있다. 음성인식...    news
# 18            NaN  [사진=게티이미지뱅크]SKT, T맵 연계 'AI최강자' 로드맵-국내 첫 음성인식 A...    news
# 19    2016.12.16.  내년도 국내 인터넷 기반 동영상 서비스(OTT) 시장이 그 어느때보다 치열할 전망이...    news
# 20    2016.12.18.  국내 이통3사, 일제히 경쟁 돌입…IPTV와 스마트홈까지 연계\n\n국내 이동통신 ...    news
# 21    2016.12.18.  글로벌 IT업계가 인공지능(AI)에 명운을 걸었다. 구글, 아마존 등 글로벌 공룡은...    news
# 22            NaN  음성인식 스피커 시장규모 2020년 2조5천억 전망2대 이상 사용하는 사람이 전체 ...    news
# 23            NaN  네이버 등 AI 스피커 사업 모색이통업계도 관련 서비스 경쟁“말 잘 듣는 인공지능(...    news
# 24    2016.12.21.  음성인식 인공지능 기기들이 출시되면서 리모컨 없이 주요 가전들을 조작할 수 있게 변...    news
# 25    2016.12.22.  [성상훈기자] SK텔레콤 음성인식 기반 인공지능 서비스 '누구'가 이르면 연말부터 ...    news
# 26    2016.12.23.  개인화·맞춤형 콘텐츠 본격화, 카카오 동영상 플랫폼 통합도 관심... MCN은 ‘오...    news
# 27    2016.12.25.  보이스 홈·자동 상담 등 개발 활발…"관련 전공자 몸값도 뛰어" (서울=연합뉴스) ...    news
# 28    2016.12.25.  인공지능(AI) 전문가들의 몸값이 뛰고 있다. AI 기술이 생활 속으로 빠르게 스며...    news
# 29            NaN  SKT, 오늘부터 누구·B tv 연계음성으로 채널 조정·동영상 검색KT, 내년초 '...    news
# ...           ...                                                ...     ...
# 4189         None  음성인식 및 응답률, 응답 퀄리티가 skt, 네이버, 구글 등 타사 제품에 비해 떨...  review
# 4190         None  써본 음성인식 스피커 제품중 가장 별로입니다. 네트워크 오류가 잦고 함께 주문한 한...  review
# 4191         None                                         매우만족합니다 매번  review
# 4192         None                                         매우만족합니다 매번  review
# 4193         None                                             아주 좋아요  review
# 4194         None  배송도 빠르고 쿠폰도 빨리왔어요노래도 잘틀어주고 좋은데 가끔 컴퓨터 스피커 소리를 ...  review
# 4195         None                          말 인식을 잘못해서 답답할때도 있는데 편해요.  review
# 4196         None  스피커가 좋아서 그런지 소리는 마음에 드네요.AI는 아직 콘텐츠가 더 필요한듯하구요...  review
# 4197         None            말잘알아들어요 생각보다 음질은 좋지 않네요 너무 많은걸 기대한건가..ㅠ  review
# 4198         None                                       빠른 배송 감사합니다.  review
# 4199         None                                       빠른 배송 감사합니다.  review
# 4200         None              주문 다음날 받았어요 스피커 음질 좋고 성능 기대 이상이네요 좋아요  review
# 4201         None                            누구미니 보다 3배의 스피커성능 짱입니다.  review
# 4202         None                                    지니이용권을 보내주지 않네요  review
# 4203         None  아이들이 좋아해요 뮤직도 잘찾아주고 저렴하거 잘산것 같아요. 아이들이 듣고 싶은 노...  review
# 4204         None                          최저가 일때 구매했어요^^ 쿠폰도 잘왔어요^^  review
# 4205         None           날씨도 안좋은데 생각보다 빨리와서 좋네요. 지니쿠폰도 퀵으로 부탁해요~~  review
# 4206         None                        배송도 빨리오구 기계도 멀쩡하네요 매우 만족합니다  review
# 4207         None                           순차 발송하신다시..목빠지게 기다려일겠네요~  review
# 4208         None                             어휴... 그냥저냥 스피커 샀다고 생각함  review
# 4209         None                                   배송빠르고 최저가 인터파크!!  review
# 4210         None  지니 잘받았는데 이용권이없어요. 주문한번호로 이용권번호보내주세요. 동봉된줄알고한참찾았네요  review
# 4211         None         감사합니다. 주문후 바로 받았습니다. 이용권도 구매결정후 담날 바로 오네요.  review
# 4212         None  총 3대 주문했는데, 바로 옵니다. 구매결정하니 이용권도 담날 바로 오구요.근데, ...  review
# 4213         None                잘 받았습니다. 감사합니다. 이용권도 구매결정하면 바로 옵니다.  review
# 4214         None  빠른 배송 감사합니다! 손에 꽉 들어 오니 좋네요! 색상을 다양하게 했으면 더 좋겠습니다  review
# 4215         None                  와이파이 5기가대는 설정이 잘 안되네요. 설정하니 잘되네요.  review
# 4216         None                              잘 받았습니다. 빠르네요. 감사합니다.  review
# 4217         None  잘 받았습니다. 수고하세요... 잘 받았습니다. 수고하세요... 잘 받았습니다. 수...  review
# 4218         None                             좋아보입니다. 좋아보입니다. 좋아보입니다  review
#
# [4219 rows x 3 columns]

# %% [markdown]
# <br/><br/>
# ### 텍스트 전처리

# %%
def clear_content(temp):
    #want_remove = ['flash 오류를 우회하기 위한 함수 추가', 'function _flash_removeCallback', 
    #               '\n', '\.\.', '[\w]+ 기자', '\xa0', '\r', '\t']
    content = re.sub('[a-zA-Z0-9]+[a-zA-Z0-9+-_.]+@[a-zA-Z0-9-]+\.[a-zA-Z0-9-.]+', ' ', temp) # 이메일주소 없애기
    content = re.sub('(https?:\/\/)?([\da-z\.-]+)\.([a-z\.]{2,6})([\/\w_\.-]*)*\/?', ' ', content) # URL 없애기
    #content = re.sub('|'.join(want_remove), ' ', content)
    content = re.sub('\n|\r|\xa0', ' ', content)
    ㅠcontent = re.sub('[\(]', ' ', content) # 커머스(전자상거래)와' -> '커머스전자상거래와' 이렇게 변하던것을 -> '커머스 전자상거래'
    content = re.sub('~', ' ', content)
    #content = re.sub('[^\.\?\!\^^\♥\♡\w\d\s]','', content) # 불필요한 기호 없애기
    content = re.sub('\d', '', content)
    content = re.sub('[^\.\?\!\^^\♥\♡\w\s]','', content) # 불필요한 기호 없애기
    while '  ' in content: content = content.replace('  ', ' ') # 빈칸 없애주기 
    content = content.strip()
    return content

# %% [markdown]
# <br/><br/>
# ### 모델을 이용해서 네이버 블로그 데이터(中 clova) sentence별 긍정/부정 나누기

# %%
clova_df["preprocessed_text"] = clova_df['texts'].map(clear_content)

# %%
clova_df.head()
# Out:
#           date                                              texts source  \
# 0          NaN  KT가 `인공지능(AI)`을 적용한 기업영업 솔루션을 개발한다. 스마트로봇 `기가지...   news
# 1          NaN  AI스피커도 키즈 오디오북 인기조정래 '천년의 질문' 오디오북으로 선공개오디오북 1...   news
# 2  2019.04.26.  아마존과 구글이 이끌어…국내에선 통신사 주도(지디넷코리아=권혜미 기자)스마트폰 다음...   news
# 3  2019.05.18.  기가지나 테이블TV에 연동해 실제 녹음 진행[아이뉴스24 김문기 기자] "인공지능 ...   news
# 4         5일 전  [커버스토리 : 기적을 만드는 최강 영업팀36] KT AI사업단 AI플랫폼사업팀[한...   news
#
#                                    preprocessed_text
# 0  KT가 인공지능AI을 적용한 기업영업 솔루션을 개발한다. 스마트로봇 기가지니와 네트...
# 1  AI스피커도 키즈 오디오북 인기조정래 천년의 질문 오디오북으로 선공개오디오북 만권 ...
# 2  아마존과 구글이 이끌어국내에선 통신사 주도지디넷코리아권혜미 기자스마트폰 다음은 스마...
# 3  기가지나 테이블TV에 연동해 실제 녹음 진행아이뉴스 김문기 기자 인공지능 스피커AI...
# 4  커버스토리 기적을 만드는 최강 영업팀 KT AI사업단 AI플랫폼사업팀한경비즈니스이명...

# %%
del_idx = []
for num, i in enumerate(clova_df['preprocessed_text']):
    if i == '' or i == None or i == ' ':
        del_idx.append(num)
print(del_idx)
# Out:
# []

# %%
clova_df.loc[clova_df.index[del_idx]]
# Out:
# Empty DataFrame
# Columns: [date, texts, source, preprocessed_text]
# Index: []

# %%
final_clova_df = clova_df.drop(clova_df.index[del_idx]).copy()

# %%
# 빈 데이터들을 다 삭제하고 난 뒤, 인덱스를 다시 0부터 순서대로 부여해 줌
final_clova_df.reset_index(drop=True, inplace=True)

# %%
final_clova_df.head()
# Out:
#           date                                              texts source  \
# 0          NaN  KT가 `인공지능(AI)`을 적용한 기업영업 솔루션을 개발한다. 스마트로봇 `기가지...   news
# 1          NaN  AI스피커도 키즈 오디오북 인기조정래 '천년의 질문' 오디오북으로 선공개오디오북 1...   news
# 2  2019.04.26.  아마존과 구글이 이끌어…국내에선 통신사 주도(지디넷코리아=권혜미 기자)스마트폰 다음...   news
# 3  2019.05.18.  기가지나 테이블TV에 연동해 실제 녹음 진행[아이뉴스24 김문기 기자] "인공지능 ...   news
# 4         5일 전  [커버스토리 : 기적을 만드는 최강 영업팀36] KT AI사업단 AI플랫폼사업팀[한...   news
#
#                                    preprocessed_text
# 0  KT가 인공지능AI을 적용한 기업영업 솔루션을 개발한다. 스마트로봇 기가지니와 네트...
# 1  AI스피커도 키즈 오디오북 인기조정래 천년의 질문 오디오북으로 선공개오디오북 만권 ...
# 2  아마존과 구글이 이끌어국내에선 통신사 주도지디넷코리아권혜미 기자스마트폰 다음은 스마...
# 3  기가지나 테이블TV에 연동해 실제 녹음 진행아이뉴스 김문기 기자 인공지능 스피커AI...
# 4  커버스토리 기적을 만드는 최강 영업팀 KT AI사업단 AI플랫폼사업팀한경비즈니스이명...

# %% [markdown]
# - 각 문헌을 sentence별로 나누기

# %%
import nltk.tokenize
final_clova_df['sentence_text'] = final_clova_df['preprocessed_text'].map(nltk.tokenize.sent_tokenize)

# %%
final_clova_df.head()
# Out:
#           date                                              texts source  \
# 0          NaN  KT가 `인공지능(AI)`을 적용한 기업영업 솔루션을 개발한다. 스마트로봇 `기가지...   news
# 1          NaN  AI스피커도 키즈 오디오북 인기조정래 '천년의 질문' 오디오북으로 선공개오디오북 1...   news
# 2  2019.04.26.  아마존과 구글이 이끌어…국내에선 통신사 주도(지디넷코리아=권혜미 기자)스마트폰 다음...   news
# 3  2019.05.18.  기가지나 테이블TV에 연동해 실제 녹음 진행[아이뉴스24 김문기 기자] "인공지능 ...   news
# 4         5일 전  [커버스토리 : 기적을 만드는 최강 영업팀36] KT AI사업단 AI플랫폼사업팀[한...   news
#
#                                    preprocessed_text  \
# 0  KT가 인공지능AI을 적용한 기업영업 솔루션을 개발한다. 스마트로봇 기가지니와 네트...
# 1  AI스피커도 키즈 오디오북 인기조정래 천년의 질문 오디오북으로 선공개오디오북 만권 ...
# 2  아마존과 구글이 이끌어국내에선 통신사 주도지디넷코리아권혜미 기자스마트폰 다음은 스마...
# 3  기가지나 테이블TV에 연동해 실제 녹음 진행아이뉴스 김문기 기자 인공지능 스피커AI...
# 4  커버스토리 기적을 만드는 최강 영업팀 KT AI사업단 AI플랫폼사업팀한경비즈니스이명...
#
#                                        sentence_text
# 0  [KT가 인공지능AI을 적용한 기업영업 솔루션을 개발한다., 스마트로봇 기가지니와 ...
# 1  [AI스피커도 키즈 오디오북 인기조정래 천년의 질문 오디오북으로 선공개오디오북 만권...
# 2  [아마존과 구글이 이끌어국내에선 통신사 주도지디넷코리아권혜미 기자스마트폰 다음은 스...
# 3  [기가지나 테이블TV에 연동해 실제 녹음 진행아이뉴스 김문기 기자 인공지능 스피커A...
# 4  [커버스토리 기적을 만드는 최강 영업팀 KT AI사업단 AI플랫폼사업팀한경비즈니스이...

# %% [markdown]
# - 나눈 sentence들을 각각 형태소 분석하기

# %%
# 미등록단어 지정하여 Komoran 형태소 분석 
from konlpy.tag import Komoran

#dicpath = './unregistered_dic_blog_test.txt'
#komoran = Komoran(userdic= dicpath)
dicpath = './unregistered.txt'
komoran = Komoran(userdic=dicpath)

# %%
final_clova_df['pos_sentence_text'] = final_clova_df['sentence_text'].map(lambda l: [komoran.pos(sentence) for sentence in l])

# %%
#[" ".join([wors[0] for word in sent]) for sent in final_df['pos_sentence_text']]
def pos_by_sentence(l):
    result = []
    for sent in l:
        result.append(" ".join([word[0] for word in sent]))
    return result

final_clova_df['pos_sentence_text'] = final_clova_df['pos_sentence_text'].map(pos_by_sentence)

# %%
final_clova_df.head()

# %% [markdown]
# #### sentence별 긍정(1) / 부정(-1)으로 나누기

# %%
def label_by_sentence(doc):
    loaded_vectorizer = pickle.load(open('./pretrained_vectorizer.pickle', 'rb'))
    loaded_model = pickle.load(open('./pretrained_model.pickle', 'rb'))
    
    tfidf_features = loaded_vectorizer.transform(doc)
    pred_labels = loaded_model.predict(tfidf_features)
    return pred_labels

final_clova_df['label_sentence_text'] = final_clova_df['pos_sentence_text'].map(label_by_sentence)

# %%
final_clova_df.to_csv("기가지니.csv", encoding='utf-8')
