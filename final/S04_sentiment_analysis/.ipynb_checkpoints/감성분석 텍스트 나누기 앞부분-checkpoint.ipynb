# %%
import pandas as pd
import numpy as np
import pickle
import re
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### 데이터 합치기 - 뉴스, 블로그, 리뷰(플레이스토어 + 11번가)

# %% [markdown]
# #### [ 뉴스 ]

# %%
clova_news_df = pd.read_csv("../../data/naver_news/clova_speaker_news.csv", index_col=0)
clova_news_df['source'] = 'news'
clova_news_df.head()
# Out:
#                             title          publisher         date  \
# 0        "영어회화 배우려고 인공지능 스피커 샀어요"               조선비즈  2017.09.01.
# 1     삼성도 곧 참전…치열한 ‘AI 스피커’ 거실쟁탈전  ZDNet Korea언론사 선정  2019.04.26.
# 2    네이버, LGU+와 손잡고 새 AI 스피커 내놓는다  ZDNet Korea언론사 선정  2019.04.19.
# 3              '장애인의 날' 맞이한 IT기업들          블로터언론사 선정  2019.04.19.
# 4  네이버-LGU+, 장애인 위한 AI 접근성 서비스 확대          블로터언론사 선정  2019.04.17.
#
#                                                  url  \
# 0  https://news.naver.com/main/read.nhn?mode=LSD&...
# 1  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2  https://news.naver.com/main/read.nhn?mode=LSD&...
# 3  https://news.naver.com/main/read.nhn?mode=LSD&...
# 4  https://news.naver.com/main/read.nhn?mode=LSD&...
#
#                                                texts source
# 0  직장인 김모(35) 씨는 지난 7월 미국 출장 당시 인공지능(AI) 스피커 구글 홈...   news
# 1  아마존과 구글이 이끌어…국내에선 통신사 주도(지디넷코리아=권혜미 기자)스마트폰 다음...   news
# 2  LG유플러스 IoT 서비스에 사용…사전예약 시작(지디넷코리아=김민선 기자)네이버가 ...   news
# 3  매년 4월20일은 '장애인의 날'이다. 장애인과 비장애인이 차별없는 일상을 살아갈 ...   news
# 4  "주변인들 도움 없이 택시를 부를 수 있게 돼 좋다"LG유플러스가 지난 3월 내놓은...   news

# %% [markdown]
# <br/><br/>
# #### [ 블로그 ]

# %%
clova_blog_df = pd.read_csv("../../data/naver_blog/naverclova_speaker_blog.csv", encoding='utf-16', index_col=0)
clova_blog_df['source'] = 'blog'
clova_blog_df.head()
# Out:
#                                            title     publish_datetime  \
# 0            블루투스 라디오 알람시계 'iLuv 모닝콜2' 리뷰 & 어플추천  2017-09-02 11:43:00
# 1                              WAVE 리뷰를 하려다가 QA?  2017-09-02 08:50:00
# 2                                  핀테크의 교육이 시급하다  2017-09-03 20:49:00
# 3                          스마트 스피커는 어떤 제품들이 있을까?  2017-09-04 17:11:00
# 4  AI, 클라우드 플랫폼이라는 전장에서 모두가 만난다 - Byline Network                  NaN
#
#                                                 text  \
# 0  침대 옆 공간은 좁지만 놓아야 할 것들이 꽤 많아서 늘 비좁은데, 침대맡에 하나 두...
# 1  WAVE 를 입수한 김에 큰 맘먹고 리뷰를 한 번 써보려다가 결국 근사한 리뷰작성 ...
# 2  통장없이 휴대폰 하나에 공인인증서만 받아두면 왠만한 은행업무는 휴대폰 하나로 끝난다...
# 3  최근 등장한 새로운 용어바로 스마트 스피커입니다.간단히 설명하면 음성인식이 가능해서...
# 4                                                NaN
#
#                                                  url source
# 0  http://blog.naver.com/PostView.nhn?blogId=revi...   blog
# 1  http://blog.naver.com/PostView.nhn?blogId=revi...   blog
# 2  http://blog.naver.com/PostView.nhn?blogId=revi...   blog
# 3  http://blog.naver.com/PostView.nhn?blogId=revi...   blog
# 4  http://blog.naver.com/PostView.nhn?blogId=revi...   blog

# %% [markdown]
# <br/>
# #### [ 플레이스토어 리뷰 ]

# %%
clova_review_df = pd.read_csv('../../data/playstore_review_naver_clova.csv')
clova_review_df['source'] = 'review'
clova_review_df.head()
# Out:
#      name  ratings          date  helpful vote  \
# 0     김헌민        5  2019년 4월 25일             0
# 1     김민성        3  2019년 4월 20일             0
# 2     정진심        1  2019년 4월 30일             2
# 3     민석김        1   2019년 5월 3일             1
# 4  DY Kim        3  2019년 4월 21일             1
#
#                                              comment  source
# 0  국내 최고 사이트 네이버의 인공지능 도전에 박수 드립니다. 좀더 나아가서 "네이버 ...  review
# 1  18일 업데이트 이후 리모콘 조작시(티비, 셋탑) 장치를 인식하지 못하는 경우가 종...  review
# 2  동의가 안눌러져요ㅠ 왜이런가요? 뭐가 잘못된건가요? 4월23일 업데이트 되었다는데 ...  review
# 3  취침 예약 음악 종료하면 "예약된 시간이 되었어요 재생을 중단할게요" 라고 하면서 ...  review
# 4  아이폰에서도 써 보고 갤럭시에서도 써보는데 안정성이 특히 떨어지네요 저는 주로 음악...  review

# %% [markdown]
# <br/>
# #### [ 11번가 리뷰 ]

# %%
_11st_clova_review_df = pd.read_csv('../../data/review_data_clova.csv', index_col=0)
_11st_clova_review_df['source'] = 'review'
_11st_clova_review_df.head()
# Out:
#    index                                               nugu  score  source
# 0      1  택배 잘 받았어요... 언니 생일선물로 줬는데 만족하더라구요 그런데 같이 온 네이버...      4  review
# 1      2  좋은 가격에 잘 산 것 같아요. 단지, 스피커가 필요해서 겸사겸사 산 건데, 인공지...      4  review
# 2      3  여기서 사는거 서비스센터갔더니 정품이아니고 등록도 안되어있다고 AS안됩니다. 그래서...      1  review
# 3      4  좋아요! 재고부족으로 배송이 늦어질수 있다는 안내도 거의 바로 받았고 실제로 배송이...      5  review
# 4      5  선물했는데, 샤오미랑 연동이 돼서 공기청정기와 로봇청소기도 쉽게 제어할 수 있고 소...      5  review

# %% [markdown]
# <br/>
# #### [ 데이터 합치기 ]

# %%
clova_df = pd.DataFrame({"date": pd.concat([clova_news_df.date, clova_blog_df.publish_datetime, 
                                            clova_review_df.date, pd.Series([None] * len(_11st_clova_review_df))]),
                         "texts":pd.concat([clova_news_df.texts, clova_blog_df.text, 
                                            clova_review_df.comment, _11st_clova_review_df.nugu]),
                         'source':pd.concat([clova_news_df.source, clova_blog_df.source, 
                                             clova_review_df.source, _11st_clova_review_df.source])
                        })

# %%
clova_df = clova_df[clova_df.texts.notnull()].copy()
clova_df.reset_index(inplace=True, drop=True)
clova_df
# Out:
#              date                                              texts  source
# 0     2017.09.01.  직장인 김모(35) 씨는 지난 7월 미국 출장 당시 인공지능(AI) 스피커 구글 홈...    news
# 1     2019.04.26.  아마존과 구글이 이끌어…국내에선 통신사 주도(지디넷코리아=권혜미 기자)스마트폰 다음...    news
# 2     2019.04.19.  LG유플러스 IoT 서비스에 사용…사전예약 시작(지디넷코리아=김민선 기자)네이버가 ...    news
# 3     2019.04.19.  매년 4월20일은 '장애인의 날'이다. 장애인과 비장애인이 차별없는 일상을 살아갈 ...    news
# 4     2019.04.17.  "주변인들 도움 없이 택시를 부를 수 있게 돼 좋다"LG유플러스가 지난 3월 내놓은...    news
# 5     2019.03.25.  LG유플러스는 몰입형 디스플레이를 탑재한 차세대 AI 스피커 'U+AI 어벤져스'를...    news
# 6             NaN  SKT 화면 있는 ‘누구 네모’ 출시말로 물으면 화면에도 정보 표시화면 통한 통화·...    news
# 7     2017.09.04.  리딩투자증권에서 4일 NAVER(035420)에 대해 "'샐리야~ 기업가치 올려줘 ...    news
# 8             NaN  최근 국내외 정보통신기술(ICT) 기업들이 앞다퉈 인공지능(AI) 스피커를 선보이고...    news
# 9     2017.09.05.  시대의 버즈워드가 된 ‘인공지능’(AI)을 중심으로 미래 사회의 모습을 짚어보려는 ...    news
# 10            NaN  SKT 이어 네이버·카카오·KT 잇따라 출사표LG유플러스·삼성전자도 신제품 곧 선보...    news
# 11    2017.09.08.  [아이뉴스24 도민선기자] 통신과 포털은 물론 제조사까지 인공지능(AI) 플랫폼 확...    news
# 12            NaN  스피커와 '누구'로 통칭됐지만플랫폼·스피커 구분 흐름 맞춰별도 명칭 정해 생태계 확...    news
# 13    2017.09.10.  본문 이미지 영역WAVE. /사진제공=네이버웨이브아이언맨이 등장하는 영화를 본 사람...    news
# 14    2017.09.11.  [한국경제TV 트렌드와치팀 김경민 기자]카카오 미니 예약 판매 소식에 네이버, 페이...    news
# 15    2017.09.11.  인공지능(AI) 스피커 시장 경쟁이 뜨겁다. 해외에선 알파벳(구글)이 선두주자 아마...    news
# 16            NaN  [한겨레] 18일부터 ‘카카오미니’ 예약판매네이버 다음달 ‘웨이브’ 선보여“인공지능...    news
# 17    2017.09.11.  IT조선 연결지성센터, 마이크로소프트웨어는 9월21일 인사이트셰어링: ‘위키백과 에...    news
# 18            NaN  카카오 '카카오미니' 예판 속네이버 '웨이브' 2차이벤트 맞불"음원 이용권 내세워 ...    news
# 19    2017.09.12.  웨이브 2차 할인 판매…카카오 미니도 18일 예약판매 개시네이버 AI 스피커 '웨이...    news
# 20    2017.09.12.  네이버 웨이브 제공. 오는 18일부터 예약판매에 들어가는 '카카오미니'가 파격적인 ...    news
# 21            NaN  네이버 AI 스피커 '웨이브'네이버 인공지능(AI) 스피커 '웨이브(WAVE)'는 ...    news
# 22    2017.09.14.  카카오와 삼성전자가 인공지능(AI) 분야에서 손을 잡았다.카카오는 자사의 AI 플랫...    news
# 23    2017.09.14.  삼성·카카오·네이버 등 시장선점 위해 합종연횡…KT는 美 스타트업 투자 AI 강조하...    news
# 24            NaN  카카오, 해외 네트워크 강화 기대제네시스 G70에도 음성인식 탑재네이버 클로바, 퀄...    news
# 25            NaN  14일 유가증권시장에서 3만6000원(4.94%) 오른 76만5000원에 마감했다....    news
# 26    2017.09.15.  제품에 라인·카카오 캐릭터 부각…친밀감 앞세운 시장 진입 의도인 듯(서울=연합뉴스)...    news
# 27            NaN  ‘AI비서 라이벌’ 제휴 첫 사례카카오미니로는 삼성가전 제어콘텐츠ㆍ하드웨어서 시너지...    news
# 28            NaN  [동아일보][토요판 커버스토리]AI 비서 어디쯤 오고 있나《전자, 통신, 인터넷, ...    news
# 29    2017.09.17.  네이버 '웨이브' 2차 시범판매도 완판카카오 '카카오미니' 18일 선착순 예판수익보...    news
# ...           ...                                                ...     ...
# 7509         None                             너무귀여워요 ㅎ 똑똑하네요 음질도 좋아요  review
# 7510         None                                생각보다 기능이나 인식율이 별로네요  review
# 7511         None                                너무 이뻐용 받는 사람도 좋아하네요  review
# 7512         None                              정말 잘 구매한듯 ~ 쵝오 입니다 ^^  review
# 7513         None                             굉장히 좋아요~ ai 기능도 쵝오!!!!  review
# 7514         None                                    너무귀여워요아이도 좋아하네요  review
# 7515         None                                    배송도 빠르고 너무 귀여워요  review
# 7516         None                   뭔가 말을 인식할때도 있고 못할때도 있고, 기기가 불량인지  review
# 7517         None                                     좋습니다. 귀여워요 미니언  review
# 7518         None                                     배송도 빠르고 잘 받았어요  review
# 7519         None                                        감사합니다 너무좋아요  review
# 7520         None                                         미니언즈 귀여워요!  review
# 7521         None                 친구에게 선물 했는데 너무 너무 좋아하네요 육아의 필수템이에요  review
# 7522         None                           아무 이상없이 잘 작동합니다. 견고해요 ㅎㅎ  review
# 7523         None                            우리 아기가 너무 좋아하네요~ 감사합니다.  review
# 7524         None                              여자친구 선물로 줬는데 정말 좋아합니다  review
# 7525         None                               말도 잘 알아듣고 괜찮습ㄴ다 귀여워요  review
# 7526         None                                 아이 위해 샀는데 많이 좋아하네요  review
# 7527         None                                    조카가 많이 좋아하네요!!!  review
# 7528         None                                         너무좋은제품같아요.  review
# 7529         None      와우 신세계~~~~^^ 뒤늦게 ㅋㅋ아이 동요이제 편하게 들려줄수 있어 넘나 좋네요  review
# 7530         None                   브라운으로 구매했었는데맘에 들어서 미니언즈 또 구매했어요!  review
# 7531         None             5살딸아이가 너무좋아해요^^아이 이름까지 불러주니 저도 기분이좋네요♡  review
# 7532         None  전 원래 샐리야 사용자입니다. 친구에게 선물로 주었는데 기존 샐리와 비교할수없을 정...  review
# 7533         None         선물로 주려고 샀는데...아직 전해 주지 못했지만...좋아 할것 같네요...  review
# 7534         None               넘 귀엽고 똑똑합니다. ㅋㅋ 미니언즈 목소리도 되니 ㅋㅋ 재밋어요  review
# 7535         None                                 너무 예쁘고 좋네요. 만족합니다~  review
# 7536         None                                       배송도 빠르고 좋아요!  review
# 7537         None                                       귀여워요 잘쓸게요 :)  review
# 7538         None                                         말귀를 잘알아들아요  review
#
# [7539 rows x 3 columns]

# %% [markdown]
# <br/><br/>
# ### 텍스트 전처리

# %%
def clear_content(temp):
    #want_remove = ['flash 오류를 우회하기 위한 함수 추가', 'function _flash_removeCallback', 
    #               '\n', '\.\.', '[\w]+ 기자', '\xa0', '\r', '\t']
    content = re.sub('[a-zA-Z0-9]+[a-zA-Z0-9+-_.]+@[a-zA-Z0-9-]+\.[a-zA-Z0-9-.]+', ' ', temp) # 이메일주소 없애기
    content = re.sub('(https?:\/\/)?([\da-z\.-]+)\.([a-z\.]{2,6})([\/\w_\.-]*)*\/?', ' ', content) # URL 없애기
    #content = re.sub('|'.join(want_remove), ' ', content)
    content = re.sub('\n|\r|\xa0', ' ', content)
    ㅠcontent = re.sub('[\(]', ' ', content) # 커머스(전자상거래)와' -> '커머스전자상거래와' 이렇게 변하던것을 -> '커머스 전자상거래'
    content = re.sub('~', ' ', content)
    #content = re.sub('[^\.\?\!\^^\♥\♡\w\d\s]','', content) # 불필요한 기호 없애기
    content = re.sub('\d', '', content)
    content = re.sub('[^\.\?\!\^^\♥\♡\w\s]','', content) # 불필요한 기호 없애기
    while '  ' in content: content = content.replace('  ', ' ') # 빈칸 없애주기 
    content = content.strip()
    return content

# %% [markdown]
# <br/><br/>
# ### 모델을 이용해서 네이버 블로그 데이터(中 clova) sentence별 긍정/부정 나누기

# %%
clova_df["preprocessed_text"] = clova_df['texts'].map(clear_content)

# %%
clova_df.head()
# Out:
#           date                                              texts source  \
# 0  2017.09.01.  직장인 김모(35) 씨는 지난 7월 미국 출장 당시 인공지능(AI) 스피커 구글 홈...   news
# 1  2019.04.26.  아마존과 구글이 이끌어…국내에선 통신사 주도(지디넷코리아=권혜미 기자)스마트폰 다음...   news
# 2  2019.04.19.  LG유플러스 IoT 서비스에 사용…사전예약 시작(지디넷코리아=김민선 기자)네이버가 ...   news
# 3  2019.04.19.  매년 4월20일은 '장애인의 날'이다. 장애인과 비장애인이 차별없는 일상을 살아갈 ...   news
# 4  2019.04.17.  "주변인들 도움 없이 택시를 부를 수 있게 돼 좋다"LG유플러스가 지난 3월 내놓은...   news
#
#                                    preprocessed_text
# 0  직장인 김모 씨는 지난 월 미국 출장 당시 인공지능AI 스피커 구글 홈을 사 왔다....
# 1  아마존과 구글이 이끌어국내에선 통신사 주도지디넷코리아권혜미 기자스마트폰 다음은 스마...
# 2  LG유플러스 IoT 서비스에 사용사전예약 시작지디넷코리아김민선 기자네이버가 LG유플...
# 3  매년 월일은 장애인의 날이다. 장애인과 비장애인이 차별없는 일상을 살아갈 수 있도록...
# 4  주변인들 도움 없이 택시를 부를 수 있게 돼 좋다LG유플러스가 지난 월 내놓은 장애...

# %%
del_idx = []
for num, i in enumerate(clova_df['preprocessed_text']):
    if i == '' or i == None or i == ' ':
        del_idx.append(num)
print(del_idx)
# Out:
# [2108, 4953]

# %%
clova_df.loc[clova_df.index[del_idx]]
# Out:
#                      date     texts  source preprocessed_text
# 2108  2018-04-17 17:09:00  20180410    blog
# 4953          2018년 6월 6일         😤  review

# %%
final_clova_df = clova_df.drop(clova_df.index[del_idx]).copy()

# %%
# 빈 데이터들을 다 삭제하고 난 뒤, 인덱스를 다시 0부터 순서대로 부여해 줌
final_clova_df.reset_index(drop=True, inplace=True)

# %%
final_clova_df.head()
# Out:
#           date                                              texts source  \
# 0  2017.09.01.  직장인 김모(35) 씨는 지난 7월 미국 출장 당시 인공지능(AI) 스피커 구글 홈...   news
# 1  2019.04.26.  아마존과 구글이 이끌어…국내에선 통신사 주도(지디넷코리아=권혜미 기자)스마트폰 다음...   news
# 2  2019.04.19.  LG유플러스 IoT 서비스에 사용…사전예약 시작(지디넷코리아=김민선 기자)네이버가 ...   news
# 3  2019.04.19.  매년 4월20일은 '장애인의 날'이다. 장애인과 비장애인이 차별없는 일상을 살아갈 ...   news
# 4  2019.04.17.  "주변인들 도움 없이 택시를 부를 수 있게 돼 좋다"LG유플러스가 지난 3월 내놓은...   news
#
#                                    preprocessed_text
# 0  직장인 김모 씨는 지난 월 미국 출장 당시 인공지능AI 스피커 구글 홈을 사 왔다....
# 1  아마존과 구글이 이끌어국내에선 통신사 주도지디넷코리아권혜미 기자스마트폰 다음은 스마...
# 2  LG유플러스 IoT 서비스에 사용사전예약 시작지디넷코리아김민선 기자네이버가 LG유플...
# 3  매년 월일은 장애인의 날이다. 장애인과 비장애인이 차별없는 일상을 살아갈 수 있도록...
# 4  주변인들 도움 없이 택시를 부를 수 있게 돼 좋다LG유플러스가 지난 월 내놓은 장애...

# %% [markdown]
# - 각 문헌을 sentence별로 나누기

# %%
import nltk.tokenize
final_clova_df['sentence_text'] = final_clova_df['preprocessed_text'].map(nltk.tokenize.sent_tokenize)

# %%
final_clova_df.head()
# Out:
#           date                                              texts source  \
# 0  2017.09.01.  직장인 김모(35) 씨는 지난 7월 미국 출장 당시 인공지능(AI) 스피커 구글 홈...   news
# 1  2019.04.26.  아마존과 구글이 이끌어…국내에선 통신사 주도(지디넷코리아=권혜미 기자)스마트폰 다음...   news
# 2  2019.04.19.  LG유플러스 IoT 서비스에 사용…사전예약 시작(지디넷코리아=김민선 기자)네이버가 ...   news
# 3  2019.04.19.  매년 4월20일은 '장애인의 날'이다. 장애인과 비장애인이 차별없는 일상을 살아갈 ...   news
# 4  2019.04.17.  "주변인들 도움 없이 택시를 부를 수 있게 돼 좋다"LG유플러스가 지난 3월 내놓은...   news
#
#                                    preprocessed_text  \
# 0  직장인 김모 씨는 지난 월 미국 출장 당시 인공지능AI 스피커 구글 홈을 사 왔다....
# 1  아마존과 구글이 이끌어국내에선 통신사 주도지디넷코리아권혜미 기자스마트폰 다음은 스마...
# 2  LG유플러스 IoT 서비스에 사용사전예약 시작지디넷코리아김민선 기자네이버가 LG유플...
# 3  매년 월일은 장애인의 날이다. 장애인과 비장애인이 차별없는 일상을 살아갈 수 있도록...
# 4  주변인들 도움 없이 택시를 부를 수 있게 돼 좋다LG유플러스가 지난 월 내놓은 장애...
#
#                                        sentence_text
# 0  [직장인 김모 씨는 지난 월 미국 출장 당시 인공지능AI 스피커 구글 홈을 사 왔다...
# 1  [아마존과 구글이 이끌어국내에선 통신사 주도지디넷코리아권혜미 기자스마트폰 다음은 스...
# 2  [LG유플러스 IoT 서비스에 사용사전예약 시작지디넷코리아김민선 기자네이버가 LG유...
# 3  [매년 월일은 장애인의 날이다., 장애인과 비장애인이 차별없는 일상을 살아갈 수 있...
# 4  [주변인들 도움 없이 택시를 부를 수 있게 돼 좋다LG유플러스가 지난 월 내놓은 장...

# %% [markdown]
# - 나눈 sentence들을 각각 형태소 분석하기

# %%
# 미등록단어 지정하여 Komoran 형태소 분석 
from konlpy.tag import Komoran

#dicpath = './unregistered_dic_blog_test.txt'
#komoran = Komoran(userdic= dicpath)
dicpath = './unregistered.txt'
komoran = Komoran(userdic=dicpath)

# %%
final_clova_df['pos_sentence_text'] = final_clova_df['sentence_text'].map(lambda l: [komoran.pos(sentence) for sentence in l])

# %%
#[" ".join([wors[0] for word in sent]) for sent in final_df['pos_sentence_text']]
def pos_by_sentence(l):
    result = []
    for sent in l:
        result.append(" ".join([word[0] for word in sent]))
    return result

final_clova_df['pos_sentence_text'] = final_clova_df['pos_sentence_text'].map(pos_by_sentence)

# %%
final_clova_df.head()
# Out:
#           date                                              texts source  \
# 0  2017.09.01.  직장인 김모(35) 씨는 지난 7월 미국 출장 당시 인공지능(AI) 스피커 구글 홈...   news
# 1  2019.04.26.  아마존과 구글이 이끌어…국내에선 통신사 주도(지디넷코리아=권혜미 기자)스마트폰 다음...   news
# 2  2019.04.19.  LG유플러스 IoT 서비스에 사용…사전예약 시작(지디넷코리아=김민선 기자)네이버가 ...   news
# 3  2019.04.19.  매년 4월20일은 '장애인의 날'이다. 장애인과 비장애인이 차별없는 일상을 살아갈 ...   news
# 4  2019.04.17.  "주변인들 도움 없이 택시를 부를 수 있게 돼 좋다"LG유플러스가 지난 3월 내놓은...   news
#
#                                    preprocessed_text  \
# 0  직장인 김모 씨는 지난 월 미국 출장 당시 인공지능AI 스피커 구글 홈을 사 왔다....
# 1  아마존과 구글이 이끌어국내에선 통신사 주도지디넷코리아권혜미 기자스마트폰 다음은 스마...
# 2  LG유플러스 IoT 서비스에 사용사전예약 시작지디넷코리아김민선 기자네이버가 LG유플...
# 3  매년 월일은 장애인의 날이다. 장애인과 비장애인이 차별없는 일상을 살아갈 수 있도록...
# 4  주변인들 도움 없이 택시를 부를 수 있게 돼 좋다LG유플러스가 지난 월 내놓은 장애...
#
#                                        sentence_text  \
# 0  [직장인 김모 씨는 지난 월 미국 출장 당시 인공지능AI 스피커 구글 홈을 사 왔다...
# 1  [아마존과 구글이 이끌어국내에선 통신사 주도지디넷코리아권혜미 기자스마트폰 다음은 스...
# 2  [LG유플러스 IoT 서비스에 사용사전예약 시작지디넷코리아김민선 기자네이버가 LG유...
# 3  [매년 월일은 장애인의 날이다., 장애인과 비장애인이 차별없는 일상을 살아갈 수 있...
# 4  [주변인들 도움 없이 택시를 부를 수 있게 돼 좋다LG유플러스가 지난 월 내놓은 장...
#
#                                    pos_sentence_text
# 0  [직장인 김 모 씨 는 지나 ㄴ 월 미국 출장 당시 인공지능 AI 스피커 구글 홈 ...
# 1  [아마존 과 구글 이 이끌 어 국내 에서 ㄴ 통신사 주 도지 디 넷 코리아 권 혜미...
# 2  [LG유플러스 IoT 서비스 에 사용 사전 예약 시작 지 디 넷 코리아 김민서 ㄴ ...
# 3  [매년 월 일 은 장애인의 날 이 다 ., 장애인 과 비 장애인 이 차별 없 는 일...
# 4  [주변 이 ㄴ들 도움 없이 택시 를 부르 ㄹ 수 있 게 되 어 좋 다 LG 유 플러...

# %% [markdown]
# #### sentence별 긍정(1) / 부정(-1)으로 나누기

# %%
def label_by_sentence(doc):
    loaded_vectorizer = pickle.load(open('./pretrained_vectorizer.pickle', 'rb'))
    loaded_model = pickle.load(open('./pretrained_model.pickle', 'rb'))
    
    tfidf_features = loaded_vectorizer.transform(doc)
    pred_labels = loaded_model.predict(tfidf_features)
    return pred_labels

final_clova_df['label_sentence_text'] = final_clova_df['pos_sentence_text'].map(label_by_sentence)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-473734801ee5> in <module>()
#       7     return pred_labels
#       8
# ----> 9 final_clova_df['label_sentence_text'] = final_clova_df['pos_sentence_text'].map(label_by_sentence)
#
# /Users/Taewoo/anaconda2/envs/python36/lib/python3.6/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    2996         """
#    2997         new_values = super(Series, self)._map_values(
# -> 2998             arg, na_action=na_action)
#    2999         return self._constructor(new_values,
#    3000                                  index=self.index).__finalize__(self)
#
# /Users/Taewoo/anaconda2/envs/python36/lib/python3.6/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#    1002
#    1003         # mapper is a function
# -> 1004         new_values = map_f(values, mapper)
#    1005
#    1006         return new_values
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-22-473734801ee5> in label_by_sentence(doc)
#       1 def label_by_sentence(doc):
# ----> 2     loaded_vectorizer = pickle.load(open('./pretrained_vectorizer.pickle', 'rb'))
#       3     loaded_model = pickle.load(open('./pretrained_model.pickle', 'rb'))
#       4
#       5     tfidf_features = loaded_vectorizer.transform(doc)
#
# /Users/Taewoo/anaconda2/envs/python36/lib/python3.6/site-packages/sklearn/base.py in __setstate__(self, state)
#     242             return state
#     243
# --> 244     def __setstate__(self, state):
#     245         if type(self).__module__.startswith('sklearn.'):
#     246             pickle_version = state.pop("_sklearn_version", "pre-0.18")
#
# KeyboardInterrupt:

# %%
final_clova_df
