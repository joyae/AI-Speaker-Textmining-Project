# %%
import subprocess
import os
import re
import csv

class MalletError(Exception):
    pass


class MalletTopicModel(object):
    def __init__(self, mallet_dir, memory=1):
        '''
        Constructor
        mallet_dir : str : file path of Mallet-3 directory
        memory : int, float : maximum gigabytes of memory to allocate to Mallet
        '''
        self.memory = memory
        #self.mallet_dir = mallet_dir if mallet_dir.endswith('/') else mallet_dir + '/'
        self.mallet_dir = mallet_dir

        self.set_memory()
        self.set_output_dir()

    def set_memory(self):
        '''
        Sets the memory limit by editing a line in a batch file
        Default from constructor is 1gb
        '''
        # reads
        full_path = os.path.join(self.mallet_dir, 'bin/mallet')
        with open(full_path, 'r') as file:
            filedata = file.read()
        # replaces memory line
        filedata = re.sub('set MALLET_MEMORY=.*', 'set MALLET_MEMORY=' + str(self.memory) + 'g', filedata)
        # writes
        with open(full_path, 'w') as file:
            file.write(filedata)

    def set_output_dir(self):
        '''
        Creates (if not already present) an output folder in the Mallet directory
        Sets stdout file path
        '''
        if not os.path.isdir(self.mallet_dir + 'output'):
            os.mkdir(self.mallet_dir + 'output')

        outdir_full_path = os.path.join(self.mallet_dir, 'output')
        self.output_dir = outdir_full_path
        self.out_full_path = os.path.join(self.output_dir, 'output.txt')
        self.stdout = self.out_full_path

    def call(self, command):
        '''
        Executes a command within the Mallet directory
        Redirects all output to a txt file
        '''

        print(command)
        result = subprocess.call(command, cwd=self.mallet_dir, stderr=subprocess.STDOUT, stdout=open(self.stdout, 'w'),shell=False)

    def execute(self, command, args):
        '''
        Cannot determine success/failure of Mallet command execution from exit codes (0 or 1)
        Checks whether the file that was supposed to be generated by a command is actually generated
        If the file did not previously exist, checks if it exists after command execution
        Otherwise, checks whether the modified timestamp of the file has changed
        '''
        start = None
        for arg in args:
            # for train_topics, this will be either 'output-topic-keys' or 'output-doc-topics' (not 'topic-word-weights-file')
            # it should not matter which of the three are checked; if the command fails, neither should be generated
            if 'output' in arg:
                if os.path.isfile(args[arg]):
                    start = os.path.getmtime(args[arg])
                break
        self.call(command)
        stop = None
        if os.path.isfile(args[arg]):
            stop = os.path.getmtime(args[arg])
        if not stop or start == stop:
            raise MalletError('\n\n' + args[arg] + ' was not generated from the command:\n\n"' + ' '.join(command) +
                              '"\n\nCheck ' + self.out_full_path + ' for details.\n')

    def build_command(self, operation, kwargs):
        '''
        Converts the command arguments from dictionary to list format
        '''
        command = [r'bin\mallet.bat' if os.name == 'nt' else 'bin/mallet', operation]
        for key, value in kwargs.items():
            if isinstance(value, list):
                command.extend(['--' + key.replace('_', '-'), ' '.join(value)])
            else:
                command.extend(['--' + key.replace('_', '-'), value])
        return command

    def import_dir(self, **kwargs):
        '''
        Calls the import-dir Mallet command
        Overwrites some arguments
        '''
        kwargs['keep_sequence'] = True  # topic modeling currently only supports feature sequences: use --keep-sequence option when importing data.
        full_path = os.path.join(self.output_dir, 'import.mallet')
        kwargs['output'] = full_path
        command = self.build_command(operation='import-dir', kwargs=kwargs)
        self.execute(command, kwargs)

    def import_file(self, **kwargs):
        '''
        Calls the import-file Mallet command
        Overwrites some arguments
        '''
        kwargs['keep_sequence'] = str(True)  # topic modeling currently only supports feature sequences: use --keep-sequence option when importing data.
        full_path = os.path.join(self.output_dir, 'import.mallet')
        kwargs['output'] = full_path

        kwargs['label-as-features'] = str(True)
        command = self.build_command(operation='import-file', kwargs=kwargs)
        self.execute(command, kwargs)

    def train_topics(self, **kwargs):
        '''
        Calls the train-topics Mallet command
        Overwrites some arguments
        '''
        instance_input = os.path.join(self.output_dir, 'import.mallet')
        kwargs['input'] = instance_input
        self.word_weights_file = os.path.join(self.output_dir, 'topic_word_weights.txt')
        kwargs['topic-word-weights-file'] = self.word_weights_file
        self.topic_keys_file = os.path.join(self.output_dir, 'topic_keys.txt')
        kwargs['output-topic-keys'] = self.topic_keys_file  # these can also be derived from topic-word-weights-file
        self.doc_topics_file = os.path.join(self.output_dir, 'doc_topics.txt')
        kwargs['output-doc-topics'] = self.doc_topics_file

        self.parameter_file = os.path.join(self.output_dir, 'topic_parameter.txt')
        kwargs['parameter-filename'] = self.parameter_file

        kwargs ['num-top-words'] = str(30)
        kwargs['num-iterations'] = str(2000);
        kwargs['num-topics'] = str(10);

        # sets the doc-topics-threshold to a very low number if not specified
        # output-doc-topics format changes when this parameter is not specified
        # see https://github.com/mimno/Mallet/issues/41
        if not kwargs.get('doc-topics-threshold', False):
            kwargs['doc-topics-threshold'] = str(0.00001)
        command = self.build_command(operation='train-topics', kwargs=kwargs)
        self.execute(command, kwargs)

        # parses the files generated by the command into python objects
        self.parse_topic_keys()
        self.parse_doc_topics()
        self.parse_word_weights()

    def parse_topic_keys(self):
        '''
        Parses the output-topic-keys txt file generated by train_topics into a python object
        {topic # (int): {dirichlet parameter: float, words: list}, ... }
        '''
        self.topic_keys = dict()
        with open(self.topic_keys_file, mode='r', encoding='utf8') as file:
            for line in file:
                data = re.split('\t| ',
                                line.strip())  # cols 0, 1, and 2 are tab delimited, the rest are space delimited
                self.topic_keys[int(data[0])] = {'dirichlet': float(data[1]), 'words': self.process_words(data[2:])}

    def parse_doc_topics(self):
        '''
        Parses the output-doc-topics txt file generated by train_topics into a python object
        {document # (int): {document name: e.g. file path (str), topics: {topic # (int): weight (float), ... }}, ... }
        '''
        self.doc_topics = dict()
        with open(self.doc_topics_file, mode='r', encoding='utf8') as file:
            next(file)
            for line in file:
                data = line.strip().split('\t')
                self.doc_topics[int(data[0])] = {'name': data[1], 'topics': self.process_topics(data[2:])}

    def parse_word_weights(self):
        '''
        Parses the topic-word-weights txt file generated by train_topics into a python object
        {topic # (int): {word (str): weight (float)}, ... }
        '''
        self.word_weights = dict()
        with open(self.word_weights_file, mode='r', encoding='utf8') as file:
            for line in file:
                data = line.strip().split('\t')
                try:
                    self.word_weights[int(data[0])][data[1]] = float(data[2])
                except KeyError:
                    self.word_weights[int(data[0])] = {data[1]: float(data[2])}

    @staticmethod
    def process_words(words):
        return [x.replace('_', ' ') for x in words]

    @staticmethod
    def process_topics(topics):
        topic_weights = dict()
        for i in range(0, len(topics), 2):
            topic_weights[int(topics[i])] = float(topics[i + 1])
        return topic_weights

if __name__ == '__main__':

    model = MalletTopicModel('/Users/yaelinjo/Desktop/notebook/Textmining/mallet')
    #model.import_file(input=r'C:\mallet\topic_input\dblp_sample.txt')
    model.import_file(input=r'/Users/yaelinjo/Desktop/notebook/AIspeaker_project/data/clova_news_input_data.txt')
    model.train_topics()

    print(model.topic_keys)# see output_topic_keys parameter in Train Topics documentation
    print('/n')
    print(model.doc_topics)  # see output_doc_topics parameter in Train Topics documentation
    print('/n')
    print(model.word_weights)  # see topic_word_weights_file parameter in Train Topics documentation
# Out:
# ['bin/mallet', 'import-file', '--input', '/Users/yaelinjo/Desktop/notebook/AIspeaker_project/data/clova_news_input_data.txt', '--keep-sequence', 'True', '--output', '/Users/yaelinjo/Desktop/notebook/Textmining/mallet/output/import.mallet', '--label-as-features', 'True']
# ['bin/mallet', 'train-topics', '--input', '/Users/yaelinjo/Desktop/notebook/Textmining/mallet/output/import.mallet', '--topic-word-weights-file', '/Users/yaelinjo/Desktop/notebook/Textmining/mallet/output/topic_word_weights.txt', '--output-topic-keys', '/Users/yaelinjo/Desktop/notebook/Textmining/mallet/output/topic_keys.txt', '--output-doc-topics', '/Users/yaelinjo/Desktop/notebook/Textmining/mallet/output/doc_topics.txt', '--parameter-filename', '/Users/yaelinjo/Desktop/notebook/Textmining/mallet/output/topic_parameter.txt', '--num-top-words', '30', '--num-iterations', '2000', '--num-topics', '10', '--doc-topics-threshold', '1e-05']
# {0: {'dirichlet': 0.18728, 'words': ['프렌즈', '네이버', '스피커', '캐릭터', '웨이브', '미니언즈', '인공지능', '디자인', '도라에몽', '스마트', '목소리', '브라운', '배터리', '콘텐츠', '블루투스', '플랫폼', '스토어', '이용자', '명령어', '사용자', '저작권', '이벤트', '업데이트', '코리아', '온라인', '프로모션', '라이언', '이용권', '에디션', '애니메이션']}, 1: {'dirichlet': 0.07566, 'words': ['스포츠서울', '시스템', '디자인', '바이오', '위원회', '대통령', '일자리', '기대감', '어벤져스', '티브이', '대한민국', '모바일', '증권사', '가이드라인', '차세대', '배틀그라운드', '현대차', '경쟁력', '연합뉴스tv', '통신비', '과학기술', '역차별', '대기업', '사업자', '근로자', '한국당', 'sbs', '우리나라', '리스트', '케이티']}, 2: {'dirichlet': 0.24805, 'words': ['스피커', 'sk텔레콤', '스마트폰', '아마존', '어시스턴트', '사용자', '한국어', '디스플레이', '데이터', '목소리', '삼성전자', '인공지능', '안드로이드', '갤럭시', '스마트', '알렉사', '내비게이션', 'skt', '유튜브', '보이스', '통신사', '이용자', '자동차', 'nugu', '판매량', '하반기', '오디오', '스트리밍', '지난달', '모바일']}, 3: {'dirichlet': 0.083, 'words': ['카카오', '올림픽', '이벤트', '이용자', '카카오톡', '블록체인', '모바일', '업데이트', '콘텐츠', '페이지', '스마트', '프로그램', '클래식', '스포츠', '저작권', 'for', 'kakao', '플레이', '프로젝트', '온라인', '라이브', '포인트', '실시간', '클라우드', '미디어', '개인정보', '스토어', '이모티콘', '카카오페이지', '엔터테인먼트']}, 4: {'dirichlet': 0.3057, 'words': ['네이버', '플랫폼', '인공지능', '데이터', '사용자', '이용자', '글로벌', '스타트', '개발자', '콘텐츠', '모바일', '시스템', '파트너', '클라우드', '자연어', '인터페이스', '스피커', '컨퍼런스', '알고리즘', 'ict', '저작권', '경쟁력', '생태계', '스마트', '프로젝트', 'api', 'clova', 'naver', '테스트', '미디어']}, 5: {'dirichlet': 0.19292, 'words': ['lg유플러스', 'iot', '스피커', '네이버', 'iptv', '우리집', '인터넷', '스마트', '인공지능', '셋톱박스', '플랫폼', '보일러', '콘텐츠', '가입자', 'sk텔레콤', 'vod', '프렌즈', '가습기', '통신사', '미디어', '데이터', '케이블', '부회장', '한마디', '테이블', '권영수', '아파트', '사용자', '아이들', 'sk브로드밴드']}, 6: {'dirichlet': 0.12297, 'words': ['이데일리', '온라인', '디지털', '스피커', '데일리', '브랜드', '모바일', '시스템', '디지털타임스', '오프라인', 'edaily', '스토어', '편의점', '김현아', '현대백화점', '이마트', '미디어', '라이트', '스마트폰', '업그레이드', '유인나', '시리즈', '신세계', '롯데닷컴', 'krit', '이대호', '쇼핑몰', '홈페이지', '유통업', '컬렉션']}, 7: {'dirichlet': 0.07858, 'words': ['콘텐츠', '오디오북', '네이버', '장애인', '스피커', '오디오', '어린이', '플랫폼', '접근성', '아이들', '사용자', '이용자', '인공지능', '출판사', '스마트', 'news', '디지털', '전자책', '바이브', '저작권', '콜택시', '유튜브', '스마트폰', 'donga', '인터넷', '머니투데이', '성장세', '주인공', '자장가', '영유아']}, 8: {'dirichlet': 0.1537, 'words': ['스마트', 'lg전자', '인공지능', '플랫폼', '삼성전자', 'iot', '스피커', '에어컨', '네이버', '아마존', '청정기', '가전제품', '냉장고', '스마트폰', '인터넷', '브랜드', '세탁기', 'ces', '코웨이', '알렉사', '솔루션', '글로벌', '어시스턴트', '파트너십', '미세먼지', '스타일', '생태계', '프리미엄', '청소기', '신제품']}, 9: {'dirichlet': 0.15706, 'words': ['카카오', '네이버', '스피커', '플랫폼', '인공지능', '카카오톡', '샤오미', '인터넷', '웨이브', '사업자', '이용자', '생태계', '삼성전자', '모바일', '메신저', 'sk텔레콤', '글로벌', '지난달', '사용자', '프렌즈', '하드웨어', '파트너', '콘텐츠', '스마트', '부사장', '사이트', '스마트폰', '시너지', 'voip', '통신사']}}
# /n
# {0: {'name': '"영어회화 배우려고 인공지능 스피커 샀어요"', 'topics': {0: 0.3783443267131705, 2: 0.29014369374585713, 4: 0.13045894435862768, 9: 0.020661825657973372, 7: 0.01926035939322422, 5: 0.003444980683150432, 8: 0.0027445692737510506, 6: 0.0021959370315660265, 3: 0.0014821946816967705, 1: 0.0013511275355091237}}, 1: {'name': '[ET투자뉴스]NAVER, "\'샐리야~ 기업가치…" 매수(신규)-리딩투자증권', 'topics': {4: 0.5251096323862144, 1: 0.21299352196131752, 9: 0.041481966093202094, 2: 0.02400090095707687, 0: 0.022832351844952803, 5: 0.0037099791972389265, 8: 0.0029556899871165158, 6: 0.0023648552647634134, 3: 0.0015962096572119066, 7: 0.001511156269626082}}, 2: {'name': '[블로터11th] 인공지능, 일상에 스며들다', 'topics': {4: 0.6771428245354821, 9: 0.14880063804585525, 1: 0.043979715673937984, 8: 0.03930339630007314, 2: 0.03466678065636982, 7: 0.03182136283703298, 3: 0.002635043557603453, 5: 0.00046938909551441405, 0: 0.0004556746859794301, 6: 0.00029920309919147806}}, 3: {'name': '통신과 포털, 같은 듯 다른 AI 전략', 'topics': {9: 0.3802988890068267, 2: 0.25200037782070966, 4: 0.14762662003292865, 5: 0.11445902353432601, 0: 0.017639373354335047, 3: 0.016798410501411443, 8: 0.001239482897823055, 6: 0.0009917134981265927, 7: 0.0006337106937141635, 1: 0.0006101866289396043}}, 4: {'name': "[사용기] 마음 흔드는 네이버 '웨이브'", 'topics': {0: 0.7351169742470243, 2: 0.14521949380731425, 1: 0.029292029923700103, 4: 0.0029114369912680996, 5: 0.0018373230310135635, 9: 0.0014958308271096085, 8: 0.0014637702793338936, 6: 0.001171166416835214, 3: 0.0007905038302382776, 7: 0.0007483821525767263}}, 5: {'name': '불붙은 AI 스피커 시장 검색·쇼핑·길안내…차별화로 시장선점 ‘각축’', 'topics': {2: 0.4952408028466329, 9: 0.1782092546635855, 8: 0.16552972075525355, 5: 0.03919568935605332, 1: 0.038453564189800706, 4: 0.020922157494197156, 3: 0.00685444874794316, 0: 0.0011853309869464923, 6: 0.0007783067959980854, 7: 0.0004973425697503561}}, 6: {'name': '카카오 미니, 예약 판매 가격은?...네이버 클로바 경쟁', 'topics': {9: 0.6109227889577747, 0: 0.14092710384191268, 6: 0.04162691125034701, 2: 0.024471506858196025, 4: 0.005994134982022558, 5: 0.0037827238873808663, 8: 0.003013644692746251, 3: 0.0016275078857846891, 7: 0.0015407867847167895, 1: 0.0014835910193825672}}, 7: {'name': '[알립니다] 함께 만드는 인터넷 백과사전, 위키백과 에디터톤에 참여하세요', 'topics': {0: 0.590438615246324, 2: 0.20291819823256468, 5: 0.06109316374419323, 9: 0.037141908668782454, 4: 0.0035964809892135344, 8: 0.0018081868156477508, 6: 0.0014467349855023233, 3: 0.0009765047314708134, 7: 0.0009244720708300738, 1: 0.0008901546116295403}}, 8: {'name': '네이버·카카오, AI 스피커 초기 판촉전 돌입(종합)', 'topics': {9: 0.6430790974507267, 0: 0.19042628587402416, 2: 0.019500732027624958, 4: 0.004776576313799226, 5: 0.003014358097756628, 8: 0.002401498114532169, 6: 0.0019214449026202732, 3: 0.001296920346484674, 7: 0.0012278144690711916, 1: 0.0011822365935704833}}, 9: {'name': "'멜론1년+라이언' 카카오미니, 네이버 웨이브 가격과 비교해 봐도 꿀이득", 'topics': {9: 0.43538777811014795, 0: 0.2542564158167624, 2: 0.051091973858363574, 6: 0.025522101676538577, 7: 0.02451318468228537, 4: 0.0069477473655261465, 5: 0.004384520869464186, 8: 0.0034930881665922457, 3: 0.0018864295948867987, 1: 0.0017196168633752484}}, 10: {'name': '카카오와 삼성전자, 인공지능 분야 손잡아···네이버와 플랫폼 경쟁', 'topics': {9: 0.7374374969752473, 4: 0.09546782625382931, 5: 0.03670021745122327, 8: 0.013260872176207573, 6: 0.012907729583536752, 2: 0.0028511132157241076, 0: 0.0021526700682476525, 3: 0.0009540563468393004, 7: 0.0009032198393167386, 1: 0.0008696912872242636}}, 11: {'name': '빅스비-카카오 동맹…기업들 AI 제휴 확산', 'topics': {4: 0.30277909894621047, 2: 0.2749822440888, 9: 0.27415511124405917, 8: 0.05594268981209144, 5: 0.010844717438694765, 0: 0.0017025663267049617, 6: 0.0011179315797063408, 3: 0.0007545718379547195, 7: 0.000714364782005057, 1: 0.0006878467453500993}}, 12: {'name': "네이버-카카오 AI스피커 '브라운 vs 라이언' 맞대결", 'topics': {0: 0.45981831851339344, 9: 0.40224374624066445, 4: 0.004367155486902149, 2: 0.0035435264252571055, 5: 0.0027559845465203454, 8: 0.0021956554190008404, 6: 0.0017567496252528212, 3: 0.0011857557453574163, 7: 0.0011225732288650894 ...
# /n
# {0: {'직장인': 0.01, '인공지능': 164.01, '스피커': 732.01, '유치원': 3.01, '학부모': 6.01, '네이버': 741.01, '웨이브': 284.01, '이벤트': 49.01, '조선일보': 2.01, '프로그램': 0.01, '아이들': 16.01, 'naver': 0.01, 'skt': 0.01, 'ibm': 0.01, 'c&c': 0.01, '에이브': 0.01, '괜찮아': 3.01, '사용자': 51.01, '인공신경망': 0.01, '아마존': 0.01, '스타트': 0.01, '스파크': 2.01, '어린이': 0.01, '문제점': 0.01, '플랫폼': 61.01, '정보기술': 0.01, '연구원': 0.01, 'airi': 0.01, '기업가': 0.01, '리스트': 0.01, '증권사': 0.01, '리포트': 0.01, '기대감': 0.01, 'briefing': 0.01, 'wave': 11.01, '인포테인먼트': 0.01, 'ivi': 0.01, 'vehicle': 0.01, 'infotainment': 0.01, 'away': 0.01, '오프라인': 0.01, 'clova': 26.01, '스마트': 113.01, '카메라': 0.01, '하반기': 0.01, '마케팅': 0.01, '수수료': 0.01, '인건비': 0.01, '투자비': 0.01, '성장률': 0.01, 'statistics': 0.01, 'ktb': 0.01, '실시간': 0.01, 'etbot': 0.01, '인터넷': 0.01, '휴대폰': 10.01, '세탁기': 0.01, '울트론': 0.01, '어벤저스': 0.01, '고양이': 0.01, '컴퓨터': 0.01, '데이터': 0.01, '강아지': 0.01, '이야기': 0.01, '생산성': 0.01, '일자리': 0.01, '상층부': 0.01, '불평등': 0.01, '불안정': 0.01, '플리커': 0.01, 'schubert': 0.01, '인프라': 0.01, '미지수': 0.01, '카카오': 0.01, '제록스': 0.01, '연구소': 0.01, '경쟁력': 0.01, 'items': 0.01, '이용자': 53.01, '관심사': 0.01, '시스템': 0.01, '콘텐츠': 66.01, '움직임': 0.01, '생활환경': 0.01, 'cto': 0.01, '오디오': 22.01, '엔터테인먼트': 0.01, '모바일': 0.01, '프로젝트': 0.01, '중심축': 0.01, '글로벌': 0.01, '자연어': 0.01, '리서치': 0.01, '전문가': 0.01, '제작자': 0.01, '이해진': 0.01, '창업자': 0.01, '책임자': 0.01, '주머니': 0.01, '스마트폰': 0.01, '와이파이': 23.01, '로그인': 0.01, '인간의': 0.01, '컴퓨팅': 0.01, '퍼스트': 0.01, '세계로': 0.01, 'ceo': 0.01, '개발자': 0.01, 'i/o': 0.01, '기조연설': 0.01, '이아이': 0.01, 'google': 0.01, 'bringing': 0.01, 'the': 0.01, 'benefits': 0.01, 'everyone': 0.01, '생태계': 0.01, '우리나라': 0.01, '알파고': 0.01, '유명세': 0.01, '딥마인드': 0.01, '브레인': 0.01, '알고리즘': 0.01, '클라우드': 0.01, '최적화': 0.01, '라이브러리': 0.01, '프레임': 0.01, 'tpu': 0.01, 'tensor': 0.01, 'processing': 0.01, 'unit': 0.01, '프로세서': 0.01, '연구자': 0.01, '일상생활': 0.01, '모회사': 0.01, '알파벳': 0.01, 'xxvi': 0.01, '먹거리': 0.01, '커넥트': 0.01, 'everything': 0.01, '카카오톡': 0.01, '파트너': 0.01, '인터페이스': 0.01, 'kakao': 0.01, 'inside': 0.01, '임지훈': 0.01, '방향성': 0.01, '수입원': 0.01, '브런치': 0.01, '이동하': 0.01, '제네시스': 0.01, '포스코건설': 0.01, '포스코': 0.01, 'ict': 0.01, 'gs건설': 0.01, '자회사': 0.01, '이사회': 0.01, '솔루션': 0.01, '개인화': 0.01, '김병학': 0.01, '국내외': 0.01, '실생활': 5.01, '네트워크': 10.01, '저커버그': 0.01, '하버드': 0.01, '디렉터': 0.01, 'fair': 0.01, '테크놀로지': 0.01, '가상현실': 0.01, '마이크': 26.01, '증강현실': 0.01, '스페이스': 0.01, '커뮤니티': 0.01, '인스타그램': 2.01, '메신저': 0.01, '비디오': 0.01, 'api': 0.01, '선호도': 0.01, '필터버블': 0.01, '정보통신산업진흥원': 0.01, '정기간행물': 0.01, '최계영': 0.01, '정보통신정책연구원': 0.01, 'chaibs': 2.01, 'bloter': 12.01, 'net': 14.01, '저작권': 49.01, '미디어': 23.01, 'sk텔레콤': 0.01, '통신업체': 0.01, 'nugu': 0.01, 'iptv': 0.01, '셋톱박스': 0.01, 'giga': 1.01, 'genie': 0.01, '지난달': 0.01, 'line': 0.01, '사용성': 14.01, '통신업': 0.01, '내비게이션': 0.01, '이동성': 21.01, '이상호': 0.01, '자동차': 0.01, '가입자': 0.01, '사업자': 0.01, '노하우': 0.01, '보조금': 0.01, '경쟁사': 5.01, '경쟁자': 0.01, '가정환경': 0.01, '기술력': 0.01, '테스트': 11.01, '아파트': 0.01, '일부분': 0.01, '포인트': 0.01, '통신사': 0.01, 'inews': 0.01, 'com': 0.01, '프리미엄': 12.01, '스포츠': 10.01, '라이브': 0.01, '아이언맨': 21.01, '자비스': 16.01, '주인공': 19.01, '스타크': 4.01, '미래상': 1.01, '삼성전자': 0.01, '원통형': 6.01, '안녕하세요': 2.01, 'wifi': 2.01, '초록색': 3.01, '마찬가지': 17.01, '업데이트': 48.01, '주황색': 7.01, '난이도': 2.01, '대한민국': 8.01, '대통령': 0.01, '문재인': 0.01, '이튿날': 1.01, '미세먼지': 12.01, '리모컨': 5.01, '궁금증': 3.01, '브리핑': 15.01, '언론사': 6.01, 'ytn': 13.01, '파이브': 0.01, '이퀄라이저': 1.01, '지하철역': 1.01, '분식집': 2.01, '한국어': 11.01, '샤오미': 0.01, '신제품': 0.01, '각축전': 0.01, 'lg유플러스': 0.01, '라디오': 2.01, '판매량': 0.01, '배터리': 78.01, '광화문': 0.01, '만족도': 0.01, '도전장': 0.01, '부사장': 0.01, '스트리밍': 12.01, '올가을': 0.01, 'iot': 0.01, '기업인': 0.01, '가전제품': 2.01, '브랜드': 0.01, '핫이슈': 3.01, 'echo': 0.01, 'lcd': 0.01, '스크린': 0.01, '후속작': 0.01, '시리즈': 0.01, '마이크로소프트': 0.01, '알렉사': 0.01, '코타나': 0.01, '오피스': 0.01, '활용도': 7.01, 'homepod': 0.01, '시너지': 0.01, '파나소닉': 0.01, '베를린': 0.01, '국제가전박람회': 0.01, 'ifa': 0.01, '잠재력': 0.01, '가트너': 0.01, '정확도': 0.01, '문지현': 0.01, '음식점': 0.01, ...
